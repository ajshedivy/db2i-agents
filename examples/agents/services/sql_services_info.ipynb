# %%
from mapepire_python import connect
import os
from textwrap import dedent
from typing import Any, Dict, Optional

from agno.agent import Agent
from agno.models.openai import OpenAIChat
from agno.models.ollama import Ollama
from agno.tools import tool
from dotenv import load_dotenv
from mapepire_python import connect
from pep249 import QueryParameters
from dotenv import load_dotenv

# %%
load_dotenv()

credentials = {
    "host": os.getenv("HOST"),
    "user": os.getenv("DB_USER"),
    "password": os.getenv("PASSWORD"),
    "port": os.getenv("DB_PORT"),
}

ptf_currency = dedent(
    """
    With iLevel(iVersion, iRelease) AS
    (
    select OS_VERSION, OS_RELEASE from sysibmadm.env_sys_info
    )
    SELECT P.*
        FROM iLevel, systools.group_ptf_currency P
        WHERE ptf_group_release = 
            'R' CONCAT iVersion CONCAT iRelease concat '0'
        ORDER BY ptf_group_level_available -
            ptf_group_level_installed DESC
    """
)

def run_sql_statement(
    sql: str,
    parameters: Optional[QueryParameters] = None,
    creds: Dict[str, Any] = credentials,
) -> Any:
    with connect(creds) as conn:
        with conn.execute(sql, parameters=parameters) as cur:
            if cur.has_results:
                result = cur.fetchall()
                return result["data"]
            else:
                return f"No Data found for employee: {id}"

def get_ptf_currency() -> str:
    return run_sql_statement(sql=ptf_currency)

stuff = get_ptf_currency()
stuff
# Out:
# [{'PTF_GROUP_CURRENCY': 'UPDATE AVAILABLE',
#   'PTF_GROUP_ID': 'SF99738',
#   'PTF_GROUP_TITLE': 'SF99738 - 740 Group Security',
#   'PTF_GROUP_LEVEL_INSTALLED': 75,
#   'PTF_GROUP_LEVEL_AVAILABLE': 78,
#   'LAST_UPDATED_BY_IBM': '06/10/25',
#   'PTF_GROUP_RELEASE': 'R740',
#   'PTF_GROUP_STATUS_ON_SYSTEM': 'INSTALLED',
#   'PTF_GROUP_LAST_UPDATED_BY_IBM': '06/10/2025'},
#  {'PTF_GROUP_CURRENCY': 'UPDATE AVAILABLE',
#   'PTF_GROUP_ID': 'SF99739',
#   'PTF_GROUP_TITLE': 'SF99739 - 740 Group Hiper',
#   'PTF_GROUP_LEVEL_INSTALLED': 149,
#   'PTF_GROUP_LEVEL_AVAILABLE': 152,
#   'LAST_UPDATED_BY_IBM': '06/10/25',
#   'PTF_GROUP_RELEASE': 'R740',
#   'PTF_GROUP_STATUS_ON_SYSTEM': 'INSTALLED',
#   'PTF_GROUP_LAST_UPDATED_BY_IBM': '06/10/2025'},
#  {'PTF_GROUP_CURRENCY': 'UPDATE AVAILABLE',
#   'PTF_GROUP_ID': 'SF99662',
#   'PTF_GROUP_TITLE': 'SF99662 - 740 IBM HTTP Server for i',
#   'PTF_GROUP_LEVEL_INSTALLED': 42,
#   'PTF_GROUP_LEVEL_AVAILABLE': 44,
#   'LAST_UPDATED_BY_IBM': '06/09/25',
#   'PTF_GROUP_RELEASE': 'R740',
#   'PTF_GROUP_STATUS_ON_SYSTEM': 'INSTALLED',
#   'PTF_GROUP_LAST_UPDATED_BY_IBM': '06/09/2025'},
#  {'PTF_GROUP_CURRENCY': 'INSTALLED LEVEL IS CURRENT',
#   'PTF_GROUP_ID': 'SF99661',
#   'PTF_GROUP_TITLE': 'SF99661 - 740 WebSphere App Server V8.5',
#   'PTF_GROUP_LEVEL_INSTALLED': 10,
#   'PTF_GROUP_LEVEL_AVAILABLE': 10,
#   'LAST_UPDATED_BY_IBM': '02/08/23',
#   'PTF_GROUP_RELEASE': 'R740',
#   'PTF_GROUP_STATUS_ON_SYSTEM': 'INSTALLED',
#   'PTF_GROUP_LAST_UPDATED_BY_IBM': '02/08/2023'},
#  {'PTF_GROUP_CURRENCY': 'INSTALLED LEVEL IS CURRENT',
#   'PTF_GROUP_ID': 'SF99663',
#   'PTF_GROUP_TITLE': 'SF99663 - 740 Performance Tools',
#   'PTF_GROUP_LEVEL_INSTALLED': 16,
#   'PTF_GROUP_LEVEL_AVAILABLE': 16,
#   'LAST_UPDATED_BY_IBM': '04/24/25',
#   'PTF_GROUP_RELEASE': 'R740',
#   'PTF_GROUP_STATUS_ON_SYSTEM': 'INSTALLED',
#   'PTF_GROUP_LAST_UPDATED_BY_IBM': '04/24/2025'},
#  {'PTF_GROUP_CURRENCY': 'INSTALLED LEVEL IS CURRENT',
#   'PTF_GROUP_ID': 'SF99664',
#   'PTF_GROUP_TITLE': 'SF99664 - 740 Backup Recovery Solutions',
#   'PTF_GROUP_LEVEL_INSTALLED': 46,
#   'PTF_GROUP_LEVEL_AVAILABLE': 46,
#   'LAST_UPDATED_BY_IBM': '04/02/25',
#   'PTF_GROUP_RELEASE': 'R740',
#   'PTF_GROUP_STATUS_ON_SYSTEM': 'INSTALLED',
#   'PTF_GROUP_LAST_UPDATED_BY_IBM': '04/02/2025'},
#  {'PTF_GROUP_CURRENCY': 'INSTALLED LEVEL IS CURRENT',
#   'PTF_GROUP_ID': 'SF99665',
#   'PTF_GROUP_TITLE': 'SF99665 - 740 Java',
#   'PTF_GROUP_LEVEL_INSTALLED': 27,
#   'PTF_GROUP_LEVEL_AVAILABLE': 27,
#   'LAST_UPDATED_BY_IBM': '04/01/25',
#   'PTF_GROUP_RELEASE': 'R740',
#   'PTF_GROUP_STATUS_ON_SYSTEM': 'INSTALLED',
#   'PTF_GROUP_LAST_UPDATED_BY_IBM': '04/01/2025'},
#  {'PTF_GROUP_CURRENCY': 'INSTALLED LEVEL IS CURRENT',
#   'PTF_GROUP_ID': 'SF99666',
#   'PTF_GROUP_TITLE': 'SF99666 - 740 High Availability for IBM i',
#   'PTF_GROUP_LEVEL_INSTALLED': 20,
#   'PTF_GROUP_LEVEL_AVAILABLE': 20,
#   'LAST_UPDATED_BY_IBM': '04/18/25',
#   'PTF_GROUP_RELEASE': 'R740',
#   'PTF_GROUP_STATUS_ON_SYSTEM': 'INSTALLED',
#   'PTF_GROUP_LAST_UPDATED_BY_IBM': '04/18/2025'},
#  {'PTF_GROUP_CURRENCY': 'INSTALLED LEVEL IS CURRENT',
#   'PTF_GROUP_ID': 'SF99667',
#   'PTF_GROUP_TITLE': 'SF99667 - 740 740 TCP/IP PTF',
#   'PTF_GROUP_LEVEL_INSTALLED': 13,
#   'PTF_GROUP_LEVEL_AVAILABLE': 13,
#   'LAST_UPDATED_BY_IBM': '09/29/24',
#   'PTF_GROUP_RELEASE': 'R740',
#   'PTF_GROUP_STATUS_ON_SYSTEM': 'INSTALLED',
#   'PTF_GROUP_LAST_UPDATED_BY_IBM': '09/29/2024'},
#  {'PTF_GROUP_CURRENCY': 'INSTALLED LEVEL IS CURRENT',
#   'PTF_GROUP_ID': 'SF99668',
#   'PTF_GROUP_TITLE': 'SF99668 - 740 IBM Db2 Mirror for i',
#   'PTF_GROUP_LEVEL_INSTALLED': 26,
#   'PTF_GROUP_LEVEL_AVAILABLE': 26,
#   'LAST_UPDATED_BY_IBM': '04/16/25',
#   'PTF_GROUP_RELEASE': 'R740',
#   'PTF_GROUP_STATUS_ON_SYSTEM': 'INSTALLED',
#   'PTF_GROUP_LAST_UPDATED_BY_IBM': '04/16/2025'},
#  {'PTF_GROUP_CURRENCY': 'INSTALLED LEVEL IS CURRENT',
#   'PTF_GROUP_ID': 'SF99675',
#   'PTF_GROUP_TITLE': 'SF99675 - 740 Hardware and Related PTFs',
#   'PTF_GROUP_LEVEL_INSTALLED': 2,
#   'PTF_GROUP_LEVEL_AVAILABLE': 2,
#   'LAST_UPDATED_BY_IBM': '01/16/20',
#   'PTF_GROUP_RELEASE': 'R740',
#   'PTF_GROUP_STATUS_ON_SYSTEM': 'INSTALLED',
#   'PTF_GROUP_LAST_UPDATED_BY_IBM': '01/16/2020'},
#  {'PTF_GROUP_CURRENCY': None,
#   'PTF_GROUP_ID': 'SF99704',
#   'PTF_GROUP_TITLE': 'SF99704 - 740 Db2 for IBM i',
#   'PTF_GROUP_LEVEL_INSTALLED': 30,
#   'PTF_GROUP_LEVEL_AVAILABLE': 30,
#   'LAST_UPDATED_BY_IBM': '04/16/25',
#   'PTF_GROUP_RELEASE': 'R740',
#   'PTF_GROUP_STATUS_ON_SYSTEM': 'NOT INSTALLED',
#   'PTF_GROUP_LAST_UPDATED_BY_IBM': '04/16/2025'},
#  {'PTF_GROUP_CURRENCY': 'INSTALLED LEVEL IS CURRENT',
#   'PTF_GROUP_ID': 'SF99737',
#   'PTF_GROUP_TITLE': 'SF99737 - 740 Technology Refresh',
#   'PTF_GROUP_LEVEL_INSTALLED': 11,
#   'PTF_GROUP_LEVEL_AVAILABLE': 11,
#   'LAST_UPDATED_BY_IBM': '11/20/24',
#   'PTF_GROUP_RELEASE': 'R740',
#   'PTF_GROUP_STATUS_ON_SYSTEM': 'INSTALLED',
#   'PTF_GROUP_LAST_UPDATED_BY_IBM': '11/20/2024'},
#  {'PTF_GROUP_CURRENCY': 'INSTALLED LEVEL IS CURRENT',
#   'PTF_GROUP_ID': 'SF99740',
#   'PTF_GROUP_TITLE': 'SF99740 - 740 Cumulative PTF Package',
#   'PTF_GROUP_LEVEL_INSTALLED': 25107,
#   'PTF_GROUP_LEVEL_AVAILABLE': 25107,
#   'LAST_UPDATED_BY_IBM': '04/18/25',
#   'PTF_GROUP_RELEASE': 'R740',
#   'PTF_GROUP_STATUS_ON_SYSTEM': 'INSTALLED',
#   'PTF_GROUP_LAST_UPDATED_BY_IBM': '04/18/2025'}]

# %%
services_info = dedent(
    """
    select * from qsys2.services_info 
    """
)

services = run_sql_statement(services_info)
services
# Out:
# [{'SERVICE_CATEGORY': 'PTF',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'PTF_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'PTF_INFO',
#   'LATEST_DB2_GROUP_LEVEL': 26,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Will an IPL impact PTF state? \r\n  SELECT PTF_IDENTIFIER, PTF_IPL_ACTION, A.* \r\n  FROM QSYS2.PTF_INFO A \r\n       WHERE PTF_IPL_ACTION <> 'NONE';"},
#  {'SERVICE_CATEGORY': 'PTF',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'GROUP_PTF_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'GRPPTFINFO',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: What is the most recently installed CUM? \r\n  SELECT MAX(PTF_GROUP_LEVEL) AS CUM_LEVEL FROM \r\n  QSYS2.GROUP_PTF_INFO P, SYSIBMADM.ENV_SYS_INFO V \r\n  WHERE PTF_GROUP_NAME = 'SF99' CONCAT V.OS_VERSION CONCAT V.OS_RELEASE CONCAT '0' \r\n  AND PTF_GROUP_STATUS = 'INSTALLED';"},
#  {'SERVICE_CATEGORY': 'PTF',
#   'SERVICE_SCHEMA_NAME': 'SYSTOOLS',
#   'SERVICE_NAME': 'GROUP_PTF_CURRENCY',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'GRPPTFCUR',
#   'LATEST_DB2_GROUP_LEVEL': 10,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Determine whether the PTF Groups are current \r\n  SELECT * FROM SYSTOOLS.GROUP_PTF_CURRENCY, SYSIBMADM.ENV_SYS_INFO V  \r\n  WHERE PTF_GROUP_RELEASE = 'R' CONCAT V.OS_VERSION CONCAT V.OS_RELEASE CONCAT '0' \r\n  ORDER BY PTF_GROUP_LEVEL_AVAILABLE - PTF_GROUP_LEVEL_INSTALLED DESC;"},
#  {'SERVICE_CATEGORY': 'PTF',
#   'SERVICE_SCHEMA_NAME': 'SYSTOOLS',
#   'SERVICE_NAME': 'GROUP_PTF_DETAILS',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'GRPPTFDTL',
#   'LATEST_DB2_GROUP_LEVEL': 10,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Review all unapplied PTFs contained within PTF Groups installed \r\n-- on the partition against the live PTF detail available from IBM \r\n  SELECT * FROM SYSTOOLS.GROUP_PTF_DETAILS \r\n  WHERE PTF_STATUS <> 'PTF APPLIED' \r\n  ORDER BY PTF_GROUP_NAME;"},
#  {'SERVICE_CATEGORY': 'SECURITY',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'USER_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'USER_INFO',
#   'LATEST_DB2_GROUP_LEVEL': 13,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Which users are at risk of becoming disabled due to lack of use? \r\n SELECT * FROM QSYS2.USER_INFO \r\n WHERE STATUS = '*ENABLED' AND LAST_USED_TIMESTAMP IS NOT NULL \r\n ORDER BY LAST_USED_TIMESTAMP ASC \r\n FETCH FIRST 20 ROWS ONLY;"},
#  {'SERVICE_CATEGORY': 'SECURITY',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'FUNCTION_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'FCN_INFO',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': '-- Description: Which function usage IDs exist \r\n SELECT * FROM QSYS2.FUNCTION_INFO ORDER BY FUNCTION_ID;'},
#  {'SERVICE_CATEGORY': 'SECURITY',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'FUNCTION_USAGE',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'FCN_USAGE',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Which Database function usage has been granted or revoked? \r\n   SELECT * FROM QSYS2.FUNCTION_USAGE \r\n   WHERE FUNCTION_ID LIKE 'QIBM_DB_%' ORDER BY FUNCTION_ID, USER_NAME;"},
#  {'SERVICE_CATEGORY': 'SECURITY',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'GROUP_PROFILE_ENTRIES',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'GROUPLIST',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Review *ALLOBJ users \r\n SELECT AUTHORIZATION_NAME, STATUS, NO_PASSWORD_INDICATOR, PREVIOUS_SIGNON, \r\n TEXT_DESCRIPTION \r\n FROM QSYS2.USER_INFO \r\n WHERE SPECIAL_AUTHORITIES LIKE '%*ALLOBJ%' \r\n OR AUTHORIZATION_NAME IN ( \r\n SELECT USER_PROFILE_NAME \r\n FROM QSYS2.GROUP_PROFILE_ENTRIES \r\n WHERE GROUP_PROFILE_NAME IN ( \r\n SELECT AUTHORIZATION_NAME \r\n FROM QSYS2.USER_INFO \r\n WHERE SPECIAL_AUTHORITIES like '%*ALLOBJ%')) \r\n ORDER BY AUTHORIZATION_NAME;"},
#  {'SERVICE_CATEGORY': 'SECURITY',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SQL_CHECK_AUTHORITY',
#   'SQL_OBJECT_TYPE': 'SCALAR FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Does this user have authority to query this file \r\n   VALUES ( CASE WHEN QSYS2.SQL_CHECK_AUTHORITY('QSYS2','SYSLIMITS') = 1 \r\n   THEN 'I can query QSYS2/SYSLIMITS' ELSE 'No query access for me' END );"},
#  {'SERVICE_CATEGORY': 'SECURITY',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SET_COLUMN_ATTRIBUTE',
#   'SQL_OBJECT_TYPE': 'PROCEDURE',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Secure salary column values in the SQL Performance Center \r\n     CALL SYSPROC.SET_COLUMN_ATTRIBUTE('TOYSTORE', 'EMPLOYEE', 'SALARY', \r\n     'SECURE YES'); \r\n-- Review configuration of SECURE column values for DBE & Performance analysts \r\n SELECT COLUMN_NAME,SECURE \r\n    FROM QSYS2.SYSCOLUMNS2 \r\n    WHERE SYSTEM_TABLE_SCHEMA = 'TOYSTORE' AND SYSTEM_TABLE_NAME = 'EMPLOYEE';"},
#  {'SERVICE_CATEGORY': 'SECURITY',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'DRDA_AUTHENTICATION_ENTRY_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'DRDA_AUTHE',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': '-- Description: Retrieve the DRDA Authentication Entry info \r\n SELECT * FROM QSYS2.DRDA_AUTHENTICATION_ENTRY_INFO \r\n  ORDER BY AUTHORIZATION_NAME, SERVER_NAME;'},
#  {'SERVICE_CATEGORY': 'SECURITY',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'AUTHORITY_COLLECTION',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'AUTH_COL',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R3M0',
#   'EXAMPLE': "-- Description: Review authority failures, contrasting the authority required versus the current authority \r\nSELECT AUTHORIZATION_NAME, OBJECT_NAME, SYSTEM_OBJECT_TYPE, \r\nREQUIRED_AUTHORITY, DETAILED_REQUIRED_AUTHORITY, CURRENT_AUTHORITY, A.* \r\n FROM QSYS2.AUTHORITY_COLLECTION A \r\n WHERE AUTHORITY_CHECK_SUCCESSFUL = '0' ORDER BY 1;"},
#  {'SERVICE_CATEGORY': 'SECURITY',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'OBJECT_PRIVILEGES',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'OBJ_PRIV',
#   'LATEST_DB2_GROUP_LEVEL': 7,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R2M0',
#   'EXAMPLE': "-- Description: Review *PUBLIC authority for user libraries \r\nSELECT OBJECT_AUTHORITY AS LIBRARY_AUTHORITY, COUNT(*) AS COUNT \r\n FROM TABLE(QSYS2.OBJECT_STATISTICS('*ALLUSR', 'LIB')) L, \r\n LATERAL (SELECT OBJECT_AUTHORITY \r\n   FROM QSYS2.OBJECT_PRIVILEGES \r\n   WHERE NAME = L.OBJNAME AND \r\n   OBJECT_SCHEMA = 'QSYS' AND \r\n   OBJECT_TYPE = '*LIB' AND \r\n   USER_NAME = '*PUBLIC') p \r\n GROUP BY OBJECT_AUTHORITY \r\n ORDER BY 2 DESC;"},
#  {'SERVICE_CATEGORY': 'SECURITY',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'AUTHORIZATION_LIST_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'AUTHL_INFO',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R2M0',
#   'EXAMPLE': "-- Description: Find objects not included in the authorization list for \r\n  --  Schema = TOYSTORE  Authorization List = TOYSTOREAL \r\nWITH ALLOBJS(OBJNAME, OBJDEFINER, OBJTYPE, SQL_OBJECT_TYPE) AS ( \r\nSELECT OBJNAME, OBJDEFINER, OBJTYPE, SQL_OBJECT_TYPE   \r\n FROM TABLE(QSYS2.OBJECT_STATISTICS('TOYSTORE', 'ALL')) O), \r\n AUTLOBJS(OBJNAME) AS ( \r\nSELECT SYSTEM_OBJECT_NAME  \r\n FROM QSYS2.AUTHORIZATION_LIST_INFO b  \r\n   WHERE B.AUTHORIZATION_LIST = 'TOYSTOREAL' \r\n) SELECT A.OBJNAME, OBJDEFINER, OBJTYPE, SQL_OBJECT_TYPE \r\n  FROM ALLOBJS A LEFT EXCEPTION JOIN AUTLOBJS B  \r\n  ON A.OBJNAME = B.OBJNAME;"},
#  {'SERVICE_CATEGORY': 'SECURITY',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'AUTHORIZATION_LIST_USER_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'AUTL_USERS',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R2M0',
#   'EXAMPLE': "-- Description: Review JOEUSER's object access via authorization lists \r\nSELECT AUTHORIZATION_LIST, object_authority  \r\n   FROM QSYS2.AUTHORIZATION_LIST_USER_INFO B \r\n   WHERE AUTHORIZATION_NAME = 'JOEUSER' OR \r\n         (AUTHORIZATION_NAME = '*PUBLIC' AND \r\n         OBJECT_AUTHORITY <> '*EXCLUDE') \r\n   ORDER BY 1;"},
#  {'SERVICE_CATEGORY': 'WORK MANAGEMENT',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SYSTEM_VALUE_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'SYSVALINFO',
#   'LATEST_DB2_GROUP_LEVEL': 26,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': '-- Description: Compare System Values across two partitions \r\n DECLARE GLOBAL TEMPORARY TABLE SESSION.Remote_System_Values \r\n ( SYSTEM_VALUE_NAME,CURRENT_NUMERIC_VALUE,CURRENT_CHARACTER_VALUE ) \r\n AS (SELECT * FROM REMOTEPART.QSYS2.SYSTEM_VALUE_INFO) WITH DATA \r\n WITH REPLACE; \r\n-- Use exception join to reveal any differences \r\n  SELECT \'REMOTEPART\' AS "System Name", A.SYSTEM_VALUE_NAME, \r\n  A.CURRENT_NUMERIC_VALUE,A.CURRENT_CHARACTER_VALUE FROM QSYS2.SYSTEM_VALUE_INFO A \r\n LEFT EXCEPTION JOIN SESSION.Remote_System_Values B \r\n ON A.SYSTEM_VALUE_NAME = B.SYSTEM_VALUE_NAME AND \r\n    A.CURRENT_NUMERIC_VALUE IS NOT DISTINCT FROM B.CURRENT_NUMERIC_VALUE AND \r\n    A.CURRENT_CHARACTER_VALUE IS NOT DISTINCT FROM B.CURRENT_CHARACTER_VALUE \r\n UNION ALL \r\n  SELECT \'LOCALPART\' AS "System Name", B.SYSTEM_VALUE_NAME, \r\n  B.CURRENT_NUMERIC_VALUE, \r\n  B.CURRENT_CHARACTER_VALUE FROM QSYS2.SYSTEM_VALUE_INFO A \r\n RIGHT EXCEPTION JOIN SESSION.Remote_System_Values B \r\n ON A.SYSTEM_VALUE_NAME = B.SYSTEM_VALUE_NAME AND \r\n    A.CURRENT_NUMERIC_VALUE IS NOT DISTINCT FROM B.CURRENT_NUMERIC_VALUE AND \r\n    A.CURRENT_CHARACTER_VALUE IS NOT DISTINCT FROM B.CURRENT_CHARACTER_VALUE \r\n ORDER BY SYSTEM_VALUE_NAME;'},
#  {'SERVICE_CATEGORY': 'WORK MANAGEMENT',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'GET_JOB_INFO',
#   'SQL_OBJECT_TYPE': 'TABLE FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Find the jobs with SQL statements executing \r\n WITH ACTIVE_USER_JOBS (Q_JOB_NAME, CPU_TIME, RUN_PRIORITY) AS ( \r\n SELECT \r\n  JOB_NAME, CPU_TIME, RUN_PRIORITY \r\n  FROM TABLE (ACTIVE_JOB_INFO()) x \r\n WHERE JOB_TYPE <> 'SYS' \r\n ) SELECT Q_JOB_NAME, CPU_TIME, RUN_PRIORITY, V_SQL_STATEMENT_TEXT, \r\n ABS( CURRENT TIMESTAMP - V_SQL_STMT_START_TIMESTAMP ) AS SQL_STMT_DURATION, B.* \r\n FROM ACTIVE_USER_JOBS, TABLE(QSYS2.GET_JOB_INFO(Q_JOB_NAME)) B \r\n WHERE V_SQL_STMT_STATUS = 'ACTIVE' \r\n ORDER BY SQL_STMT_DURATION DESC;"},
#  {'SERVICE_CATEGORY': 'WORK MANAGEMENT',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'ACTIVE_JOB_INFO',
#   'SQL_OBJECT_TYPE': 'TABLE FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Find the top 10 consumers of CPU in the QUSRWRK and QSYSWRK subsystems \r\n select CPU_TIME, A.* FROM \r\n table(QSYS2.ACTIVE_JOB_INFO(SUBSYSTEM_LIST_FILTER => 'QUSRWRK,QSYSWRK')) A \r\n ORDER BY CPU_TIME DESC \r\n LIMIT 10;"},
#  {'SERVICE_CATEGORY': 'WORK MANAGEMENT',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SCHEDULED_JOB_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'SCHED_JOB',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Review the job scheduled entries which are no longer in effect \r\n   SELECT * FROM QSYS2.SCHEDULED_JOB_INFO WHERE \r\n   STATUS IN ('HELD', 'SAVED') ORDER BY SCHEDULED_BY;"},
#  {'SERVICE_CATEGORY': 'WORK MANAGEMENT',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'MEMORY_POOL',
#   'SQL_OBJECT_TYPE': 'TABLE FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Return all available pool information. \r\n SELECT * FROM TABLE(QSYS2.MEMORY_POOL('YES')) X;"},
#  {'SERVICE_CATEGORY': 'WORK MANAGEMENT',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'MEMORY_POOL_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'POOL_INFO',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': '-- Description: Review the details of all active memory pools. \r\n SELECT * FROM QSYS2.MEMORY_POOL_INFO;'},
#  {'SERVICE_CATEGORY': 'WORK MANAGEMENT',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SYSTEM_STATUS',
#   'SQL_OBJECT_TYPE': 'TABLE FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Review elapsed system status over a 60 second window \r\n DECLARE GLOBAL TEMPORARY TABLE SESSION.SYSTEM_STATUS_REFERENCE_POINT AS ( \r\n  SELECT TOTAL_JOBS_IN_SYSTEM, ACTIVE_JOBS_IN_SYSTEM, ELAPSED_CPU_USED, \r\n         ELAPSED_CPU_SHARED, ELAPSED_CPU_UNCAPPED_CAPACITY \r\n    FROM TABLE(QSYS2.SYSTEM_STATUS('YES')) A \r\n ) WITH DATA WITH REPLACE; \r\n CALL QSYS2.QCMDEXC('DLYJOB DLY(60)'); \r\n SELECT B.TOTAL_JOBS_IN_SYSTEM - A.TOTAL_JOBS_IN_SYSTEM \r\n   AS DELTA_TOTAL_JOBS_IN_SYSTEM, \r\n B.ACTIVE_JOBS_IN_SYSTEM - A.ACTIVE_JOBS_IN_SYSTEM \r\n AS DELTA_ACTIVE_JOBS_IN_SYSTEM, \r\n        B.ELAPSED_TIME, \r\n B.ELAPSED_CPU_USED - A.ELAPSED_CPU_USED \r\n AS DELTA_ELAPSED_CPU_USED, \r\n B.ELAPSED_CPU_SHARED - A.ELAPSED_CPU_SHARED \r\n AS DELTA_ELAPSED_CPU_SHARED, \r\n B.ELAPSED_CPU_UNCAPPED_CAPACITY - A.ELAPSED_CPU_UNCAPPED_CAPACITY \r\n AS DELTA_ELAPSED_CPU_UNCAPPED_CAPACITY \r\n FROM SESSION.SYSTEM_STATUS_REFERENCE_POINT A, \r\n TABLE(QSYS2.SYSTEM_STATUS('NO')) B;"},
#  {'SERVICE_CATEGORY': 'WORK MANAGEMENT',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SYSTEM_STATUS_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'SYS_STATUS',
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': '-- Description: Review current system status, including the job max percentage \r\n SELECT TOTAL_JOBS_IN_SYSTEM, MAXIMUM_JOBS_IN_SYSTEM, \r\n DECIMAL((DECIMAL(TOTAL_JOBS_IN_SYSTEM) / \r\n          DECIMAL(MAXIMUM_JOBS_IN_SYSTEM)), 11, 3) * 100 AS JOB_MAX_PERCENT, A.* \r\n    FROM QSYS2.SYSTEM_STATUS_INFO A;'},
#  {'SERVICE_CATEGORY': 'WORK MANAGEMENT',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'OBJECT_LOCK_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'OBJ_LOCK',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Find any object locks over the TOYSTORE/SALES table \r\n WITH LOCK_CONFLICT_TABLE (object_name, lock_state, q_job_name) AS ( \r\n SELECT object_name, lock_state, job_name \r\n FROM QSYS2.OBJECT_LOCK_INFO where \r\n object_schema = 'TOYSTORE' and \r\n object_name = 'SALES' ) \r\n      SELECT object_name, lock_state, q_job_name, \r\n    V_SQL_STATEMENT_TEXT, V_CLIENT_IP_ADDRESS, \r\n   B.* FROM LOCK_CONFLICT_TABLE, \r\n TABLE(QSYS2.GET_JOB_INFO(q_job_name)) B;"},
#  {'SERVICE_CATEGORY': 'WORK MANAGEMENT',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'RECORD_LOCK_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'RCD_LOCK',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Find any record locks over the TOYSTORE/SALES table \r\n WITH LOCK_CONFLICT_TABLE ( \r\n  table_name, lock_state, rrn, q_job_name) AS ( \r\n SELECT table_name, lock_state, rrn, job_name \r\n FROM QSYS2.RECORD_LOCK_INFO where \r\n  table_schema = 'TOYSTORE' and \r\n  table_name = 'SALES' \r\n ) SELECT table_name, lock_state, rrn, \r\n          q_job_name, V_SQL_STATEMENT_TEXT, \r\n          V_CLIENT_IP_ADDRESS, B.* \r\n     FROM LOCK_CONFLICT_TABLE, TABLE(QSYS2.GET_JOB_INFO(q_job_name)) B;"},
#  {'SERVICE_CATEGORY': 'WORK MANAGEMENT',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'JOB_INFO',
#   'SQL_OBJECT_TYPE': 'TABLE FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 13,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R2M0',
#   'EXAMPLE': "-- Description: Review jobs that are scheduled to run tomorrow\r\n SELECT * \r\n   FROM TABLE(qsys2.job_info(job_status_filter => '*JOBQ')) x \r\n   WHERE job_scheduled_time BETWEEN DATE(CURRENT TIMESTAMP + 1 DAY) \r\n      AND DATE(CURRENT TIMESTAMP + 2 DAYS) \r\n   ORDER BY job_scheduled_time  ;"},
#  {'SERVICE_CATEGORY': 'WORK MANAGEMENT',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'JOB_QUEUE_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'JOBQ_INFO',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R2M0',
#   'EXAMPLE': '-- Description: Examine the job queues with the largest number of active jobs.\r\n SELECT * FROM QSYS2.JOB_QUEUE_INFO \r\n WHERE ACTIVE_JOBS IS NOT NULL \r\n ORDER BY NUMBER_OF_JOBS DESC;'},
#  {'SERVICE_CATEGORY': 'MESSAGE HANDLING',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'REPLY_LIST_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'REPLYLIST',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Review reply list detail for all messages which begin with CPA \r\n SELECT * FROM QSYS2.REPLY_LIST_INFO WHERE message_ID LIKE 'CPA%';"},
#  {'SERVICE_CATEGORY': 'MESSAGE HANDLING',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'JOBLOG_INFO',
#   'SQL_OBJECT_TYPE': 'TABLE FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 20,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Find the top 25 consumers of CPU in active QSQSRVR jobs \r\nWITH TT(AUTHORIZATION_NAME, SERVER_MODE_JOB_NAME, CPU_TIME, TOTAL_DISK_IO_COUNT) \r\nAS (SELECT AUTHORIZATION_NAME, JOB_NAME, CPU_TIME, TOTAL_DISK_IO_COUNT \r\n    FROM TABLE(QSYS2.ACTIVE_JOB_INFO(JOB_NAME_FILTER => 'QSQSRVR')) X) \r\nSELECT AUTHORIZATION_NAME, SS.MESSAGE_TEXT, \r\n       SERVER_MODE_JOB_NAME, CPU_TIME, TOTAL_DISK_IO_COUNT \r\nFROM TT, TABLE(QSYS2.JOBLOG_INFO(SERVER_MODE_JOB_NAME)) SS \r\nWHERE MESSAGE_ID = 'CPF9898' AND FROM_PROGRAM = 'QSQSRVR' \r\nORDER BY CPU_TIME DESC LIMIT 25;"},
#  {'SERVICE_CATEGORY': 'MESSAGE HANDLING',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'HISTORY_LOG_INFO',
#   'SQL_OBJECT_TYPE': 'TABLE FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 23,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R2M0',
#   'EXAMPLE': "-- Description: Compute the 50 user jobs with the longest time span, \r\n     -- that started between yesterday (midnight) and now \r\n   WITH new_jobs(job_name, start_time) \r\n   AS (SELECT from_job, message_timestamp \r\n          FROM TABLE(qsys2.history_log_info()) x \r\n          WHERE message_id = 'CPF1124'), \r\n     ended_jobs(job_name, end_time) \r\n   AS (SELECT from_job, message_timestamp \r\n          FROM TABLE(qsys2.history_log_info()) x \r\n          WHERE message_id = 'CPF1164') \r\n   SELECT n.job_name, \r\n          TIMESTAMPDIFF(4, CAST(end_time - start_time AS CHAR(22))) AS execution_minutes \r\n          FROM new_jobs n INNER JOIN ended_jobs e ON n.job_name = e.job_name \r\n      WHERE n.job_name NOT LIKE '%/Q%/%' \r\n      ORDER BY execution_minutes DESC \r\n      FETCH FIRST 50 ROWS ONLY  ;"},
#  {'SERVICE_CATEGORY': 'MESSAGE HANDLING',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'MESSAGE_QUEUE_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'MSGQ_INFO',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R2M0',
#   'EXAMPLE': "-- Description: Review system operator license expiration messages \r\nSELECT MESSAGE_TEXT, M.* \r\n   FROM QSYS2.MESSAGE_QUEUE_INFO M \r\n   WHERE MESSAGE_QUEUE_NAME = 'QSYSOPR' AND \r\n         MESSAGE_TEXT LIKE '%EXPIRE%';"},
#  {'SERVICE_CATEGORY': 'LIBRARIAN',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'LIBRARY_LIST_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'LIBLIST',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Ensure that the TOYSTORE library is the first library \r\n-- in the user portion of the library list \r\n BEGIN \r\n DECLARE V_ROW_NUM INTEGER; \r\n WITH CTE1(SCHEMA_NAME, ROW_NUM) AS ( \r\n SELECT SCHEMA_NAME, ROW_NUMBER() OVER (ORDER BY ORDINAL_POSITION) AS ROW_NUM \r\n FROM QSYS2.LIBRARY_LIST_INFO WHERE TYPE = 'USER' \r\n ) SELECT ROW_NUM INTO V_ROW_NUM FROM CTE1 WHERE SCHEMA_NAME = 'TOYSTORE'; \r\n IF (V_ROW_NUM IS NULL) THEN \r\n   CALL QSYS2.QCMDEXC('ADDLIBLE TOYSTORE'); \r\n ELSEIF (V_ROW_NUM > 1) THEN \r\n   BEGIN \r\n     CALL QSYS2.QCMDEXC('RMVLIBLE TOYSTORE'); \r\n     CALL QSYS2.QCMDEXC('ADDLIBLE TOYSTORE'); \r\n   END; \r\n END IF; \r\n END;"},
#  {'SERVICE_CATEGORY': 'LIBRARIAN',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'OBJECT_STATISTICS',
#   'SQL_OBJECT_TYPE': 'TABLE FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 13,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Find programs that are the least utilized \r\n   SELECT S1.OBJNAME, P.OBJCREATED, P.OBJNAME, P.OBJLONGNAME, P.OBJTYPE, \r\n   P.SQL_OBJECT_TYPE, P.OBJDEFINER, \r\n   P.LAST_USED_TIMESTAMP, P.LAST_RESET_TIMESTAMP \r\n   FROM TABLE(QSYS2.OBJECT_STATISTICS('*ALLUSR', 'LIB    ')) AS S1, \r\n   LATERAL \r\n (SELECT * FROM TABLE(QSYS2.OBJECT_STATISTICS(S1.OBJNAME, \r\n                                              'PGM SRVPGM')) AS X) AS P \r\n    WHERE S1.OBJNAME NOT LIKE 'Q%' AND \r\n    P.LAST_USED_TIMESTAMP IS NULL \r\n    OR P.DAYS_USED_COUNT = 0 \r\n    ORDER BY OBJCREATED ASC \r\n    LIMIT 100;"},
#  {'SERVICE_CATEGORY': 'STORAGE',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'USER_STORAGE',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'USER_STG',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Review the top 10 storage consumers, by user \r\n    SELECT A.AUTHORIZATION_NAME, SUM(A.STORAGE_USED) AS \r\n    TOTAL_STORAGE_USED, \r\n    B.TEXT_DESCRIPTION, B.ACCOUNTING_CODE, B.MAXIMUM_ALLOWED_STORAGE \r\n   FROM QSYS2.USER_STORAGE A \r\n    INNER JOIN QSYS2.USER_INFO B ON B.USER_NAME = A.AUTHORIZATION_NAME \r\n    WHERE \r\n    B.USER_NAME NOT LIKE 'Q%' \r\n    GROUP BY A.AUTHORIZATION_NAME, B.TEXT_DESCRIPTION, \r\n    B.ACCOUNTING_CODE, \r\n    B.MAXIMUM_ALLOWED_STORAGE \r\n   ORDER BY TOTAL_STORAGE_USED DESC FETCH FIRST 10 ROWS ONLY;"},
#  {'SERVICE_CATEGORY': 'STORAGE',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SYSDISKSTAT',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'SYSDISKS',
#   'LATEST_DB2_GROUP_LEVEL': 28,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Query information for all storage devices \r\n SELECT PERCENT_USED, \r\n       CASE WHEN UNIT_TYPE = 1 \r\n          THEN 'SSD' \r\n          ELSE 'DISK' END as STORAGE_TYPE, A.* \r\n FROM QSYS2.SYSDISKSTAT A \r\n ORDER BY PERCENT_USED DESC;"},
#  {'SERVICE_CATEGORY': 'STORAGE',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SYSTMPSTG',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'SYSTMPSTG',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R2M0',
#   'EXAMPLE': "-- Description: Looking at the database server jobs, find the \r\n-- top 10 consumers of temporary storage and retrieve \r\n-- details about those jobs. \r\n WITH TOP_TMP_STG(BUCKET_CURRENT_SIZE, BUCKET_PEAK_SIZE, Q_JOB_NAME) \r\n AS (SELECT BUCKET_CURRENT_SIZE, BUCKET_PEAK_SIZE, RTRIM(JOB_NUMBER) CONCAT '/' CONCAT \r\n     RTRIM(JOB_USER_NAME) CONCAT '/' CONCAT RTRIM(JOB_NAME) AS Q_JOB_NAME \r\n    FROM QSYS2.SYSTMPSTG \r\n    WHERE JOB_STATUS = '*ACTIVE' AND \r\n    JOB_NAME IN ('QZDASOINIT', 'QZDASSINIT', 'QRWTSRVR', 'QSQSRVR') \r\n    ORDER BY BUCKET_CURRENT_SIZE DESC \r\n    FETCH FIRST 10 ROWS ONLY) \r\n SELECT BUCKET_CURRENT_SIZE, BUCKET_PEAK_SIZE, Q_JOB_NAME, V_SQL_STATEMENT_TEXT, B.* \r\n FROM TOP_TMP_STG, TABLE(QSYS2.GET_JOB_INFO(Q_JOB_NAME)) B;"},
#  {'SERVICE_CATEGORY': 'BACKUP AND RECOVERY',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'MEDIA_LIBRARY_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'MEDIA_INFO',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Check for unavailable tape drives \r\n SELECT * FROM QSYS2.MEDIA_LIBRARY_INFO WHERE DEVICE_STATUS = 'VARIED OFF';"},
#  {'SERVICE_CATEGORY': 'STORAGE',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'ASP_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'ASP_INFO',
#   'LATEST_DB2_GROUP_LEVEL': 25,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R2M0',
#   'EXAMPLE': '-- Description: Show the ASP information for the partition. \r\n SELECT * FROM QSYS2.ASP_INFO;'},
#  {'SERVICE_CATEGORY': 'STORAGE',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'ASP_VARY_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'VARY_INFO',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R2M0',
#   'EXAMPLE': '-- Description: Analyze the total time needed for vary on and off. \r\n SELECT IASP_NAME, OPERATION_TYPE, OPERATION_NUMBER,   BIGINT(SUM(DURATION)) AS TOTAL_SECONDS,  DATE(MAX(START_TIMESTAMP)) AS WHEN   FROM QSYS2.ASP_VARY_INFO GROUP BY IASP_NAME, OPERATION_TYPE,   OPERATION_NUMBER ORDER BY 5 DESC;'},
#  {'SERVICE_CATEGORY': 'PRODUCT',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'LICENSE_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'LIC_INFO',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Review licenses for installed features  \r\n     --    which have logged license violations  \r\n SELECT L.*  \r\n   FROM QSYS2.LICENSE_INFO L  \r\n   WHERE INSTALLED = 'YES' AND  \r\n         LOG_VIOLATION = 'YES';"},
#  {'SERVICE_CATEGORY': 'PTF',
#   'SERVICE_SCHEMA_NAME': 'SYSTOOLS',
#   'SERVICE_NAME': 'FIRMWARE_CURRENCY',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'FWCUR',
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R3M0',
#   'EXAMPLE': '-- Description: Determine whether there is a newer version of \r\n-- firmware available for the current partition \r\n  SELECT * FROM SYSTOOLS.FIRMWARE_CURRENCY;'},
#  {'SERVICE_CATEGORY': 'SPOOL',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'OUTPUT_QUEUE_ENTRIES',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'OUTQ_INFO',
#   'LATEST_DB2_GROUP_LEVEL': 23,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': '-- Description: Find spool files that will expire within two weeks \r\n SELECT * FROM QSYS2.OUTPUT_QUEUE_ENTRIES \r\n   WHERE EXPIRATION_DATE < CURRENT DATE + 14 DAYS \r\n   ORDER BY EXPIRATION_DATE DESC;'},
#  {'SERVICE_CATEGORY': 'SPOOL',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'OUTPUT_QUEUE_ENTRIES',
#   'SQL_OBJECT_TYPE': 'TABLE FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 23,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Find the top 10 consumers of SPOOL storage \r\n SELECT USER_NAME, SUM(SIZE) AS TOTAL_SPOOL_SPACE \r\n   FROM TABLE(QSYS2.OBJECT_STATISTICS('*ALLUSR   ', 'LIB    ')) AS S1, \r\n   LATERAL \r\n   (SELECT * FROM TABLE(QSYS2.OBJECT_STATISTICS(CAST(S1.objname AS CHAR(10)), \r\n                                                'OUTQ   ')) AS b) AS S2, \r\n   LATERAL \r\n   (SELECT * FROM TABLE(QSYS2.OUTPUT_QUEUE_ENTRIES(S1.objname, \r\n                                                   S2.objname, '*NO')) \r\n    AS c) AS S3 \r\n   WHERE S1.OBJNAME NOT LIKE 'Q%' AND USER_NAME NOT LIKE 'Q%' \r\n   GROUP BY USER_NAME \r\n   ORDER BY TOTAL_SPOOL_SPACE DESC \r\n   LIMIT 10;"},
#  {'SERVICE_CATEGORY': 'SPOOL',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'OUTPUT_QUEUE_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'OUTQ_DTL',
#   'LATEST_DB2_GROUP_LEVEL': 23,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Find the output queue with the most files and examine the spool detail \r\n WITH BIGGEST_OUTQ(LIBNAME, QUEUENAME, FILECOUNT) \r\n AS (SELECT OUTPUT_QUEUE_LIBRARY_NAME, OUTPUT_QUEUE_NAME, NUMBER_OF_FILES \r\n    FROM QSYS2.OUTPUT_QUEUE_INFO \r\n    ORDER BY NUMBER_OF_FILES DESC \r\n    FETCH FIRST 1 ROWS ONLY) \r\n SELECT LIBNAME, QUEUENAME, X.* \r\n    FROM BIGGEST_OUTQ, TABLE(QSYS2.OUTPUT_QUEUE_ENTRIES(LIBNAME, QUEUENAME, '*NO')) X \r\n ORDER BY TOTAL_PAGES DESC;"},
#  {'SERVICE_CATEGORY': 'SYSTEM HEALTH',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SYSLIMTBL',
#   'SQL_OBJECT_TYPE': 'TABLE',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'SYSLIMTBL',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Are there any triggers created over the System Limits table \r\n SELECT * FROM QSYS2.SYSTRIGGERS \r\n  WHERE EVENT_OBJECT_SCHEMA = 'QSYS2' AND EVENT_OBJECT_TABLE = 'SYSLIMTBL';"},
#  {'SERVICE_CATEGORY': 'SYSTEM HEALTH',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SYSLIMITS',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'SYSLIMITS',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': '-- Description: Review the largest tables in System Limits \r\n WITH X AS (SELECT ROW_NUMBER() \r\n            OVER(PARTITION BY SYSTEM_SCHEMA_NAME, \r\n                 SYSTEM_OBJECT_NAME, SYSTEM_TABLE_MEMBER ORDER BY \r\n                CURRENT_VALUE DESC NULLS LAST) AS R, U.* \r\n            FROM QSYS2.SYSLIMITS U \r\n            WHERE LIMIT_ID = 15000) \r\n        SELECT LAST_CHANGE_TIMESTAMP, SYSTEM_SCHEMA_NAME, \r\n          SYSTEM_OBJECT_NAME, SYSTEM_TABLE_MEMBER, \r\n        CURRENT_VALUE \r\n        FROM X WHERE R = 1 \r\n        ORDER BY CURRENT_VALUE DESC;'},
#  {'SERVICE_CATEGORY': 'JOURNAL',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'JOURNAL_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'JRNINFO',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': '-- Description: Which remote journals fell the farthest behind this week? \r\n SELECT MAXIMUM_TIME_BEHIND, A.* FROM QSYS2.JOURNAL_INFO A WHERE \r\n        MAXIMUM_BEHIND_TIMESTAMP > CURRENT TIMESTAMP - 7 DAYS AND \r\n        MAXIMUM_TIME_BEHIND > 0 AND \r\n        MAXIMUM_TIME_BEHIND IS NOT NULL ORDER BY MAXIMUM_TIME_BEHIND DESC \r\n        FETCH FIRST 10 ROWS ONLY;'},
#  {'SERVICE_CATEGORY': 'JOURNAL',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'DISPLAY_JOURNAL',
#   'SQL_OBJECT_TYPE': 'TABLE FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 26,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Retrieve the Change Profile entries over that last day \r\n SELECT journal_code, journal_entry_type, object, object_type, X.* \r\n FROM TABLE ( \r\n QSYS2.Display_Journal( \r\n   'QSYS', 'QAUDJRN', \r\n   Starting_Timestamp => CURRENT DATE - 1 DAY, \r\n   Journal_Codes => 'T', \r\n   Journal_Entry_Types => 'CP' \r\n )) as x;"},
#  {'SERVICE_CATEGORY': 'JAVA',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'JVM_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'JVM_INFO',
#   'LATEST_DB2_GROUP_LEVEL': 25,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': '-- Description: Find the top 10 JVM jobs in Garbage Collection \r\n SELECT TOTAL_GC_TIME, GC_CYCLE_NUMBER,JAVA_THREAD_COUNT, A.* FROM QSYS2.JVM_INFO A \r\n ORDER BY TOTAL_GC_TIME DESC \r\n LIMIT 10;'},
#  {'SERVICE_CATEGORY': 'JAVA',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SET_JVM',
#   'SQL_OBJECT_TYPE': 'PROCEDURE',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Generate detailed diagnostics for a specific JVM \r\n CALL QSYS2.SET_JVM('962835/JAVA/QJVAEXEC', 'GENERATE_HEAP_DUMP');"},
#  {'SERVICE_CATEGORY': 'APPLICATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'QCMDEXC',
#   'SQL_OBJECT_TYPE': 'PROCEDURE',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Use QCMDEXC to execute CL command \r\n BEGIN \r\n   CALL QSYS2.QCMDEXC('DLYJOB DLY(5)'); \r\n END;"},
#  {'SERVICE_CATEGORY': 'APPLICATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SERVICES_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'SERV_INFO',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Review all the Security related IBM i Services \r\n SELECT * FROM QSYS2.SERVICES_INFO \r\n  WHERE SERVICE_CATEGORY = 'SECURITY';"},
#  {'SERVICE_CATEGORY': 'APPLICATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'ENVIRONMENT_VARIABLE_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'ENV_VARS',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Review all system level environment variables for this connection \r\n SELECT * \r\n   FROM QSYS2.ENVIRONMENT_VARIABLE_INFO \r\n   WHERE ENVIRONMENT_VARIABLE_TYPE = 'SYSTEM';"},
#  {'SERVICE_CATEGORY': 'APPLICATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SET_PASE_SHELL_INFO',
#   'SQL_OBJECT_TYPE': 'PROCEDURE',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Set the current user's shell to BASH shipped by 5733-OPS. \r\n CALL QSYS2.SET_PASE_SHELL_INFO('*CURRENT',  \r\n   '/QOpenSys/QIBM/ProdData/OPS/tools/bin/bash');"},
#  {'SERVICE_CATEGORY': 'MESSAGE HANDLING',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'MESSAGE_FILE_DATA',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'MSGF_DATA',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R3M0',
#   'EXAMPLE': "-- Description: Find any messages in the APPLIB/APPMSGS message file that  \r\n-- contain the word VALUE in upper case, lower case, or mixed case in the second  \r\n-- level message text. \r\nSELECT * FROM QSYS2.MESSAGE_FILE_DATA  \r\n  WHERE MESSAGE_FILE_LIBRARY = 'APPLIB' AND MESSAGE_FILE = 'APPMSGS' \r\n   AND UPPER(MESSAGE_SECOND_LEVEL_TEXT) LIKE '%VALUE%';"},
#  {'SERVICE_CATEGORY': 'COMMUNICATION',
#   'SERVICE_SCHEMA_NAME': 'SYSIBMADM',
#   'SERVICE_NAME': 'ENV_SYS_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'ENVSYSINFO',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Review the IBM i Operating system level \r\n     SELECT OS_NAME CONCAT ' ' CONCAT OS_VERSION CONCAT '.' \r\n     CONCAT OS_RELEASE FROM SYSIBMADM.ENV_SYS_INFO;"},
#  {'SERVICE_CATEGORY': 'COMMUNICATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'TCPIP_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'TCPIP_INFO',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': '-- Description: Retrieve the Host name, IBM i OS version and Client IP address \r\n SELECT LOCAL_HOST_NAME, HOST_VERSION, CLIENT_IP_ADDRESS FROM QSYS2.TCPIP_INFO;'},
#  {'SERVICE_CATEGORY': 'COMMUNICATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SET_SERVER_SBS_ROUTING',
#   'SQL_OBJECT_TYPE': 'PROCEDURE',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 4,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Use SERVER_SBS_ROUTING to reposition SCOTT to an alternate SBS \r\n CL: CRTSBSD SBSD(QGPL/ADHOCSBS) POOLS((1 *BASE)) TEXT('Ad hoc users SBS'); \r\n CL: CRTJOBQ QGPL/ADHOCJOBQ TEXT('Ad hoc users job queue'); \r\n CL: ADDJOBQE SBSD(QGPL/ADHOCSBS) JOBQ(QGPL/ADHOCJOBQ) MAXACT(100) SEQNBR(40); \r\n CL: CRTCLS CLS(QGPL/ADHOCCLS) RUNPTY(55) TIMESLICE(100) TEXT('Ad hoc class'); \r\n CL: ADDPJE SBSD(QGPL/ADHOCSBS) PGM(QSYS/QRWTSRVR) JOBD(QGPL/QDFTSVR) CLS(QGPL/ADHOCCLS); \r\n CL: ADDPJE SBSD(QGPL/ADHOCSBS) PGM(QSYS/QZDASOINIT) JOBD(QGPL/QDFTSVR) CLS(QGPL/ADHOCCLS); \r\n CL: STRSBS SBSD(QGPL/ADHOCSBS); \r\n CALL QSYS2.SET_SERVER_SBS_ROUTING('SCOTT','*ALL','ADHOCSBS');"},
#  {'SERVICE_CATEGORY': 'COMMUNICATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SERVER_SBS_ROUTING',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'SRVR_RTG',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': '-- Description: Review the existing configurations for users and groups \r\n SELECT * FROM QSYS2.SERVER_SBS_ROUTING;'},
#  {'SERVICE_CATEGORY': 'COMMUNICATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'NETSTAT_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'NS_INFO',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': '-- Description: Review the connections that are transferring the most data \r\n SELECT * FROM QSYS2.NETSTAT_INFO \r\n   ORDER BY BYTES_SENT_REMOTELY + BYTES_RECEIVED_LOCALLY DESC \r\n   LIMIT 10;'},
#  {'SERVICE_CATEGORY': 'COMMUNICATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'NETSTAT_INTERFACE_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'NS_INTER',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': '-- Description: Review the TCP/IP Interface details \r\n SELECT * FROM QSYS2.NETSTAT_INTERFACE_INFO;'},
#  {'SERVICE_CATEGORY': 'COMMUNICATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'NETSTAT_JOB_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'NS_JOB',
#   'LATEST_DB2_GROUP_LEVEL': 26,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Review the network jobs coming in from a unique IP address \r\n WITH NETSTAT_USER_JOBS (V_JOB_NAME,  V_LOCAL_PORT) AS ( \r\n SELECT JOB_NAME, LOCAL_PORT_NAME FROM QSYS2.NETSTAT_JOB_INFO \r\n  WHERE REMOTE_ADDRESS = '9.10.213.27' ) \r\n   SELECT AUTHORIZATION_NAME, V_JOB_NAME, V_LOCAL_PORT, \r\n          RUN_PRIORITY, CPU_TIME, SERVER_TYPE \r\n     FROM NETSTAT_USER_JOBS, \r\n          TABLE(QSYS2.ACTIVE_JOB_INFO()) B \r\n          WHERE JOB_NAME = V_JOB_NAME;"},
#  {'SERVICE_CATEGORY': 'COMMUNICATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'NETSTAT_ROUTE_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'NS_ROUTE',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': '-- Description: Review the details of all TCP/IP routes \r\n SELECT * FROM QSYS2.NETSTAT_ROUTE_INFO;'},
#  {'SERVICE_CATEGORY': 'DATABASE-APPLICATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'PARSE_STATEMENT',
#   'SQL_OBJECT_TYPE': 'TABLE FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 26,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R2M0',
#   'EXAMPLE': "-- Description: For schema TOYSTORE, find all tables referenced by \r\n-- static SQL statements by all application programs \r\n  WITH program_statements(naming_mode,\r\n                          dec_point,\r\n                          string_delim,\r\n                          stmt_text,\r\n                          system_program_name,\r\n                          program_type)\r\n    AS (SELECT a.naming,\r\n               a.decimal_point,\r\n               a.sql_string_delimiter,\r\n               b.statement_text,\r\n               a.system_program_name,\r\n               a.program_type\r\n          FROM qsys2.sysprogramstat a INNER JOIN\r\n               qsys2.sysprogramstmtstat b ON \r\n                     a.program_schema = b.program_schema AND\r\n                     a.program_name = b.program_name AND\r\n                     a.module_name = b.module_name\r\n          WHERE a.program_schema = 'TOYSTORE' AND\r\n                b.program_schema = 'TOYSTORE')\r\n    SELECT system_program_name,\r\n           program_type,\r\n           c.schema,\r\n           c.name,\r\n           stmt_text\r\n      FROM program_statements,\r\n         TABLE(qsys2.parse_statement(stmt_text, naming_mode,\r\n                                     dec_point, string_delim)) c\r\n      WHERE c.name_type = 'TABLE'\r\n      ORDER BY c.schema, c.name;"},
#  {'SERVICE_CATEGORY': 'DATABASE-APPLICATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'DELIMIT_NAME',
#   'SQL_OBJECT_TYPE': 'SCALAR FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': '-- Description: Delimit DB2 for i catalog names, as needed \r\n SELECT QSYS2.DELIMIT_NAME(TABLE_NAME) FROM QSYS2.SYSTABLES;'},
#  {'SERVICE_CATEGORY': 'DATABASE-APPLICATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'OVERRIDE_TABLE',
#   'SQL_OBJECT_TYPE': 'PROCEDURE',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Use a higher blocking factor for I/O \r\n CALL QSYS2.OVERRIDE_TABLE('TOYSTORE', 'ITEM_FACT', '*BUF128KB');"},
#  {'SERVICE_CATEGORY': 'DATABASE-APPLICATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'OVERRIDE_QAQQINI',
#   'SQL_OBJECT_TYPE': 'PROCEDURE',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 7,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Establish the temporary override for QAQQINI. \r\n -- The current QAQQINI values for the job will be used as the initial values. \r\n CALL QSYS2.OVERRIDE_QAQQINI(1, '', ''); \r\n    -- Description: Temporarily override the UDF timeout QAQQINI option. \r\n CALL QSYS2.OVERRIDE_QAQQINI(2, 'UDF_TIME_OUT', '*MAX');"},
#  {'SERVICE_CATEGORY': 'DATABASE-APPLICATION',
#   'SERVICE_SCHEMA_NAME': 'SYSPROC',
#   'SERVICE_NAME': 'WLM_SET_CLIENT_INFO',
#   'SQL_OBJECT_TYPE': 'PROCEDURE',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 23,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: Brand the client special register values for a connection \r\n CALL SYSPROC.WLM_SET_CLIENT_INFO('db2user','machine.rchland.ibm.com','auditor', \r\n    'Accounting department', 'MYPGM');"},
#  {'SERVICE_CATEGORY': 'DATABASE-PERFORMANCE',
#   'SERVICE_SCHEMA_NAME': 'SYSTOOLS',
#   'SERVICE_NAME': 'ACT_ON_INDEX_ADVICE',
#   'SQL_OBJECT_TYPE': 'PROCEDURE',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
#   'EXAMPLE': "-- Description: For schema TOYSTORE, find all instances of index advice where \r\n-- an MTI was used more than 1000 times and create permanent SQL indexes. \r\n CALL SYSTOOLS.ACT_ON_INDEX_ADVICE('TOYSTORE',NULL,NULL,1000,NULL);"},
#  {'SERVICE_CATEGORY': 'DATABASE-PERFORMANCE',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'DATABASE_MONITOR_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'DBMON_INFO',
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0',
#   'EXAMPLE': "-- Description: Retrieve the info for all the active PUBLIC monitors \r\n SELECT MONITOR_ID, MONITOR_LIBRARY, MONITOR_FILE \r\n   FROM QSYS2.DATABASE_MONITOR_INFO \r\n   WHERE MONITOR_STATUS = 'ACTIVE' AND \r\n         MONITOR_TYPE = 'PUBLIC';"},
#  {'SERVICE_CATEGORY': 'DATABASE-PERFORMANCE',
#   'SERVICE_SCHEMA_NAME': 'SYSTOOLS',
#   'SERVICE_NAME': 'HARVEST_INDEX_ADVICE',
#   'SQL_OBJECT_TYPE': 'PROCEDURE',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': None,
#   'INITIAL_DB2_GROUP_LEVEL': None,
#   'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0',
# ...
#  {'SERVICE_CATEGORY': 'DATABASE-APPLICATION',
#   'SERVICE_SCHEMA_NAME': 'SYSIBMADM',
#   'SERVICE_NAME': 'SELFCODES',
#   'SQL_OBJECT_TYPE': 'GLOBAL VARIABLE',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 23,
#   'INITIAL_DB2_GROUP_LEVEL': 23,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': "-- Description: Configure SELF to capture detail for all jobs started in the future, \r\n     -- for any SQL statements that fail with SQLCODE = -913 or SQLCODE = -204. \r\n  CREATE OR REPLACE VARIABLE SYSIBMADM.SELFCODES  \r\n      VARCHAR(256) DEFAULT '-913, -204';"},
#  {'SERVICE_CATEGORY': 'DATABASE-UTILITY',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SYSMEMBERSTAT',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'SYSMSTAT',
#   'LATEST_DB2_GROUP_LEVEL': 28,
#   'INITIAL_DB2_GROUP_LEVEL': 28,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': "-- Description: Examine some statistical information for all members of all files in APPLIB1. \r\n SELECT TABLE_NAME, NUMBER_ROWS, NUMBER_DELETED_ROWS, LAST_USED_TIMESTAMP \r\n  FROM QSYS2.SYSMEMBERSTAT \r\n  WHERE TABLE_SCHEMA = 'APPLIB1';"},
#  {'SERVICE_CATEGORY': 'IFS',
#   'SERVICE_SCHEMA_NAME': 'SYSTOOLS',
#   'SERVICE_NAME': 'IFS_UNLINK',
#   'SQL_OBJECT_TYPE': 'SCALAR FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 28,
#   'INITIAL_DB2_GROUP_LEVEL': 28,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': "-- Description: Unlink file /usr/reportdata.txt. \r\n   VALUES SYSTOOLS.IFS_UNLINK(PATH_NAME => '/usr/reportdata.txt');"},
#  {'SERVICE_CATEGORY': 'IFS',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'COMPARE_IFS',
#   'SQL_OBJECT_TYPE': 'TABLE FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 28,
#   'INITIAL_DB2_GROUP_LEVEL': 28,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': "-- Description: Compare the names for all objects in two subtrees. Compare recursively  \r\n        -- through the entire set of subdirectories. \r\n   SELECT * FROM TABLE(QSYS2.COMPARE_IFS(  \r\n                                       START_PATH_NAME1    => '/usr/files.dir',  \r\n                                       START_PATH_NAME2    => '/usrbackup/files.dir', \r\n                                       SUBTREE_DIRECTORIES => 'YES', \r\n                                       COMPARE_ATTRIBUTES  => 'NAMES' \r\n                              ));"},
#  {'SERVICE_CATEGORY': 'SECURITY',
#   'SERVICE_SCHEMA_NAME': 'SYSTOOLS',
#   'SERVICE_NAME': 'ADD_VALIDATION_LIST_ENTRY',
#   'SQL_OBJECT_TYPE': 'SCALAR FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': "-- Description: Add an authentication entry for a user of an external interface. \r\n     --   Use a global variable so the password is not visible in the function invocation. \r\n     --   for all user profiles on the system. \r\n     CREATE VARIABLE MYLIB.VLDL_PW VARCHAR(100); \r\n \r\nSET MYLIB.VLDL_PW = 'password for my user access'; \r\n \r\nVALUES SYSTOOLS.ADD_VALIDATION_LIST_ENTRY( \r\n                             VALIDATION_LIST_LIBRARY => 'APPLIB',  \r\n                             VALIDATION_LIST_NAME    => 'APPVLDL', \r\n                             VALIDATION_USER         => 'my application user name', \r\n                             PASSWORD                => MYLIB.VLDL_PW);"},
#  {'SERVICE_CATEGORY': 'SECURITY',
#   'SERVICE_SCHEMA_NAME': 'SYSTOOLS',
#   'SERVICE_NAME': 'CHANGE_VALIDATION_LIST_ENTRY',
#   'SQL_OBJECT_TYPE': 'SCALAR FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': "-- Description: Change the password for an existing authentication entry.\r\n     CREATE VARIABLE MYLIB.VLDL_PW VARCHAR(100); \r\n \r\nSET MYLIB.VLDL_PW = 'my new password'; \r\n \r\nVALUES SYSTOOLS.CHANGE_VALIDATION_LIST_ENTRY( \r\n                             VALIDATION_LIST_LIBRARY => 'APPLIB',  \r\n                             VALIDATION_LIST_NAME    => 'APPVLDL', \r\n                             VALIDATION_USER         => 'my application user name', \r\n                             PASSWORD                => MYLIB.VLDL_PW);"},
#  {'SERVICE_CATEGORY': 'SECURITY',
#   'SERVICE_SCHEMA_NAME': 'SYSTOOLS',
#   'SERVICE_NAME': 'REMOVE_VALIDATION_LIST_ENTRY',
#   'SQL_OBJECT_TYPE': 'SCALAR FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': "-- Description: Remove an authentication entry for a specific user of an external interface.\r\nVALUES SYSTOOLS.REMOVE_VALIDATION_LIST_ENTRY( \r\n                             VALIDATION_LIST_LIBRARY => 'APPLIB',  \r\n                             VALIDATION_LIST_NAME    => 'APPVLDL', \r\n                             VALIDATION_USER         => 'my application user name');"},
#  {'SERVICE_CATEGORY': 'WORK MANAGEMENT',
#   'SERVICE_SCHEMA_NAME': 'SYSTOOLS',
#   'SERVICE_NAME': 'END_JOBS',
#   'SQL_OBJECT_TYPE': 'PROCEDURE',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': "-- Description: Find and end all the active jobs with a job name of BATCHTEST. \r\n    -- For every job, end using the controlled option, save any spooled files, and do \r\n    -- not generate a job log. \r\n  CALL SYSTOOLS.END_JOBS(JOB_NAME_FILTER          => 'BATCHTEST',  \r\n                       END_OPTION               => 'CONTROLLED', \r\n                       DELETE_SPOOLED_FILES     => 'NO', \r\n                       MAXIMUM_JOBLOG_ENTRIES   => 0);"},
#  {'SERVICE_CATEGORY': 'WORK MANAGEMENT',
#   'SERVICE_SCHEMA_NAME': 'SYSTOOLS',
#   'SERVICE_NAME': 'POWER_SCHEDULE_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'POWER_INFO',
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': '-- Description: List all the scheduled power events. \r\n  SELECT * FROM SYSTOOLS.POWER_SCHEDULE_INFO;'},
#  {'SERVICE_CATEGORY': 'CONFIGURATION',
#   'SERVICE_SCHEMA_NAME': 'SYSTOOLS',
#   'SERVICE_NAME': 'CONFIGURATION_STATUS',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'CONFIG_STS',
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': "-- Description: List the status of all controllers. \r\n   SELECT OBJECT_NAME, OBJECT_ATTRIBUTE, STATUS_DESCRIPTION, TEXT_DESCRIPTION  \r\n  FROM SYSTOOLS.CONFIGURATION_STATUS \r\n  WHERE OBJECT_TYPE = '*CTLD';"},
#  {'SERVICE_CATEGORY': 'CONFIGURATION',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'SERVICE_TOOLS_SERVER_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'STS_INFO',
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': '-- Description: Show information about the service tools server configuration. \r\n   SELECT * FROM QSYS2.SERVICE_TOOLS_SERVER_INFO;'},
#  {'SERVICE_CATEGORY': 'JOURNAL',
#   'SERVICE_SCHEMA_NAME': 'SYSTOOLS',
#   'SERVICE_NAME': 'AUDIT_JOURNAL_VP',
#   'SQL_OBJECT_TYPE': 'TABLE FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': '-- Description: Review the Network Server password failures, by day and by server name. \r\n  SELECT DATE(ENTRY_TIMESTAMP) AS "DATE", SERVER_NAME,  \r\n       COUNT(*) AS NETWORK_SERVER_PASSWORD_ERROR_COUNT \r\n  FROM TABLE (  \r\n      SYSTOOLS.AUDIT_JOURNAL_VP(STARTING_TIMESTAMP => CURRENT TIMESTAMP - 7 DAYS))  \r\n  GROUP BY DATE(ENTRY_TIMESTAMP), SERVER_NAME \r\n  ORDER BY "DATE", NETWORK_SERVER_PASSWORD_ERROR_COUNT DESC;'},
#  {'SERVICE_CATEGORY': 'MIGRATE WHILE ACTIVE',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'CHANGE_MIGRATION_MANAGER',
#   'SQL_OBJECT_TYPE': 'PROCEDURE',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': "-- Description: Enable initial configuration of IBM i Migrate While Active                         \r\n-- and set the current node as the source node.                                                     \r\n    CALL QSYS2.CHANGE_MIGRATION_MANAGER(ACTION => 'SETUP');"},
#  {'SERVICE_CATEGORY': 'MIGRATE WHILE ACTIVE',
#   'SERVICE_SCHEMA_NAME': 'SYSIBMADM',
#   'SERVICE_NAME': 'DATA_COMPRESSION_FACTOR',
#   'SQL_OBJECT_TYPE': 'TABLE',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'COMP_FACT',
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': '-- Description: List the compression factors used for the different types                          \r\n-- of compression in IBM i Migrate While Active.                                                    \r\n    SELECT * FROM SYSIBMADM.DATA_COMPRESSION_FACTOR;'},
#  {'SERVICE_CATEGORY': 'MIGRATE WHILE ACTIVE',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'ESTIMATE_FINAL_SYNCHRONIZATION_TIME',
#   'SQL_OBJECT_TYPE': 'TABLE FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': '-- Description: Estimate the length of time required to complete                                   \r\n-- synchronization of objects in a IBM i Migrate While                                              \r\n-- Active environment to the copy node.                                                             \r\n    SELECT * FROM TABLE(QSYS2.ESTIMATE_FINAL_SYNCHRONIZATION_TIME());'},
#  {'SERVICE_CATEGORY': 'MIGRATE WHILE ACTIVE',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'IFS_MIGRATION_LIST',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'MIG_ITL',
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': "-- Description: Examine the integrated file system objects that are                                \r\n-- currently attempting migration to the copy node.                                                 \r\n    SELECT PATH_NAME, OBJECT_TYPE                                                                   \r\n      FROM QSYS2.IFS_MIGRATION_LIST                                                                 \r\n      WHERE TRACKING_STATE = 'MIGRATING'                                                          \r\n      ORDER BY PATH_NAME, OBJECT_TYPE;"},
#  {'SERVICE_CATEGORY': 'MIGRATE WHILE ACTIVE',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'LIBRARY_MIGRATION_LIST',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'MIG_LTL',
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': "-- Description: Examine the eligible library-based objects that need                               \r\n-- to be migrated to the copy node.                                                                 \r\n    SELECT LIBRARY_NAME, OBJECT_NAME, OBJECT_SIZE                                                   \r\n      FROM QSYS2.LIBRARY_MIGRATION_LIST                                                             \r\n      WHERE TRACKING_STATE  <> 'MIGRATING'                                                        \r\n      ORDER BY LIBRARY_NAME, OBJECT_NAME;"},
#  {'SERVICE_CATEGORY': 'MIGRATE WHILE ACTIVE',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'MIGRATED_IFS',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'MIG_IFS',
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': '-- Description: Review a list of the integrated file system objects that                           \r\n-- have successfully completed migration to the copy node within                                    \r\n-- the last hour.                                                                                   \r\n    SELECT * FROM QSYS2.MIGRATED_IFS                                                                \r\n      WHERE MIGRATION_END_TIME > CURRENT TIMESTAMP - 1 HOUR                                         \r\n      ORDER BY MIGRATION_END_TIME DESC;'},
#  {'SERVICE_CATEGORY': 'MIGRATE WHILE ACTIVE',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'MIGRATED_LIBRARY',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'MIG_LIB',
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': "-- Description: Review a list of library-based objects in TOYSTORE                                 \r\n-- that have successfully completed migration to the copy node                                      \r\n-- within the last hour.                                                                            \r\n    SELECT * FROM QSYS2.MIGRATED_LIBRARY                                                            \r\n      WHERE MIGRATION_END_TIME > CURRENT TIMESTAMP - 1 HOUR AND                                     \r\n            (LIBRARY_NAME = 'TOYSTORE' OR                                                         \r\n             (LIBRARY_NAME = 'QSYS' AND                                                           \r\n              OBJECT_NAME = 'TOYSTORE' AND                                                        \r\n              OBJECT_TYPE = '*LIB'))                                                              \r\n      ORDER BY MIGRATION_END_TIME DESC;"},
#  {'SERVICE_CATEGORY': 'MIGRATE WHILE ACTIVE',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'MIGRATION_MANAGER_INFO',
#   'SQL_OBJECT_TYPE': 'VIEW',
#   'OBJECT_TYPE': '*FILE',
#   'SYSTEM_OBJECT_NAME': 'MIG_MANAGE',
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': '-- Description: Examine information about the IBM i Migrate While                                  \r\n-- Active environment.                                                                              \r\n    SELECT * FROM QSYS2.MIGRATION_MANAGER_INFO;'},
#  {'SERVICE_CATEGORY': 'MIGRATE WHILE ACTIVE',
#   'SERVICE_SCHEMA_NAME': 'QSYS2',
#   'SERVICE_NAME': 'MIGRATION_NETWORK_BANDWIDTH',
#   'SQL_OBJECT_TYPE': 'TABLE FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': '-- Description: Check the bandwidth to the copy node in a IBM i                                    \r\n-- Migrate While Active environment. Take the measurement 5                                         \r\n-- times for calculating the values.                                                                \r\n    SELECT * FROM TABLE(QSYS2.MIGRATION_NETWORK_BANDWIDTH(5));'},
#  {'SERVICE_CATEGORY': 'IFS',
#   'SERVICE_SCHEMA_NAME': 'SYSTOOLS',
#   'SERVICE_NAME': 'IFS_ACCESS',
#   'SQL_OBJECT_TYPE': 'SCALAR FUNCTION',
#   'OBJECT_TYPE': None,
#   'SYSTEM_OBJECT_NAME': None,
#   'LATEST_DB2_GROUP_LEVEL': 29,
#   'INITIAL_DB2_GROUP_LEVEL': 29,
#   'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0',
#   'EXAMPLE': "-- Description: Determine whether the invoker of the function has read access to \r\n        --   /usr/reportdata.txt. \r\n   VALUES SYSTOOLS.IFS_ACCESS(PATH_NAME => '/usr/reportdata.txt',  \r\n                           READ => 'YES');"}]

# %%
type(services[0])
# Out:
# dict

# %%
from collections import Counter
service_catagories = [item['SERVICE_CATEGORY'] for item in services]
counter = Counter(service_catagories)
dict(counter)
# Out:
# {'PTF': 8,
#  'SECURITY': 22,
#  'WORK MANAGEMENT': 35,
#  'MESSAGE HANDLING': 8,
#  'LIBRARIAN': 5,
#  'STORAGE': 17,
#  'BACKUP AND RECOVERY': 5,
#  'PRODUCT': 4,
#  'SPOOL': 9,
#  'SYSTEM HEALTH': 4,
#  'JOURNAL': 50,
#  'JAVA': 3,
#  'APPLICATION': 45,
#  'COMMUNICATION': 21,
#  'DATABASE-APPLICATION': 9,
#  'DATABASE-PERFORMANCE': 10,
#  'DATABASE-PLAN CACHE': 14,
#  'DATABASE-UTILITY': 18,
#  'MIRROR-COMMUNICATION': 8,
#  'MIRROR-PRODUCT': 27,
#  'MIRROR-REPLICATION': 8,
#  'MIRROR-RESYNCHRONIZATION': 5,
#  'MIRROR-SERVICEABILITY': 7,
#  'IFS': 12,
#  'MIRROR-RECLONE': 6,
#  'PERFORMANCE': 1,
#  'CONFIGURATION': 4,
#  'MIGRATE WHILE ACTIVE': 9}

# %%
from collections import Counter
sql_object_types = [item['SQL_OBJECT_TYPE'] for item in services]
counter = Counter(sql_object_types)
counter
# Out:
# Counter({'VIEW': 129,
#          'TABLE FUNCTION': 114,
#          'PROCEDURE': 103,
#          'SCALAR FUNCTION': 23,
#          'TABLE': 4,
#          'GLOBAL VARIABLE': 1})

# %%
from typing import Optional
from pydantic import BaseModel, Field

class ServiceInfo(BaseModel):
    SERVICE_CATEGORY: str
    SERVICE_SCHEMA_NAME: str
    SERVICE_NAME: str
    SQL_OBJECT_TYPE: str
    OBJECT_TYPE: Optional[str]
    SYSTEM_OBJECT_NAME: Optional[str]
    LATEST_DB2_GROUP_LEVEL: Optional[int] = None
    INITIAL_DB2_GROUP_LEVEL: Optional[int] = None
    EARLIEST_POSSIBLE_RELEASE: Optional[str] = None
    EXAMPLE: Optional[str] = None
    
    model_config = {
        "from_attributes": True  # For ORM compatibility
    }

# %%
service_collection = {}
for item in services:
    name = item['SERVICE_NAME']
    service_collection[name] = ServiceInfo(**item)
    
service_collection
# Out:
# {'PTF_INFO': ServiceInfo(SERVICE_CATEGORY='PTF', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='PTF_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='PTF_INFO', LATEST_DB2_GROUP_LEVEL=26, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Will an IPL impact PTF state? \r\n  SELECT PTF_IDENTIFIER, PTF_IPL_ACTION, A.* \r\n  FROM QSYS2.PTF_INFO A \r\n       WHERE PTF_IPL_ACTION <> 'NONE';"),
#  'GROUP_PTF_INFO': ServiceInfo(SERVICE_CATEGORY='PTF', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='GROUP_PTF_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='GRPPTFINFO', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: What is the most recently installed CUM? \r\n  SELECT MAX(PTF_GROUP_LEVEL) AS CUM_LEVEL FROM \r\n  QSYS2.GROUP_PTF_INFO P, SYSIBMADM.ENV_SYS_INFO V \r\n  WHERE PTF_GROUP_NAME = 'SF99' CONCAT V.OS_VERSION CONCAT V.OS_RELEASE CONCAT '0' \r\n  AND PTF_GROUP_STATUS = 'INSTALLED';"),
#  'GROUP_PTF_CURRENCY': ServiceInfo(SERVICE_CATEGORY='PTF', SERVICE_SCHEMA_NAME='SYSTOOLS', SERVICE_NAME='GROUP_PTF_CURRENCY', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='GRPPTFCUR', LATEST_DB2_GROUP_LEVEL=10, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Determine whether the PTF Groups are current \r\n  SELECT * FROM SYSTOOLS.GROUP_PTF_CURRENCY, SYSIBMADM.ENV_SYS_INFO V  \r\n  WHERE PTF_GROUP_RELEASE = 'R' CONCAT V.OS_VERSION CONCAT V.OS_RELEASE CONCAT '0' \r\n  ORDER BY PTF_GROUP_LEVEL_AVAILABLE - PTF_GROUP_LEVEL_INSTALLED DESC;"),
#  'GROUP_PTF_DETAILS': ServiceInfo(SERVICE_CATEGORY='PTF', SERVICE_SCHEMA_NAME='SYSTOOLS', SERVICE_NAME='GROUP_PTF_DETAILS', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='GRPPTFDTL', LATEST_DB2_GROUP_LEVEL=10, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Review all unapplied PTFs contained within PTF Groups installed \r\n-- on the partition against the live PTF detail available from IBM \r\n  SELECT * FROM SYSTOOLS.GROUP_PTF_DETAILS \r\n  WHERE PTF_STATUS <> 'PTF APPLIED' \r\n  ORDER BY PTF_GROUP_NAME;"),
#  'USER_INFO': ServiceInfo(SERVICE_CATEGORY='SECURITY', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='USER_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='USER_INFO', LATEST_DB2_GROUP_LEVEL=13, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Which users are at risk of becoming disabled due to lack of use? \r\n SELECT * FROM QSYS2.USER_INFO \r\n WHERE STATUS = '*ENABLED' AND LAST_USED_TIMESTAMP IS NOT NULL \r\n ORDER BY LAST_USED_TIMESTAMP ASC \r\n FETCH FIRST 20 ROWS ONLY;"),
#  'FUNCTION_INFO': ServiceInfo(SERVICE_CATEGORY='SECURITY', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='FUNCTION_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='FCN_INFO', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE='-- Description: Which function usage IDs exist \r\n SELECT * FROM QSYS2.FUNCTION_INFO ORDER BY FUNCTION_ID;'),
#  'FUNCTION_USAGE': ServiceInfo(SERVICE_CATEGORY='SECURITY', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='FUNCTION_USAGE', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='FCN_USAGE', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Which Database function usage has been granted or revoked? \r\n   SELECT * FROM QSYS2.FUNCTION_USAGE \r\n   WHERE FUNCTION_ID LIKE 'QIBM_DB_%' ORDER BY FUNCTION_ID, USER_NAME;"),
#  'GROUP_PROFILE_ENTRIES': ServiceInfo(SERVICE_CATEGORY='SECURITY', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='GROUP_PROFILE_ENTRIES', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='GROUPLIST', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Review *ALLOBJ users \r\n SELECT AUTHORIZATION_NAME, STATUS, NO_PASSWORD_INDICATOR, PREVIOUS_SIGNON, \r\n TEXT_DESCRIPTION \r\n FROM QSYS2.USER_INFO \r\n WHERE SPECIAL_AUTHORITIES LIKE '%*ALLOBJ%' \r\n OR AUTHORIZATION_NAME IN ( \r\n SELECT USER_PROFILE_NAME \r\n FROM QSYS2.GROUP_PROFILE_ENTRIES \r\n WHERE GROUP_PROFILE_NAME IN ( \r\n SELECT AUTHORIZATION_NAME \r\n FROM QSYS2.USER_INFO \r\n WHERE SPECIAL_AUTHORITIES like '%*ALLOBJ%')) \r\n ORDER BY AUTHORIZATION_NAME;"),
#  'SQL_CHECK_AUTHORITY': ServiceInfo(SERVICE_CATEGORY='SECURITY', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SQL_CHECK_AUTHORITY', SQL_OBJECT_TYPE='SCALAR FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Does this user have authority to query this file \r\n   VALUES ( CASE WHEN QSYS2.SQL_CHECK_AUTHORITY('QSYS2','SYSLIMITS') = 1 \r\n   THEN 'I can query QSYS2/SYSLIMITS' ELSE 'No query access for me' END );"),
#  'SET_COLUMN_ATTRIBUTE': ServiceInfo(SERVICE_CATEGORY='SECURITY', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SET_COLUMN_ATTRIBUTE', SQL_OBJECT_TYPE='PROCEDURE', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Secure salary column values in the SQL Performance Center \r\n     CALL SYSPROC.SET_COLUMN_ATTRIBUTE('TOYSTORE', 'EMPLOYEE', 'SALARY', \r\n     'SECURE YES'); \r\n-- Review configuration of SECURE column values for DBE & Performance analysts \r\n SELECT COLUMN_NAME,SECURE \r\n    FROM QSYS2.SYSCOLUMNS2 \r\n    WHERE SYSTEM_TABLE_SCHEMA = 'TOYSTORE' AND SYSTEM_TABLE_NAME = 'EMPLOYEE';"),
#  'DRDA_AUTHENTICATION_ENTRY_INFO': ServiceInfo(SERVICE_CATEGORY='SECURITY', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='DRDA_AUTHENTICATION_ENTRY_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='DRDA_AUTHE', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE='-- Description: Retrieve the DRDA Authentication Entry info \r\n SELECT * FROM QSYS2.DRDA_AUTHENTICATION_ENTRY_INFO \r\n  ORDER BY AUTHORIZATION_NAME, SERVER_NAME;'),
#  'AUTHORITY_COLLECTION': ServiceInfo(SERVICE_CATEGORY='SECURITY', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='AUTHORITY_COLLECTION', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='AUTH_COL', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R3M0', EXAMPLE="-- Description: Review authority failures, contrasting the authority required versus the current authority \r\nSELECT AUTHORIZATION_NAME, OBJECT_NAME, SYSTEM_OBJECT_TYPE, \r\nREQUIRED_AUTHORITY, DETAILED_REQUIRED_AUTHORITY, CURRENT_AUTHORITY, A.* \r\n FROM QSYS2.AUTHORITY_COLLECTION A \r\n WHERE AUTHORITY_CHECK_SUCCESSFUL = '0' ORDER BY 1;"),
#  'OBJECT_PRIVILEGES': ServiceInfo(SERVICE_CATEGORY='SECURITY', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='OBJECT_PRIVILEGES', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='OBJ_PRIV', LATEST_DB2_GROUP_LEVEL=7, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R2M0', EXAMPLE="-- Description: Review *PUBLIC authority for user libraries \r\nSELECT OBJECT_AUTHORITY AS LIBRARY_AUTHORITY, COUNT(*) AS COUNT \r\n FROM TABLE(QSYS2.OBJECT_STATISTICS('*ALLUSR', 'LIB')) L, \r\n LATERAL (SELECT OBJECT_AUTHORITY \r\n   FROM QSYS2.OBJECT_PRIVILEGES \r\n   WHERE NAME = L.OBJNAME AND \r\n   OBJECT_SCHEMA = 'QSYS' AND \r\n   OBJECT_TYPE = '*LIB' AND \r\n   USER_NAME = '*PUBLIC') p \r\n GROUP BY OBJECT_AUTHORITY \r\n ORDER BY 2 DESC;"),
#  'AUTHORIZATION_LIST_INFO': ServiceInfo(SERVICE_CATEGORY='SECURITY', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='AUTHORIZATION_LIST_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='AUTHL_INFO', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R2M0', EXAMPLE="-- Description: Find objects not included in the authorization list for \r\n  --  Schema = TOYSTORE  Authorization List = TOYSTOREAL \r\nWITH ALLOBJS(OBJNAME, OBJDEFINER, OBJTYPE, SQL_OBJECT_TYPE) AS ( \r\nSELECT OBJNAME, OBJDEFINER, OBJTYPE, SQL_OBJECT_TYPE   \r\n FROM TABLE(QSYS2.OBJECT_STATISTICS('TOYSTORE', 'ALL')) O), \r\n AUTLOBJS(OBJNAME) AS ( \r\nSELECT SYSTEM_OBJECT_NAME  \r\n FROM QSYS2.AUTHORIZATION_LIST_INFO b  \r\n   WHERE B.AUTHORIZATION_LIST = 'TOYSTOREAL' \r\n) SELECT A.OBJNAME, OBJDEFINER, OBJTYPE, SQL_OBJECT_TYPE \r\n  FROM ALLOBJS A LEFT EXCEPTION JOIN AUTLOBJS B  \r\n  ON A.OBJNAME = B.OBJNAME;"),
#  'AUTHORIZATION_LIST_USER_INFO': ServiceInfo(SERVICE_CATEGORY='SECURITY', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='AUTHORIZATION_LIST_USER_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='AUTL_USERS', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R2M0', EXAMPLE="-- Description: Review JOEUSER's object access via authorization lists \r\nSELECT AUTHORIZATION_LIST, object_authority  \r\n   FROM QSYS2.AUTHORIZATION_LIST_USER_INFO B \r\n   WHERE AUTHORIZATION_NAME = 'JOEUSER' OR \r\n         (AUTHORIZATION_NAME = '*PUBLIC' AND \r\n         OBJECT_AUTHORITY <> '*EXCLUDE') \r\n   ORDER BY 1;"),
#  'SYSTEM_VALUE_INFO': ServiceInfo(SERVICE_CATEGORY='WORK MANAGEMENT', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SYSTEM_VALUE_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='SYSVALINFO', LATEST_DB2_GROUP_LEVEL=26, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE='-- Description: Compare System Values across two partitions \r\n DECLARE GLOBAL TEMPORARY TABLE SESSION.Remote_System_Values \r\n ( SYSTEM_VALUE_NAME,CURRENT_NUMERIC_VALUE,CURRENT_CHARACTER_VALUE ) \r\n AS (SELECT * FROM REMOTEPART.QSYS2.SYSTEM_VALUE_INFO) WITH DATA \r\n WITH REPLACE; \r\n-- Use exception join to reveal any differences \r\n  SELECT \'REMOTEPART\' AS "System Name", A.SYSTEM_VALUE_NAME, \r\n  A.CURRENT_NUMERIC_VALUE,A.CURRENT_CHARACTER_VALUE FROM QSYS2.SYSTEM_VALUE_INFO A \r\n LEFT EXCEPTION JOIN SESSION.Remote_System_Values B \r\n ON A.SYSTEM_VALUE_NAME = B.SYSTEM_VALUE_NAME AND \r\n    A.CURRENT_NUMERIC_VALUE IS NOT DISTINCT FROM B.CURRENT_NUMERIC_VALUE AND \r\n    A.CURRENT_CHARACTER_VALUE IS NOT DISTINCT FROM B.CURRENT_CHARACTER_VALUE \r\n UNION ALL \r\n  SELECT \'LOCALPART\' AS "System Name", B.SYSTEM_VALUE_NAME, \r\n  B.CURRENT_NUMERIC_VALUE, \r\n  B.CURRENT_CHARACTER_VALUE FROM QSYS2.SYSTEM_VALUE_INFO A \r\n RIGHT EXCEPTION JOIN SESSION.Remote_System_Values B \r\n ON A.SYSTEM_VALUE_NAME = B.SYSTEM_VALUE_NAME AND \r\n    A.CURRENT_NUMERIC_VALUE IS NOT DISTINCT FROM B.CURRENT_NUMERIC_VALUE AND \r\n    A.CURRENT_CHARACTER_VALUE IS NOT DISTINCT FROM B.CURRENT_CHARACTER_VALUE \r\n ORDER BY SYSTEM_VALUE_NAME;'),
#  'GET_JOB_INFO': ServiceInfo(SERVICE_CATEGORY='WORK MANAGEMENT', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='GET_JOB_INFO', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Find the jobs with SQL statements executing \r\n WITH ACTIVE_USER_JOBS (Q_JOB_NAME, CPU_TIME, RUN_PRIORITY) AS ( \r\n SELECT \r\n  JOB_NAME, CPU_TIME, RUN_PRIORITY \r\n  FROM TABLE (ACTIVE_JOB_INFO()) x \r\n WHERE JOB_TYPE <> 'SYS' \r\n ) SELECT Q_JOB_NAME, CPU_TIME, RUN_PRIORITY, V_SQL_STATEMENT_TEXT, \r\n ABS( CURRENT TIMESTAMP - V_SQL_STMT_START_TIMESTAMP ) AS SQL_STMT_DURATION, B.* \r\n FROM ACTIVE_USER_JOBS, TABLE(QSYS2.GET_JOB_INFO(Q_JOB_NAME)) B \r\n WHERE V_SQL_STMT_STATUS = 'ACTIVE' \r\n ORDER BY SQL_STMT_DURATION DESC;"),
#  'ACTIVE_JOB_INFO': ServiceInfo(SERVICE_CATEGORY='WORK MANAGEMENT', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='ACTIVE_JOB_INFO', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Find the top 10 consumers of CPU in the QUSRWRK and QSYSWRK subsystems \r\n select CPU_TIME, A.* FROM \r\n table(QSYS2.ACTIVE_JOB_INFO(SUBSYSTEM_LIST_FILTER => 'QUSRWRK,QSYSWRK')) A \r\n ORDER BY CPU_TIME DESC \r\n LIMIT 10;"),
#  'SCHEDULED_JOB_INFO': ServiceInfo(SERVICE_CATEGORY='WORK MANAGEMENT', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SCHEDULED_JOB_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='SCHED_JOB', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Review the job scheduled entries which are no longer in effect \r\n   SELECT * FROM QSYS2.SCHEDULED_JOB_INFO WHERE \r\n   STATUS IN ('HELD', 'SAVED') ORDER BY SCHEDULED_BY;"),
#  'MEMORY_POOL': ServiceInfo(SERVICE_CATEGORY='WORK MANAGEMENT', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='MEMORY_POOL', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Return all available pool information. \r\n SELECT * FROM TABLE(QSYS2.MEMORY_POOL('YES')) X;"),
#  'MEMORY_POOL_INFO': ServiceInfo(SERVICE_CATEGORY='WORK MANAGEMENT', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='MEMORY_POOL_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='POOL_INFO', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE='-- Description: Review the details of all active memory pools. \r\n SELECT * FROM QSYS2.MEMORY_POOL_INFO;'),
#  'SYSTEM_STATUS': ServiceInfo(SERVICE_CATEGORY='WORK MANAGEMENT', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SYSTEM_STATUS', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Review elapsed system status over a 60 second window \r\n DECLARE GLOBAL TEMPORARY TABLE SESSION.SYSTEM_STATUS_REFERENCE_POINT AS ( \r\n  SELECT TOTAL_JOBS_IN_SYSTEM, ACTIVE_JOBS_IN_SYSTEM, ELAPSED_CPU_USED, \r\n         ELAPSED_CPU_SHARED, ELAPSED_CPU_UNCAPPED_CAPACITY \r\n    FROM TABLE(QSYS2.SYSTEM_STATUS('YES')) A \r\n ) WITH DATA WITH REPLACE; \r\n CALL QSYS2.QCMDEXC('DLYJOB DLY(60)'); \r\n SELECT B.TOTAL_JOBS_IN_SYSTEM - A.TOTAL_JOBS_IN_SYSTEM \r\n   AS DELTA_TOTAL_JOBS_IN_SYSTEM, \r\n B.ACTIVE_JOBS_IN_SYSTEM - A.ACTIVE_JOBS_IN_SYSTEM \r\n AS DELTA_ACTIVE_JOBS_IN_SYSTEM, \r\n        B.ELAPSED_TIME, \r\n B.ELAPSED_CPU_USED - A.ELAPSED_CPU_USED \r\n AS DELTA_ELAPSED_CPU_USED, \r\n B.ELAPSED_CPU_SHARED - A.ELAPSED_CPU_SHARED \r\n AS DELTA_ELAPSED_CPU_SHARED, \r\n B.ELAPSED_CPU_UNCAPPED_CAPACITY - A.ELAPSED_CPU_UNCAPPED_CAPACITY \r\n AS DELTA_ELAPSED_CPU_UNCAPPED_CAPACITY \r\n FROM SESSION.SYSTEM_STATUS_REFERENCE_POINT A, \r\n TABLE(QSYS2.SYSTEM_STATUS('NO')) B;"),
#  'SYSTEM_STATUS_INFO': ServiceInfo(SERVICE_CATEGORY='WORK MANAGEMENT', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SYSTEM_STATUS_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='SYS_STATUS', LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE='-- Description: Review current system status, including the job max percentage \r\n SELECT TOTAL_JOBS_IN_SYSTEM, MAXIMUM_JOBS_IN_SYSTEM, \r\n DECIMAL((DECIMAL(TOTAL_JOBS_IN_SYSTEM) / \r\n          DECIMAL(MAXIMUM_JOBS_IN_SYSTEM)), 11, 3) * 100 AS JOB_MAX_PERCENT, A.* \r\n    FROM QSYS2.SYSTEM_STATUS_INFO A;'),
#  'OBJECT_LOCK_INFO': ServiceInfo(SERVICE_CATEGORY='WORK MANAGEMENT', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='OBJECT_LOCK_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='OBJ_LOCK', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Find any object locks over the TOYSTORE/SALES table \r\n WITH LOCK_CONFLICT_TABLE (object_name, lock_state, q_job_name) AS ( \r\n SELECT object_name, lock_state, job_name \r\n FROM QSYS2.OBJECT_LOCK_INFO where \r\n object_schema = 'TOYSTORE' and \r\n object_name = 'SALES' ) \r\n      SELECT object_name, lock_state, q_job_name, \r\n    V_SQL_STATEMENT_TEXT, V_CLIENT_IP_ADDRESS, \r\n   B.* FROM LOCK_CONFLICT_TABLE, \r\n TABLE(QSYS2.GET_JOB_INFO(q_job_name)) B;"),
#  'RECORD_LOCK_INFO': ServiceInfo(SERVICE_CATEGORY='WORK MANAGEMENT', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='RECORD_LOCK_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='RCD_LOCK', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Find any record locks over the TOYSTORE/SALES table \r\n WITH LOCK_CONFLICT_TABLE ( \r\n  table_name, lock_state, rrn, q_job_name) AS ( \r\n SELECT table_name, lock_state, rrn, job_name \r\n FROM QSYS2.RECORD_LOCK_INFO where \r\n  table_schema = 'TOYSTORE' and \r\n  table_name = 'SALES' \r\n ) SELECT table_name, lock_state, rrn, \r\n          q_job_name, V_SQL_STATEMENT_TEXT, \r\n          V_CLIENT_IP_ADDRESS, B.* \r\n     FROM LOCK_CONFLICT_TABLE, TABLE(QSYS2.GET_JOB_INFO(q_job_name)) B;"),
#  'JOB_INFO': ServiceInfo(SERVICE_CATEGORY='WORK MANAGEMENT', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='JOB_INFO', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=13, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R2M0', EXAMPLE="-- Description: Review jobs that are scheduled to run tomorrow\r\n SELECT * \r\n   FROM TABLE(qsys2.job_info(job_status_filter => '*JOBQ')) x \r\n   WHERE job_scheduled_time BETWEEN DATE(CURRENT TIMESTAMP + 1 DAY) \r\n      AND DATE(CURRENT TIMESTAMP + 2 DAYS) \r\n   ORDER BY job_scheduled_time  ;"),
#  'JOB_QUEUE_INFO': ServiceInfo(SERVICE_CATEGORY='WORK MANAGEMENT', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='JOB_QUEUE_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='JOBQ_INFO', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R2M0', EXAMPLE='-- Description: Examine the job queues with the largest number of active jobs.\r\n SELECT * FROM QSYS2.JOB_QUEUE_INFO \r\n WHERE ACTIVE_JOBS IS NOT NULL \r\n ORDER BY NUMBER_OF_JOBS DESC;'),
#  'REPLY_LIST_INFO': ServiceInfo(SERVICE_CATEGORY='MESSAGE HANDLING', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='REPLY_LIST_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='REPLYLIST', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Review reply list detail for all messages which begin with CPA \r\n SELECT * FROM QSYS2.REPLY_LIST_INFO WHERE message_ID LIKE 'CPA%';"),
#  'JOBLOG_INFO': ServiceInfo(SERVICE_CATEGORY='MESSAGE HANDLING', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='JOBLOG_INFO', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=20, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Find the top 25 consumers of CPU in active QSQSRVR jobs \r\nWITH TT(AUTHORIZATION_NAME, SERVER_MODE_JOB_NAME, CPU_TIME, TOTAL_DISK_IO_COUNT) \r\nAS (SELECT AUTHORIZATION_NAME, JOB_NAME, CPU_TIME, TOTAL_DISK_IO_COUNT \r\n    FROM TABLE(QSYS2.ACTIVE_JOB_INFO(JOB_NAME_FILTER => 'QSQSRVR')) X) \r\nSELECT AUTHORIZATION_NAME, SS.MESSAGE_TEXT, \r\n       SERVER_MODE_JOB_NAME, CPU_TIME, TOTAL_DISK_IO_COUNT \r\nFROM TT, TABLE(QSYS2.JOBLOG_INFO(SERVER_MODE_JOB_NAME)) SS \r\nWHERE MESSAGE_ID = 'CPF9898' AND FROM_PROGRAM = 'QSQSRVR' \r\nORDER BY CPU_TIME DESC LIMIT 25;"),
#  'HISTORY_LOG_INFO': ServiceInfo(SERVICE_CATEGORY='MESSAGE HANDLING', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='HISTORY_LOG_INFO', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=23, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R2M0', EXAMPLE="-- Description: Compute the 50 user jobs with the longest time span, \r\n     -- that started between yesterday (midnight) and now \r\n   WITH new_jobs(job_name, start_time) \r\n   AS (SELECT from_job, message_timestamp \r\n          FROM TABLE(qsys2.history_log_info()) x \r\n          WHERE message_id = 'CPF1124'), \r\n     ended_jobs(job_name, end_time) \r\n   AS (SELECT from_job, message_timestamp \r\n          FROM TABLE(qsys2.history_log_info()) x \r\n          WHERE message_id = 'CPF1164') \r\n   SELECT n.job_name, \r\n          TIMESTAMPDIFF(4, CAST(end_time - start_time AS CHAR(22))) AS execution_minutes \r\n          FROM new_jobs n INNER JOIN ended_jobs e ON n.job_name = e.job_name \r\n      WHERE n.job_name NOT LIKE '%/Q%/%' \r\n      ORDER BY execution_minutes DESC \r\n      FETCH FIRST 50 ROWS ONLY  ;"),
#  'MESSAGE_QUEUE_INFO': ServiceInfo(SERVICE_CATEGORY='MESSAGE HANDLING', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='MESSAGE_QUEUE_INFO', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=13, INITIAL_DB2_GROUP_LEVEL=13, EARLIEST_POSSIBLE_RELEASE='V7R3M0', EXAMPLE="-- Description: Return a list of inquiry messages in QSYSOPR that have not been replied to \r\n SELECT MESSAGE_ID, MESSAGE_TEXT, MESSAGE_TIMESTAMP \r\n  FROM TABLE(QSYS2.MESSAGE_QUEUE_INFO(MESSAGE_FILTER => 'INQUIRY'));"),
#  'LIBRARY_LIST_INFO': ServiceInfo(SERVICE_CATEGORY='LIBRARIAN', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='LIBRARY_LIST_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='LIBLIST', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Ensure that the TOYSTORE library is the first library \r\n-- in the user portion of the library list \r\n BEGIN \r\n DECLARE V_ROW_NUM INTEGER; \r\n WITH CTE1(SCHEMA_NAME, ROW_NUM) AS ( \r\n SELECT SCHEMA_NAME, ROW_NUMBER() OVER (ORDER BY ORDINAL_POSITION) AS ROW_NUM \r\n FROM QSYS2.LIBRARY_LIST_INFO WHERE TYPE = 'USER' \r\n ) SELECT ROW_NUM INTO V_ROW_NUM FROM CTE1 WHERE SCHEMA_NAME = 'TOYSTORE'; \r\n IF (V_ROW_NUM IS NULL) THEN \r\n   CALL QSYS2.QCMDEXC('ADDLIBLE TOYSTORE'); \r\n ELSEIF (V_ROW_NUM > 1) THEN \r\n   BEGIN \r\n     CALL QSYS2.QCMDEXC('RMVLIBLE TOYSTORE'); \r\n     CALL QSYS2.QCMDEXC('ADDLIBLE TOYSTORE'); \r\n   END; \r\n END IF; \r\n END;"),
#  'OBJECT_STATISTICS': ServiceInfo(SERVICE_CATEGORY='LIBRARIAN', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='OBJECT_STATISTICS', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=13, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Find programs that are the least utilized \r\n   SELECT S1.OBJNAME, P.OBJCREATED, P.OBJNAME, P.OBJLONGNAME, P.OBJTYPE, \r\n   P.SQL_OBJECT_TYPE, P.OBJDEFINER, \r\n   P.LAST_USED_TIMESTAMP, P.LAST_RESET_TIMESTAMP \r\n   FROM TABLE(QSYS2.OBJECT_STATISTICS('*ALLUSR', 'LIB    ')) AS S1, \r\n   LATERAL \r\n (SELECT * FROM TABLE(QSYS2.OBJECT_STATISTICS(S1.OBJNAME, \r\n                                              'PGM SRVPGM')) AS X) AS P \r\n    WHERE S1.OBJNAME NOT LIKE 'Q%' AND \r\n    P.LAST_USED_TIMESTAMP IS NULL \r\n    OR P.DAYS_USED_COUNT = 0 \r\n    ORDER BY OBJCREATED ASC \r\n    LIMIT 100;"),
#  'USER_STORAGE': ServiceInfo(SERVICE_CATEGORY='STORAGE', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='USER_STORAGE', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='USER_STG', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Review the top 10 storage consumers, by user \r\n    SELECT A.AUTHORIZATION_NAME, SUM(A.STORAGE_USED) AS \r\n    TOTAL_STORAGE_USED, \r\n    B.TEXT_DESCRIPTION, B.ACCOUNTING_CODE, B.MAXIMUM_ALLOWED_STORAGE \r\n   FROM QSYS2.USER_STORAGE A \r\n    INNER JOIN QSYS2.USER_INFO B ON B.USER_NAME = A.AUTHORIZATION_NAME \r\n    WHERE \r\n    B.USER_NAME NOT LIKE 'Q%' \r\n    GROUP BY A.AUTHORIZATION_NAME, B.TEXT_DESCRIPTION, \r\n    B.ACCOUNTING_CODE, \r\n    B.MAXIMUM_ALLOWED_STORAGE \r\n   ORDER BY TOTAL_STORAGE_USED DESC FETCH FIRST 10 ROWS ONLY;"),
#  'SYSDISKSTAT': ServiceInfo(SERVICE_CATEGORY='STORAGE', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SYSDISKSTAT', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=28, INITIAL_DB2_GROUP_LEVEL=10, EARLIEST_POSSIBLE_RELEASE='V7R3M0', EXAMPLE="-- Description: Return information about all disks, resetting the \r\n     -- statistical information shown for the current job. \r\n SELECT * FROM TABLE(QSYS2.SYSDISKSTAT(RESET_STATISTICS=>'YES'));"),
#  'SYSTMPSTG': ServiceInfo(SERVICE_CATEGORY='STORAGE', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SYSTMPSTG', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='SYSTMPSTG', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R2M0', EXAMPLE="-- Description: Looking at the database server jobs, find the \r\n-- top 10 consumers of temporary storage and retrieve \r\n-- details about those jobs. \r\n WITH TOP_TMP_STG(BUCKET_CURRENT_SIZE, BUCKET_PEAK_SIZE, Q_JOB_NAME) \r\n AS (SELECT BUCKET_CURRENT_SIZE, BUCKET_PEAK_SIZE, RTRIM(JOB_NUMBER) CONCAT '/' CONCAT \r\n     RTRIM(JOB_USER_NAME) CONCAT '/' CONCAT RTRIM(JOB_NAME) AS Q_JOB_NAME \r\n    FROM QSYS2.SYSTMPSTG \r\n    WHERE JOB_STATUS = '*ACTIVE' AND \r\n    JOB_NAME IN ('QZDASOINIT', 'QZDASSINIT', 'QRWTSRVR', 'QSQSRVR') \r\n    ORDER BY BUCKET_CURRENT_SIZE DESC \r\n    FETCH FIRST 10 ROWS ONLY) \r\n SELECT BUCKET_CURRENT_SIZE, BUCKET_PEAK_SIZE, Q_JOB_NAME, V_SQL_STATEMENT_TEXT, B.* \r\n FROM TOP_TMP_STG, TABLE(QSYS2.GET_JOB_INFO(Q_JOB_NAME)) B;"),
#  'MEDIA_LIBRARY_INFO': ServiceInfo(SERVICE_CATEGORY='BACKUP AND RECOVERY', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='MEDIA_LIBRARY_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='MEDIA_INFO', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Check for unavailable tape drives \r\n SELECT * FROM QSYS2.MEDIA_LIBRARY_INFO WHERE DEVICE_STATUS = 'VARIED OFF';"),
#  'ASP_INFO': ServiceInfo(SERVICE_CATEGORY='STORAGE', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='ASP_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='ASP_INFO', LATEST_DB2_GROUP_LEVEL=25, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R2M0', EXAMPLE='-- Description: Show the ASP information for the partition. \r\n SELECT * FROM QSYS2.ASP_INFO;'),
#  'ASP_VARY_INFO': ServiceInfo(SERVICE_CATEGORY='STORAGE', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='ASP_VARY_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='VARY_INFO', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R2M0', EXAMPLE='-- Description: Analyze the total time needed for vary on and off. \r\n SELECT IASP_NAME, OPERATION_TYPE, OPERATION_NUMBER,   BIGINT(SUM(DURATION)) AS TOTAL_SECONDS,  DATE(MAX(START_TIMESTAMP)) AS WHEN   FROM QSYS2.ASP_VARY_INFO GROUP BY IASP_NAME, OPERATION_TYPE,   OPERATION_NUMBER ORDER BY 5 DESC;'),
#  'LICENSE_INFO': ServiceInfo(SERVICE_CATEGORY='PRODUCT', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='LICENSE_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='LIC_INFO', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Review licenses for installed features  \r\n     --    which have logged license violations  \r\n SELECT L.*  \r\n   FROM QSYS2.LICENSE_INFO L  \r\n   WHERE INSTALLED = 'YES' AND  \r\n         LOG_VIOLATION = 'YES';"),
#  'FIRMWARE_CURRENCY': ServiceInfo(SERVICE_CATEGORY='PTF', SERVICE_SCHEMA_NAME='SYSTOOLS', SERVICE_NAME='FIRMWARE_CURRENCY', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='FWCUR', LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R3M0', EXAMPLE='-- Description: Determine whether there is a newer version of \r\n-- firmware available for the current partition \r\n  SELECT * FROM SYSTOOLS.FIRMWARE_CURRENCY;'),
#  'OUTPUT_QUEUE_ENTRIES': ServiceInfo(SERVICE_CATEGORY='SPOOL', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='OUTPUT_QUEUE_ENTRIES', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=23, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Find the top 10 consumers of SPOOL storage \r\n SELECT USER_NAME, SUM(SIZE) AS TOTAL_SPOOL_SPACE \r\n   FROM TABLE(QSYS2.OBJECT_STATISTICS('*ALLUSR   ', 'LIB    ')) AS S1, \r\n   LATERAL \r\n   (SELECT * FROM TABLE(QSYS2.OBJECT_STATISTICS(CAST(S1.objname AS CHAR(10)), \r\n                                                'OUTQ   ')) AS b) AS S2, \r\n   LATERAL \r\n   (SELECT * FROM TABLE(QSYS2.OUTPUT_QUEUE_ENTRIES(S1.objname, \r\n                                                   S2.objname, '*NO')) \r\n    AS c) AS S3 \r\n   WHERE S1.OBJNAME NOT LIKE 'Q%' AND USER_NAME NOT LIKE 'Q%' \r\n   GROUP BY USER_NAME \r\n   ORDER BY TOTAL_SPOOL_SPACE DESC \r\n   LIMIT 10;"),
#  'OUTPUT_QUEUE_INFO': ServiceInfo(SERVICE_CATEGORY='SPOOL', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='OUTPUT_QUEUE_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='OUTQ_DTL', LATEST_DB2_GROUP_LEVEL=23, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Find the output queue with the most files and examine the spool detail \r\n WITH BIGGEST_OUTQ(LIBNAME, QUEUENAME, FILECOUNT) \r\n AS (SELECT OUTPUT_QUEUE_LIBRARY_NAME, OUTPUT_QUEUE_NAME, NUMBER_OF_FILES \r\n    FROM QSYS2.OUTPUT_QUEUE_INFO \r\n    ORDER BY NUMBER_OF_FILES DESC \r\n    FETCH FIRST 1 ROWS ONLY) \r\n SELECT LIBNAME, QUEUENAME, X.* \r\n    FROM BIGGEST_OUTQ, TABLE(QSYS2.OUTPUT_QUEUE_ENTRIES(LIBNAME, QUEUENAME, '*NO')) X \r\n ORDER BY TOTAL_PAGES DESC;"),
#  'SYSLIMTBL': ServiceInfo(SERVICE_CATEGORY='SYSTEM HEALTH', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SYSLIMTBL', SQL_OBJECT_TYPE='TABLE', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='SYSLIMTBL', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Are there any triggers created over the System Limits table \r\n SELECT * FROM QSYS2.SYSTRIGGERS \r\n  WHERE EVENT_OBJECT_SCHEMA = 'QSYS2' AND EVENT_OBJECT_TABLE = 'SYSLIMTBL';"),
#  'SYSLIMITS': ServiceInfo(SERVICE_CATEGORY='SYSTEM HEALTH', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SYSLIMITS', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='SYSLIMITS', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE='-- Description: Review the largest tables in System Limits \r\n WITH X AS (SELECT ROW_NUMBER() \r\n            OVER(PARTITION BY SYSTEM_SCHEMA_NAME, \r\n                 SYSTEM_OBJECT_NAME, SYSTEM_TABLE_MEMBER ORDER BY \r\n                CURRENT_VALUE DESC NULLS LAST) AS R, U.* \r\n            FROM QSYS2.SYSLIMITS U \r\n            WHERE LIMIT_ID = 15000) \r\n        SELECT LAST_CHANGE_TIMESTAMP, SYSTEM_SCHEMA_NAME, \r\n          SYSTEM_OBJECT_NAME, SYSTEM_TABLE_MEMBER, \r\n        CURRENT_VALUE \r\n        FROM X WHERE R = 1 \r\n        ORDER BY CURRENT_VALUE DESC;'),
#  'JOURNAL_INFO': ServiceInfo(SERVICE_CATEGORY='JOURNAL', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='JOURNAL_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='JRNINFO', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE='-- Description: Which remote journals fell the farthest behind this week? \r\n SELECT MAXIMUM_TIME_BEHIND, A.* FROM QSYS2.JOURNAL_INFO A WHERE \r\n        MAXIMUM_BEHIND_TIMESTAMP > CURRENT TIMESTAMP - 7 DAYS AND \r\n        MAXIMUM_TIME_BEHIND > 0 AND \r\n        MAXIMUM_TIME_BEHIND IS NOT NULL ORDER BY MAXIMUM_TIME_BEHIND DESC \r\n        FETCH FIRST 10 ROWS ONLY;'),
#  'DISPLAY_JOURNAL': ServiceInfo(SERVICE_CATEGORY='JOURNAL', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='DISPLAY_JOURNAL', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=26, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Retrieve the Change Profile entries over that last day \r\n SELECT journal_code, journal_entry_type, object, object_type, X.* \r\n FROM TABLE ( \r\n QSYS2.Display_Journal( \r\n   'QSYS', 'QAUDJRN', \r\n   Starting_Timestamp => CURRENT DATE - 1 DAY, \r\n   Journal_Codes => 'T', \r\n   Journal_Entry_Types => 'CP' \r\n )) as x;"),
#  'JVM_INFO': ServiceInfo(SERVICE_CATEGORY='JAVA', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='JVM_INFO', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=25, INITIAL_DB2_GROUP_LEVEL=25, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE='-- Description: Show information for all JVMs on the system. Do not wait longer than  \r\n  --   10 seconds for the results of any individual JVM to be returned. \r\n SELECT * FROM TABLE(QSYS2.JVM_INFO(WAIT_TIME => 10));'),
#  'SET_JVM': ServiceInfo(SERVICE_CATEGORY='JAVA', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SET_JVM', SQL_OBJECT_TYPE='PROCEDURE', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Generate detailed diagnostics for a specific JVM \r\n CALL QSYS2.SET_JVM('962835/JAVA/QJVAEXEC', 'GENERATE_HEAP_DUMP');"),
#  'QCMDEXC': ServiceInfo(SERVICE_CATEGORY='APPLICATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='QCMDEXC', SQL_OBJECT_TYPE='SCALAR FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=13, INITIAL_DB2_GROUP_LEVEL=13, EARLIEST_POSSIBLE_RELEASE='V7R3M0', EXAMPLE="-- Description: Hold jobs that started running an SQL statement \r\n     -- more than 2 hours ago. \r\n SELECT JOB_NAME,   \r\n       CASE WHEN QSYS2.QCMDEXC('HLDJOB ' CONCAT JOB_NAME) = 1 THEN 'Job Held' \r\n            ELSE 'Job not held' \r\n         END AS HLDJOB_RESULT \r\n  FROM TABLE (QSYS2.ACTIVE_JOB_INFO (DETAILED_INFO=> 'ALL'))  \r\n  WHERE SQL_STATEMENT_START_TIMESTAMP < CURRENT TIMESTAMP - 2 HOURS;"),
#  'SERVICES_INFO': ServiceInfo(SERVICE_CATEGORY='APPLICATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SERVICES_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='SERV_INFO', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Review all the Security related IBM i Services \r\n SELECT * FROM QSYS2.SERVICES_INFO \r\n  WHERE SERVICE_CATEGORY = 'SECURITY';"),
#  'ENVIRONMENT_VARIABLE_INFO': ServiceInfo(SERVICE_CATEGORY='APPLICATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='ENVIRONMENT_VARIABLE_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='ENV_VARS', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Review all system level environment variables for this connection \r\n SELECT * \r\n   FROM QSYS2.ENVIRONMENT_VARIABLE_INFO \r\n   WHERE ENVIRONMENT_VARIABLE_TYPE = 'SYSTEM';"),
#  'SET_PASE_SHELL_INFO': ServiceInfo(SERVICE_CATEGORY='APPLICATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SET_PASE_SHELL_INFO', SQL_OBJECT_TYPE='PROCEDURE', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Set the current user's shell to BASH shipped by 5733-OPS. \r\n CALL QSYS2.SET_PASE_SHELL_INFO('*CURRENT',  \r\n   '/QOpenSys/QIBM/ProdData/OPS/tools/bin/bash');"),
#  'MESSAGE_FILE_DATA': ServiceInfo(SERVICE_CATEGORY='MESSAGE HANDLING', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='MESSAGE_FILE_DATA', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='MSGF_DATA', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R3M0', EXAMPLE="-- Description: Find any messages in the APPLIB/APPMSGS message file that  \r\n-- contain the word VALUE in upper case, lower case, or mixed case in the second  \r\n-- level message text. \r\nSELECT * FROM QSYS2.MESSAGE_FILE_DATA  \r\n  WHERE MESSAGE_FILE_LIBRARY = 'APPLIB' AND MESSAGE_FILE = 'APPMSGS' \r\n   AND UPPER(MESSAGE_SECOND_LEVEL_TEXT) LIKE '%VALUE%';"),
#  'ENV_SYS_INFO': ServiceInfo(SERVICE_CATEGORY='COMMUNICATION', SERVICE_SCHEMA_NAME='SYSIBMADM', SERVICE_NAME='ENV_SYS_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='ENVSYSINFO', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Review the IBM i Operating system level \r\n     SELECT OS_NAME CONCAT ' ' CONCAT OS_VERSION CONCAT '.' \r\n     CONCAT OS_RELEASE FROM SYSIBMADM.ENV_SYS_INFO;"),
#  'TCPIP_INFO': ServiceInfo(SERVICE_CATEGORY='COMMUNICATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='TCPIP_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='TCPIP_INFO', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE='-- Description: Retrieve the Host name, IBM i OS version and Client IP address \r\n SELECT LOCAL_HOST_NAME, HOST_VERSION, CLIENT_IP_ADDRESS FROM QSYS2.TCPIP_INFO;'),
#  'SET_SERVER_SBS_ROUTING': ServiceInfo(SERVICE_CATEGORY='COMMUNICATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SET_SERVER_SBS_ROUTING', SQL_OBJECT_TYPE='PROCEDURE', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=4, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Use SERVER_SBS_ROUTING to reposition SCOTT to an alternate SBS \r\n CL: CRTSBSD SBSD(QGPL/ADHOCSBS) POOLS((1 *BASE)) TEXT('Ad hoc users SBS'); \r\n CL: CRTJOBQ QGPL/ADHOCJOBQ TEXT('Ad hoc users job queue'); \r\n CL: ADDJOBQE SBSD(QGPL/ADHOCSBS) JOBQ(QGPL/ADHOCJOBQ) MAXACT(100) SEQNBR(40); \r\n CL: CRTCLS CLS(QGPL/ADHOCCLS) RUNPTY(55) TIMESLICE(100) TEXT('Ad hoc class'); \r\n CL: ADDPJE SBSD(QGPL/ADHOCSBS) PGM(QSYS/QRWTSRVR) JOBD(QGPL/QDFTSVR) CLS(QGPL/ADHOCCLS); \r\n CL: ADDPJE SBSD(QGPL/ADHOCSBS) PGM(QSYS/QZDASOINIT) JOBD(QGPL/QDFTSVR) CLS(QGPL/ADHOCCLS); \r\n CL: STRSBS SBSD(QGPL/ADHOCSBS); \r\n CALL QSYS2.SET_SERVER_SBS_ROUTING('SCOTT','*ALL','ADHOCSBS');"),
#  'SERVER_SBS_ROUTING': ServiceInfo(SERVICE_CATEGORY='COMMUNICATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SERVER_SBS_ROUTING', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='SRVR_RTG', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE='-- Description: Review the existing configurations for users and groups \r\n SELECT * FROM QSYS2.SERVER_SBS_ROUTING;'),
#  'NETSTAT_INFO': ServiceInfo(SERVICE_CATEGORY='COMMUNICATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='NETSTAT_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='NS_INFO', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE='-- Description: Review the connections that are transferring the most data \r\n SELECT * FROM QSYS2.NETSTAT_INFO \r\n   ORDER BY BYTES_SENT_REMOTELY + BYTES_RECEIVED_LOCALLY DESC \r\n   LIMIT 10;'),
#  'NETSTAT_INTERFACE_INFO': ServiceInfo(SERVICE_CATEGORY='COMMUNICATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='NETSTAT_INTERFACE_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='NS_INTER', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE='-- Description: Review the TCP/IP Interface details \r\n SELECT * FROM QSYS2.NETSTAT_INTERFACE_INFO;'),
#  'NETSTAT_JOB_INFO': ServiceInfo(SERVICE_CATEGORY='COMMUNICATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='NETSTAT_JOB_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='NS_JOB', LATEST_DB2_GROUP_LEVEL=26, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Review the network jobs coming in from a unique IP address \r\n WITH NETSTAT_USER_JOBS (V_JOB_NAME,  V_LOCAL_PORT) AS ( \r\n SELECT JOB_NAME, LOCAL_PORT_NAME FROM QSYS2.NETSTAT_JOB_INFO \r\n  WHERE REMOTE_ADDRESS = '9.10.213.27' ) \r\n   SELECT AUTHORIZATION_NAME, V_JOB_NAME, V_LOCAL_PORT, \r\n          RUN_PRIORITY, CPU_TIME, SERVER_TYPE \r\n     FROM NETSTAT_USER_JOBS, \r\n          TABLE(QSYS2.ACTIVE_JOB_INFO()) B \r\n          WHERE JOB_NAME = V_JOB_NAME;"),
#  'NETSTAT_ROUTE_INFO': ServiceInfo(SERVICE_CATEGORY='COMMUNICATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='NETSTAT_ROUTE_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='NS_ROUTE', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE='-- Description: Review the details of all TCP/IP routes \r\n SELECT * FROM QSYS2.NETSTAT_ROUTE_INFO;'),
#  'PARSE_STATEMENT': ServiceInfo(SERVICE_CATEGORY='DATABASE-APPLICATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='PARSE_STATEMENT', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=26, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R2M0', EXAMPLE="-- Description: For schema TOYSTORE, find all tables referenced by \r\n-- static SQL statements by all application programs \r\n  WITH program_statements(naming_mode,\r\n                          dec_point,\r\n                          string_delim,\r\n                          stmt_text,\r\n                          system_program_name,\r\n                          program_type)\r\n    AS (SELECT a.naming,\r\n               a.decimal_point,\r\n               a.sql_string_delimiter,\r\n               b.statement_text,\r\n               a.system_program_name,\r\n               a.program_type\r\n          FROM qsys2.sysprogramstat a INNER JOIN\r\n               qsys2.sysprogramstmtstat b ON \r\n                     a.program_schema = b.program_schema AND\r\n                     a.program_name = b.program_name AND\r\n                     a.module_name = b.module_name\r\n          WHERE a.program_schema = 'TOYSTORE' AND\r\n                b.program_schema = 'TOYSTORE')\r\n    SELECT system_program_name,\r\n           program_type,\r\n           c.schema,\r\n           c.name,\r\n           stmt_text\r\n      FROM program_statements,\r\n         TABLE(qsys2.parse_statement(stmt_text, naming_mode,\r\n                                     dec_point, string_delim)) c\r\n      WHERE c.name_type = 'TABLE'\r\n      ORDER BY c.schema, c.name;"),
#  'DELIMIT_NAME': ServiceInfo(SERVICE_CATEGORY='DATABASE-APPLICATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='DELIMIT_NAME', SQL_OBJECT_TYPE='SCALAR FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE='-- Description: Delimit DB2 for i catalog names, as needed \r\n SELECT QSYS2.DELIMIT_NAME(TABLE_NAME) FROM QSYS2.SYSTABLES;'),
#  'OVERRIDE_TABLE': ServiceInfo(SERVICE_CATEGORY='DATABASE-APPLICATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='OVERRIDE_TABLE', SQL_OBJECT_TYPE='PROCEDURE', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Use a higher blocking factor for I/O \r\n CALL QSYS2.OVERRIDE_TABLE('TOYSTORE', 'ITEM_FACT', '*BUF128KB');"),
#  'OVERRIDE_QAQQINI': ServiceInfo(SERVICE_CATEGORY='DATABASE-APPLICATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='OVERRIDE_QAQQINI', SQL_OBJECT_TYPE='PROCEDURE', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=7, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Establish the temporary override for QAQQINI. \r\n -- The current QAQQINI values for the job will be used as the initial values. \r\n CALL QSYS2.OVERRIDE_QAQQINI(1, '', ''); \r\n    -- Description: Temporarily override the UDF timeout QAQQINI option. \r\n CALL QSYS2.OVERRIDE_QAQQINI(2, 'UDF_TIME_OUT', '*MAX');"),
#  'WLM_SET_CLIENT_INFO': ServiceInfo(SERVICE_CATEGORY='DATABASE-APPLICATION', SERVICE_SCHEMA_NAME='SYSPROC', SERVICE_NAME='WLM_SET_CLIENT_INFO', SQL_OBJECT_TYPE='PROCEDURE', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=23, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: Brand the client special register values for a connection \r\n CALL SYSPROC.WLM_SET_CLIENT_INFO('db2user','machine.rchland.ibm.com','auditor', \r\n    'Accounting department', 'MYPGM');"),
#  'ACT_ON_INDEX_ADVICE': ServiceInfo(SERVICE_CATEGORY='DATABASE-PERFORMANCE', SERVICE_SCHEMA_NAME='SYSTOOLS', SERVICE_NAME='ACT_ON_INDEX_ADVICE', SQL_OBJECT_TYPE='PROCEDURE', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V6R1M0', EXAMPLE="-- Description: For schema TOYSTORE, find all instances of index advice where \r\n-- an MTI was used more than 1000 times and create permanent SQL indexes. \r\n CALL SYSTOOLS.ACT_ON_INDEX_ADVICE('TOYSTORE',NULL,NULL,1000,NULL);"),
#  'DATABASE_MONITOR_INFO': ServiceInfo(SERVICE_CATEGORY='DATABASE-PERFORMANCE', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='DATABASE_MONITOR_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='DBMON_INFO', LATEST_DB2_GROUP_LEVEL=None, INITIAL_DB2_GROUP_LEVEL=None, EARLIEST_POSSIBLE_RELEASE='V7R1M0', EXAMPLE="-- Description: Retrieve the info for all the active PUBLIC monitors \r\n SELECT MONITOR_ID, MONITOR_LIBRARY, MONITOR_FILE \r\n   FROM QSYS2.DATABASE_MONITOR_INFO \r\n   WHERE MONITOR_STATUS = 'ACTIVE' AND \r\n         MONITOR_TYPE = 'PUBLIC';"),
# ...
#  'PUTENV': ServiceInfo(SERVICE_CATEGORY='APPLICATION', SERVICE_SCHEMA_NAME='SYSTOOLS', SERVICE_NAME='PUTENV', SQL_OBJECT_TYPE='SCALAR FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=28, INITIAL_DB2_GROUP_LEVEL=28, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE="-- Description: Set the value of MY_ENVVAR for the current job. \r\n    VALUES SYSTOOLS.PUTENV('MY_ENVVAR', 'My job''s value for the environment variable');"),
#  'SELFCODES': ServiceInfo(SERVICE_CATEGORY='DATABASE-APPLICATION', SERVICE_SCHEMA_NAME='SYSIBMADM', SERVICE_NAME='SELFCODES', SQL_OBJECT_TYPE='GLOBAL VARIABLE', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=23, INITIAL_DB2_GROUP_LEVEL=23, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE="-- Description: Configure SELF to capture detail for all jobs started in the future, \r\n     -- for any SQL statements that fail with SQLCODE = -913 or SQLCODE = -204. \r\n  CREATE OR REPLACE VARIABLE SYSIBMADM.SELFCODES  \r\n      VARCHAR(256) DEFAULT '-913, -204';"),
#  'SYSMEMBERSTAT': ServiceInfo(SERVICE_CATEGORY='DATABASE-UTILITY', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SYSMEMBERSTAT', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='SYSMSTAT', LATEST_DB2_GROUP_LEVEL=28, INITIAL_DB2_GROUP_LEVEL=28, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE="-- Description: Examine some statistical information for all members of all files in APPLIB1. \r\n SELECT TABLE_NAME, NUMBER_ROWS, NUMBER_DELETED_ROWS, LAST_USED_TIMESTAMP \r\n  FROM QSYS2.SYSMEMBERSTAT \r\n  WHERE TABLE_SCHEMA = 'APPLIB1';"),
#  'IFS_UNLINK': ServiceInfo(SERVICE_CATEGORY='IFS', SERVICE_SCHEMA_NAME='SYSTOOLS', SERVICE_NAME='IFS_UNLINK', SQL_OBJECT_TYPE='SCALAR FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=28, INITIAL_DB2_GROUP_LEVEL=28, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE="-- Description: Unlink file /usr/reportdata.txt. \r\n   VALUES SYSTOOLS.IFS_UNLINK(PATH_NAME => '/usr/reportdata.txt');"),
#  'COMPARE_IFS': ServiceInfo(SERVICE_CATEGORY='IFS', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='COMPARE_IFS', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=28, INITIAL_DB2_GROUP_LEVEL=28, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE="-- Description: Compare the names for all objects in two subtrees. Compare recursively  \r\n        -- through the entire set of subdirectories. \r\n   SELECT * FROM TABLE(QSYS2.COMPARE_IFS(  \r\n                                       START_PATH_NAME1    => '/usr/files.dir',  \r\n                                       START_PATH_NAME2    => '/usrbackup/files.dir', \r\n                                       SUBTREE_DIRECTORIES => 'YES', \r\n                                       COMPARE_ATTRIBUTES  => 'NAMES' \r\n                              ));"),
#  'ADD_VALIDATION_LIST_ENTRY': ServiceInfo(SERVICE_CATEGORY='SECURITY', SERVICE_SCHEMA_NAME='SYSTOOLS', SERVICE_NAME='ADD_VALIDATION_LIST_ENTRY', SQL_OBJECT_TYPE='SCALAR FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE="-- Description: Add an authentication entry for a user of an external interface. \r\n     --   Use a global variable so the password is not visible in the function invocation. \r\n     --   for all user profiles on the system. \r\n     CREATE VARIABLE MYLIB.VLDL_PW VARCHAR(100); \r\n \r\nSET MYLIB.VLDL_PW = 'password for my user access'; \r\n \r\nVALUES SYSTOOLS.ADD_VALIDATION_LIST_ENTRY( \r\n                             VALIDATION_LIST_LIBRARY => 'APPLIB',  \r\n                             VALIDATION_LIST_NAME    => 'APPVLDL', \r\n                             VALIDATION_USER         => 'my application user name', \r\n                             PASSWORD                => MYLIB.VLDL_PW);"),
#  'CHANGE_VALIDATION_LIST_ENTRY': ServiceInfo(SERVICE_CATEGORY='SECURITY', SERVICE_SCHEMA_NAME='SYSTOOLS', SERVICE_NAME='CHANGE_VALIDATION_LIST_ENTRY', SQL_OBJECT_TYPE='SCALAR FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE="-- Description: Change the password for an existing authentication entry.\r\n     CREATE VARIABLE MYLIB.VLDL_PW VARCHAR(100); \r\n \r\nSET MYLIB.VLDL_PW = 'my new password'; \r\n \r\nVALUES SYSTOOLS.CHANGE_VALIDATION_LIST_ENTRY( \r\n                             VALIDATION_LIST_LIBRARY => 'APPLIB',  \r\n                             VALIDATION_LIST_NAME    => 'APPVLDL', \r\n                             VALIDATION_USER         => 'my application user name', \r\n                             PASSWORD                => MYLIB.VLDL_PW);"),
#  'REMOVE_VALIDATION_LIST_ENTRY': ServiceInfo(SERVICE_CATEGORY='SECURITY', SERVICE_SCHEMA_NAME='SYSTOOLS', SERVICE_NAME='REMOVE_VALIDATION_LIST_ENTRY', SQL_OBJECT_TYPE='SCALAR FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE="-- Description: Remove an authentication entry for a specific user of an external interface.\r\nVALUES SYSTOOLS.REMOVE_VALIDATION_LIST_ENTRY( \r\n                             VALIDATION_LIST_LIBRARY => 'APPLIB',  \r\n                             VALIDATION_LIST_NAME    => 'APPVLDL', \r\n                             VALIDATION_USER         => 'my application user name');"),
#  'END_JOBS': ServiceInfo(SERVICE_CATEGORY='WORK MANAGEMENT', SERVICE_SCHEMA_NAME='SYSTOOLS', SERVICE_NAME='END_JOBS', SQL_OBJECT_TYPE='PROCEDURE', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE="-- Description: Find and end all the active jobs with a job name of BATCHTEST. \r\n    -- For every job, end using the controlled option, save any spooled files, and do \r\n    -- not generate a job log. \r\n  CALL SYSTOOLS.END_JOBS(JOB_NAME_FILTER          => 'BATCHTEST',  \r\n                       END_OPTION               => 'CONTROLLED', \r\n                       DELETE_SPOOLED_FILES     => 'NO', \r\n                       MAXIMUM_JOBLOG_ENTRIES   => 0);"),
#  'POWER_SCHEDULE_INFO': ServiceInfo(SERVICE_CATEGORY='WORK MANAGEMENT', SERVICE_SCHEMA_NAME='SYSTOOLS', SERVICE_NAME='POWER_SCHEDULE_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='POWER_INFO', LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE='-- Description: List all the scheduled power events. \r\n  SELECT * FROM SYSTOOLS.POWER_SCHEDULE_INFO;'),
#  'CONFIGURATION_STATUS': ServiceInfo(SERVICE_CATEGORY='CONFIGURATION', SERVICE_SCHEMA_NAME='SYSTOOLS', SERVICE_NAME='CONFIGURATION_STATUS', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='CONFIG_STS', LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE="-- Description: List the status of all controllers. \r\n   SELECT OBJECT_NAME, OBJECT_ATTRIBUTE, STATUS_DESCRIPTION, TEXT_DESCRIPTION  \r\n  FROM SYSTOOLS.CONFIGURATION_STATUS \r\n  WHERE OBJECT_TYPE = '*CTLD';"),
#  'SERVICE_TOOLS_SERVER_INFO': ServiceInfo(SERVICE_CATEGORY='CONFIGURATION', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='SERVICE_TOOLS_SERVER_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='STS_INFO', LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE='-- Description: Show information about the service tools server configuration. \r\n   SELECT * FROM QSYS2.SERVICE_TOOLS_SERVER_INFO;'),
#  'AUDIT_JOURNAL_VP': ServiceInfo(SERVICE_CATEGORY='JOURNAL', SERVICE_SCHEMA_NAME='SYSTOOLS', SERVICE_NAME='AUDIT_JOURNAL_VP', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE='-- Description: Review the Network Server password failures, by day and by server name. \r\n  SELECT DATE(ENTRY_TIMESTAMP) AS "DATE", SERVER_NAME,  \r\n       COUNT(*) AS NETWORK_SERVER_PASSWORD_ERROR_COUNT \r\n  FROM TABLE (  \r\n      SYSTOOLS.AUDIT_JOURNAL_VP(STARTING_TIMESTAMP => CURRENT TIMESTAMP - 7 DAYS))  \r\n  GROUP BY DATE(ENTRY_TIMESTAMP), SERVER_NAME \r\n  ORDER BY "DATE", NETWORK_SERVER_PASSWORD_ERROR_COUNT DESC;'),
#  'CHANGE_MIGRATION_MANAGER': ServiceInfo(SERVICE_CATEGORY='MIGRATE WHILE ACTIVE', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='CHANGE_MIGRATION_MANAGER', SQL_OBJECT_TYPE='PROCEDURE', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE="-- Description: Enable initial configuration of IBM i Migrate While Active                         \r\n-- and set the current node as the source node.                                                     \r\n    CALL QSYS2.CHANGE_MIGRATION_MANAGER(ACTION => 'SETUP');"),
#  'DATA_COMPRESSION_FACTOR': ServiceInfo(SERVICE_CATEGORY='MIGRATE WHILE ACTIVE', SERVICE_SCHEMA_NAME='SYSIBMADM', SERVICE_NAME='DATA_COMPRESSION_FACTOR', SQL_OBJECT_TYPE='TABLE', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='COMP_FACT', LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE='-- Description: List the compression factors used for the different types                          \r\n-- of compression in IBM i Migrate While Active.                                                    \r\n    SELECT * FROM SYSIBMADM.DATA_COMPRESSION_FACTOR;'),
#  'ESTIMATE_FINAL_SYNCHRONIZATION_TIME': ServiceInfo(SERVICE_CATEGORY='MIGRATE WHILE ACTIVE', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='ESTIMATE_FINAL_SYNCHRONIZATION_TIME', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE='-- Description: Estimate the length of time required to complete                                   \r\n-- synchronization of objects in a IBM i Migrate While                                              \r\n-- Active environment to the copy node.                                                             \r\n    SELECT * FROM TABLE(QSYS2.ESTIMATE_FINAL_SYNCHRONIZATION_TIME());'),
#  'IFS_MIGRATION_LIST': ServiceInfo(SERVICE_CATEGORY='MIGRATE WHILE ACTIVE', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='IFS_MIGRATION_LIST', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='MIG_ITL', LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE="-- Description: Examine the integrated file system objects that are                                \r\n-- currently attempting migration to the copy node.                                                 \r\n    SELECT PATH_NAME, OBJECT_TYPE                                                                   \r\n      FROM QSYS2.IFS_MIGRATION_LIST                                                                 \r\n      WHERE TRACKING_STATE = 'MIGRATING'                                                          \r\n      ORDER BY PATH_NAME, OBJECT_TYPE;"),
#  'LIBRARY_MIGRATION_LIST': ServiceInfo(SERVICE_CATEGORY='MIGRATE WHILE ACTIVE', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='LIBRARY_MIGRATION_LIST', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='MIG_LTL', LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE="-- Description: Examine the eligible library-based objects that need                               \r\n-- to be migrated to the copy node.                                                                 \r\n    SELECT LIBRARY_NAME, OBJECT_NAME, OBJECT_SIZE                                                   \r\n      FROM QSYS2.LIBRARY_MIGRATION_LIST                                                             \r\n      WHERE TRACKING_STATE  <> 'MIGRATING'                                                        \r\n      ORDER BY LIBRARY_NAME, OBJECT_NAME;"),
#  'MIGRATED_IFS': ServiceInfo(SERVICE_CATEGORY='MIGRATE WHILE ACTIVE', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='MIGRATED_IFS', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='MIG_IFS', LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE='-- Description: Review a list of the integrated file system objects that                           \r\n-- have successfully completed migration to the copy node within                                    \r\n-- the last hour.                                                                                   \r\n    SELECT * FROM QSYS2.MIGRATED_IFS                                                                \r\n      WHERE MIGRATION_END_TIME > CURRENT TIMESTAMP - 1 HOUR                                         \r\n      ORDER BY MIGRATION_END_TIME DESC;'),
#  'MIGRATED_LIBRARY': ServiceInfo(SERVICE_CATEGORY='MIGRATE WHILE ACTIVE', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='MIGRATED_LIBRARY', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='MIG_LIB', LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE="-- Description: Review a list of library-based objects in TOYSTORE                                 \r\n-- that have successfully completed migration to the copy node                                      \r\n-- within the last hour.                                                                            \r\n    SELECT * FROM QSYS2.MIGRATED_LIBRARY                                                            \r\n      WHERE MIGRATION_END_TIME > CURRENT TIMESTAMP - 1 HOUR AND                                     \r\n            (LIBRARY_NAME = 'TOYSTORE' OR                                                         \r\n             (LIBRARY_NAME = 'QSYS' AND                                                           \r\n              OBJECT_NAME = 'TOYSTORE' AND                                                        \r\n              OBJECT_TYPE = '*LIB'))                                                              \r\n      ORDER BY MIGRATION_END_TIME DESC;"),
#  'MIGRATION_MANAGER_INFO': ServiceInfo(SERVICE_CATEGORY='MIGRATE WHILE ACTIVE', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='MIGRATION_MANAGER_INFO', SQL_OBJECT_TYPE='VIEW', OBJECT_TYPE='*FILE', SYSTEM_OBJECT_NAME='MIG_MANAGE', LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE='-- Description: Examine information about the IBM i Migrate While                                  \r\n-- Active environment.                                                                              \r\n    SELECT * FROM QSYS2.MIGRATION_MANAGER_INFO;'),
#  'MIGRATION_NETWORK_BANDWIDTH': ServiceInfo(SERVICE_CATEGORY='MIGRATE WHILE ACTIVE', SERVICE_SCHEMA_NAME='QSYS2', SERVICE_NAME='MIGRATION_NETWORK_BANDWIDTH', SQL_OBJECT_TYPE='TABLE FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE='-- Description: Check the bandwidth to the copy node in a IBM i                                    \r\n-- Migrate While Active environment. Take the measurement 5                                         \r\n-- times for calculating the values.                                                                \r\n    SELECT * FROM TABLE(QSYS2.MIGRATION_NETWORK_BANDWIDTH(5));'),
#  'IFS_ACCESS': ServiceInfo(SERVICE_CATEGORY='IFS', SERVICE_SCHEMA_NAME='SYSTOOLS', SERVICE_NAME='IFS_ACCESS', SQL_OBJECT_TYPE='SCALAR FUNCTION', OBJECT_TYPE=None, SYSTEM_OBJECT_NAME=None, LATEST_DB2_GROUP_LEVEL=29, INITIAL_DB2_GROUP_LEVEL=29, EARLIEST_POSSIBLE_RELEASE='V7R4M0', EXAMPLE="-- Description: Determine whether the invoker of the function has read access to \r\n        --   /usr/reportdata.txt. \r\n   VALUES SYSTOOLS.IFS_ACCESS(PATH_NAME => '/usr/reportdata.txt',  \r\n                           READ => 'YES');")}

# %%
filtered_services = {}
for k, v in service_collection.items():
    if v.SERVICE_CATEGORY == 'SECURITY':
        print(v.model_dump())
# Out:
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'USER_INFO', 'SQL_OBJECT_TYPE': 'VIEW', 'OBJECT_TYPE': '*FILE', 'SYSTEM_OBJECT_NAME': 'USER_INFO', 'LATEST_DB2_GROUP_LEVEL': 13, 'INITIAL_DB2_GROUP_LEVEL': None, 'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0', 'EXAMPLE': "-- Description: Which users are at risk of becoming disabled due to lack of use? \r\n SELECT * FROM QSYS2.USER_INFO \r\n WHERE STATUS = '*ENABLED' AND LAST_USED_TIMESTAMP IS NOT NULL \r\n ORDER BY LAST_USED_TIMESTAMP ASC \r\n FETCH FIRST 20 ROWS ONLY;"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'FUNCTION_INFO', 'SQL_OBJECT_TYPE': 'VIEW', 'OBJECT_TYPE': '*FILE', 'SYSTEM_OBJECT_NAME': 'FCN_INFO', 'LATEST_DB2_GROUP_LEVEL': None, 'INITIAL_DB2_GROUP_LEVEL': None, 'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0', 'EXAMPLE': '-- Description: Which function usage IDs exist \r\n SELECT * FROM QSYS2.FUNCTION_INFO ORDER BY FUNCTION_ID;'}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'FUNCTION_USAGE', 'SQL_OBJECT_TYPE': 'VIEW', 'OBJECT_TYPE': '*FILE', 'SYSTEM_OBJECT_NAME': 'FCN_USAGE', 'LATEST_DB2_GROUP_LEVEL': None, 'INITIAL_DB2_GROUP_LEVEL': None, 'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0', 'EXAMPLE': "-- Description: Which Database function usage has been granted or revoked? \r\n   SELECT * FROM QSYS2.FUNCTION_USAGE \r\n   WHERE FUNCTION_ID LIKE 'QIBM_DB_%' ORDER BY FUNCTION_ID, USER_NAME;"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'GROUP_PROFILE_ENTRIES', 'SQL_OBJECT_TYPE': 'VIEW', 'OBJECT_TYPE': '*FILE', 'SYSTEM_OBJECT_NAME': 'GROUPLIST', 'LATEST_DB2_GROUP_LEVEL': None, 'INITIAL_DB2_GROUP_LEVEL': None, 'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0', 'EXAMPLE': "-- Description: Review *ALLOBJ users \r\n SELECT AUTHORIZATION_NAME, STATUS, NO_PASSWORD_INDICATOR, PREVIOUS_SIGNON, \r\n TEXT_DESCRIPTION \r\n FROM QSYS2.USER_INFO \r\n WHERE SPECIAL_AUTHORITIES LIKE '%*ALLOBJ%' \r\n OR AUTHORIZATION_NAME IN ( \r\n SELECT USER_PROFILE_NAME \r\n FROM QSYS2.GROUP_PROFILE_ENTRIES \r\n WHERE GROUP_PROFILE_NAME IN ( \r\n SELECT AUTHORIZATION_NAME \r\n FROM QSYS2.USER_INFO \r\n WHERE SPECIAL_AUTHORITIES like '%*ALLOBJ%')) \r\n ORDER BY AUTHORIZATION_NAME;"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'SQL_CHECK_AUTHORITY', 'SQL_OBJECT_TYPE': 'SCALAR FUNCTION', 'OBJECT_TYPE': None, 'SYSTEM_OBJECT_NAME': None, 'LATEST_DB2_GROUP_LEVEL': None, 'INITIAL_DB2_GROUP_LEVEL': None, 'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0', 'EXAMPLE': "-- Description: Does this user have authority to query this file \r\n   VALUES ( CASE WHEN QSYS2.SQL_CHECK_AUTHORITY('QSYS2','SYSLIMITS') = 1 \r\n   THEN 'I can query QSYS2/SYSLIMITS' ELSE 'No query access for me' END );"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'SET_COLUMN_ATTRIBUTE', 'SQL_OBJECT_TYPE': 'PROCEDURE', 'OBJECT_TYPE': None, 'SYSTEM_OBJECT_NAME': None, 'LATEST_DB2_GROUP_LEVEL': None, 'INITIAL_DB2_GROUP_LEVEL': None, 'EARLIEST_POSSIBLE_RELEASE': 'V6R1M0', 'EXAMPLE': "-- Description: Secure salary column values in the SQL Performance Center \r\n     CALL SYSPROC.SET_COLUMN_ATTRIBUTE('TOYSTORE', 'EMPLOYEE', 'SALARY', \r\n     'SECURE YES'); \r\n-- Review configuration of SECURE column values for DBE & Performance analysts \r\n SELECT COLUMN_NAME,SECURE \r\n    FROM QSYS2.SYSCOLUMNS2 \r\n    WHERE SYSTEM_TABLE_SCHEMA = 'TOYSTORE' AND SYSTEM_TABLE_NAME = 'EMPLOYEE';"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'DRDA_AUTHENTICATION_ENTRY_INFO', 'SQL_OBJECT_TYPE': 'VIEW', 'OBJECT_TYPE': '*FILE', 'SYSTEM_OBJECT_NAME': 'DRDA_AUTHE', 'LATEST_DB2_GROUP_LEVEL': None, 'INITIAL_DB2_GROUP_LEVEL': None, 'EARLIEST_POSSIBLE_RELEASE': 'V7R1M0', 'EXAMPLE': '-- Description: Retrieve the DRDA Authentication Entry info \r\n SELECT * FROM QSYS2.DRDA_AUTHENTICATION_ENTRY_INFO \r\n  ORDER BY AUTHORIZATION_NAME, SERVER_NAME;'}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'AUTHORITY_COLLECTION', 'SQL_OBJECT_TYPE': 'VIEW', 'OBJECT_TYPE': '*FILE', 'SYSTEM_OBJECT_NAME': 'AUTH_COL', 'LATEST_DB2_GROUP_LEVEL': None, 'INITIAL_DB2_GROUP_LEVEL': None, 'EARLIEST_POSSIBLE_RELEASE': 'V7R3M0', 'EXAMPLE': "-- Description: Review authority failures, contrasting the authority required versus the current authority \r\nSELECT AUTHORIZATION_NAME, OBJECT_NAME, SYSTEM_OBJECT_TYPE, \r\nREQUIRED_AUTHORITY, DETAILED_REQUIRED_AUTHORITY, CURRENT_AUTHORITY, A.* \r\n FROM QSYS2.AUTHORITY_COLLECTION A \r\n WHERE AUTHORITY_CHECK_SUCCESSFUL = '0' ORDER BY 1;"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'OBJECT_PRIVILEGES', 'SQL_OBJECT_TYPE': 'VIEW', 'OBJECT_TYPE': '*FILE', 'SYSTEM_OBJECT_NAME': 'OBJ_PRIV', 'LATEST_DB2_GROUP_LEVEL': 7, 'INITIAL_DB2_GROUP_LEVEL': None, 'EARLIEST_POSSIBLE_RELEASE': 'V7R2M0', 'EXAMPLE': "-- Description: Review *PUBLIC authority for user libraries \r\nSELECT OBJECT_AUTHORITY AS LIBRARY_AUTHORITY, COUNT(*) AS COUNT \r\n FROM TABLE(QSYS2.OBJECT_STATISTICS('*ALLUSR', 'LIB')) L, \r\n LATERAL (SELECT OBJECT_AUTHORITY \r\n   FROM QSYS2.OBJECT_PRIVILEGES \r\n   WHERE NAME = L.OBJNAME AND \r\n   OBJECT_SCHEMA = 'QSYS' AND \r\n   OBJECT_TYPE = '*LIB' AND \r\n   USER_NAME = '*PUBLIC') p \r\n GROUP BY OBJECT_AUTHORITY \r\n ORDER BY 2 DESC;"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'AUTHORIZATION_LIST_INFO', 'SQL_OBJECT_TYPE': 'VIEW', 'OBJECT_TYPE': '*FILE', 'SYSTEM_OBJECT_NAME': 'AUTHL_INFO', 'LATEST_DB2_GROUP_LEVEL': None, 'INITIAL_DB2_GROUP_LEVEL': None, 'EARLIEST_POSSIBLE_RELEASE': 'V7R2M0', 'EXAMPLE': "-- Description: Find objects not included in the authorization list for \r\n  --  Schema = TOYSTORE  Authorization List = TOYSTOREAL \r\nWITH ALLOBJS(OBJNAME, OBJDEFINER, OBJTYPE, SQL_OBJECT_TYPE) AS ( \r\nSELECT OBJNAME, OBJDEFINER, OBJTYPE, SQL_OBJECT_TYPE   \r\n FROM TABLE(QSYS2.OBJECT_STATISTICS('TOYSTORE', 'ALL')) O), \r\n AUTLOBJS(OBJNAME) AS ( \r\nSELECT SYSTEM_OBJECT_NAME  \r\n FROM QSYS2.AUTHORIZATION_LIST_INFO b  \r\n   WHERE B.AUTHORIZATION_LIST = 'TOYSTOREAL' \r\n) SELECT A.OBJNAME, OBJDEFINER, OBJTYPE, SQL_OBJECT_TYPE \r\n  FROM ALLOBJS A LEFT EXCEPTION JOIN AUTLOBJS B  \r\n  ON A.OBJNAME = B.OBJNAME;"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'AUTHORIZATION_LIST_USER_INFO', 'SQL_OBJECT_TYPE': 'VIEW', 'OBJECT_TYPE': '*FILE', 'SYSTEM_OBJECT_NAME': 'AUTL_USERS', 'LATEST_DB2_GROUP_LEVEL': None, 'INITIAL_DB2_GROUP_LEVEL': None, 'EARLIEST_POSSIBLE_RELEASE': 'V7R2M0', 'EXAMPLE': "-- Description: Review JOEUSER's object access via authorization lists \r\nSELECT AUTHORIZATION_LIST, object_authority  \r\n   FROM QSYS2.AUTHORIZATION_LIST_USER_INFO B \r\n   WHERE AUTHORIZATION_NAME = 'JOEUSER' OR \r\n         (AUTHORIZATION_NAME = '*PUBLIC' AND \r\n         OBJECT_AUTHORITY <> '*EXCLUDE') \r\n   ORDER BY 1;"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'OBJECT_OWNERSHIP', 'SQL_OBJECT_TYPE': 'VIEW', 'OBJECT_TYPE': '*FILE', 'SYSTEM_OBJECT_NAME': 'OBJ_OWN', 'LATEST_DB2_GROUP_LEVEL': 4, 'INITIAL_DB2_GROUP_LEVEL': 4, 'EARLIEST_POSSIBLE_RELEASE': 'V7R3M0', 'EXAMPLE': "-- Description: List all the objects owned by USER1. \r\n SELECT * FROM QSYS2.OBJECT_OWNERSHIP WHERE AUTHORIZATION_NAME = 'USER1';"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'CERTIFICATE_INFO', 'SQL_OBJECT_TYPE': 'TABLE FUNCTION', 'OBJECT_TYPE': None, 'SYSTEM_OBJECT_NAME': None, 'LATEST_DB2_GROUP_LEVEL': 7, 'INITIAL_DB2_GROUP_LEVEL': 7, 'EARLIEST_POSSIBLE_RELEASE': 'V7R3M0', 'EXAMPLE': "-- Description: Retrieve all the certificates for the *SYSTEM certificate store \r\n  -- that will be expired within the next month. Use a password that has been set \r\n  -- in a global variable.List all the objects owned by USER1 \r\n CREATE VARIABLE MYLIB.SYSTEM_CERT_PW VARCHAR(30);   SET MYLIB.SYSTEM_CERT_PW = 'cert_pwd';  SELECT * FROM TABLE(QSYS2.CERTIFICATE_INFO(          CERTIFICATE_STORE_PASSWORD=> MYLIB.SYSTEM_CERT_PW))    WHERE VALIDITY_END < CURRENT DATE + 1 MONTH;"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'USER_INFO_BASIC', 'SQL_OBJECT_TYPE': 'VIEW', 'OBJECT_TYPE': '*FILE', 'SYSTEM_OBJECT_NAME': 'USER_INFOB', 'LATEST_DB2_GROUP_LEVEL': 13, 'INITIAL_DB2_GROUP_LEVEL': 13, 'EARLIEST_POSSIBLE_RELEASE': 'V7R3M0', 'EXAMPLE': "-- Description: Which users have *ALLOBJ special authority. \r\n SELECT * FROM QSYS2.USER_INFO_BASIC \r\n WHERE SPECIAL_AUTHORITIES LIKE '%*ALLOBJ%';"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'SECURITY_INFO', 'SQL_OBJECT_TYPE': 'VIEW', 'OBJECT_TYPE': '*FILE', 'SYSTEM_OBJECT_NAME': 'SEC_INFO', 'LATEST_DB2_GROUP_LEVEL': 15, 'INITIAL_DB2_GROUP_LEVEL': 13, 'EARLIEST_POSSIBLE_RELEASE': 'V7R3M0', 'EXAMPLE': '-- Description: Return the security and password levels for the system. \r\n SELECT SECURITY_LEVEL, PASSWORD_LEVEL FROM QSYS2.SECURITY_INFO;'}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'SYSTOOLS', 'SERVICE_NAME': 'CHANGE_USER_PROFILE', 'SQL_OBJECT_TYPE': 'TABLE FUNCTION', 'OBJECT_TYPE': None, 'SYSTEM_OBJECT_NAME': None, 'LATEST_DB2_GROUP_LEVEL': 26, 'INITIAL_DB2_GROUP_LEVEL': 13, 'EARLIEST_POSSIBLE_RELEASE': 'V7R3M0', 'EXAMPLE': "-- Description: Preview the list of enabled user profiles that have no password set. \r\n SELECT * FROM QSYS2.USER_INFO,  \r\n              TABLE(SYSTOOLS.CHANGE_USER_PROFILE( \r\n                    P_USER_NAME  => AUTHORIZATION_NAME,  \r\n                    P_STATUS     => '*DISABLED', \r\n                    PREVIEW      => 'YES')) \r\n  WHERE STATUS = '*ENABLED' AND  \r\n        NO_PASSWORD_INDICATOR = 'YES';"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'SQL_CHECK_FUNCTION_USAGE', 'SQL_OBJECT_TYPE': 'SCALAR FUNCTION', 'OBJECT_TYPE': None, 'SYSTEM_OBJECT_NAME': None, 'LATEST_DB2_GROUP_LEVEL': 20, 'INITIAL_DB2_GROUP_LEVEL': 20, 'EARLIEST_POSSIBLE_RELEASE': 'V7R3M0', 'EXAMPLE': "-- Description: Check whether the current user is authorized to the QIBM_DB_SQLADM \r\n     -- function usage identifier. \r\n    VALUES QSYS2.SQL_CHECK_FUNCTION_USAGE('QIBM_DB_SQLADM');"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'QSYS2', 'SERVICE_NAME': 'SQL_CHECK_SPECIAL_AUTHORITY', 'SQL_OBJECT_TYPE': 'SCALAR FUNCTION', 'OBJECT_TYPE': None, 'SYSTEM_OBJECT_NAME': None, 'LATEST_DB2_GROUP_LEVEL': 20, 'INITIAL_DB2_GROUP_LEVEL': 20, 'EARLIEST_POSSIBLE_RELEASE': 'V7R3M0', 'EXAMPLE': "-- Description: Check whether the current user has *JOBCTL special authority. \r\n     VALUES QSYS2.SQL_CHECK_SPECIAL_AUTHORITY('*JOBCTL');"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'SYSTOOLS', 'SERVICE_NAME': 'SPECIAL_AUTHORITY_DATA_MART', 'SQL_OBJECT_TYPE': 'TABLE', 'OBJECT_TYPE': '*FILE', 'SYSTEM_OBJECT_NAME': 'SPEC_AUTH', 'LATEST_DB2_GROUP_LEVEL': 28, 'INITIAL_DB2_GROUP_LEVEL': 28, 'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0', 'EXAMPLE': '-- Description: Update the table to contain the current special authority values \r\n     -- for all user profiles on the system. \r\n     REFRESH TABLE SYSTOOLS.SPECIAL_AUTHORITY_DATA_MART;'}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'SYSTOOLS', 'SERVICE_NAME': 'ADD_VALIDATION_LIST_ENTRY', 'SQL_OBJECT_TYPE': 'SCALAR FUNCTION', 'OBJECT_TYPE': None, 'SYSTEM_OBJECT_NAME': None, 'LATEST_DB2_GROUP_LEVEL': 29, 'INITIAL_DB2_GROUP_LEVEL': 29, 'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0', 'EXAMPLE': "-- Description: Add an authentication entry for a user of an external interface. \r\n     --   Use a global variable so the password is not visible in the function invocation. \r\n     --   for all user profiles on the system. \r\n     CREATE VARIABLE MYLIB.VLDL_PW VARCHAR(100); \r\n \r\nSET MYLIB.VLDL_PW = 'password for my user access'; \r\n \r\nVALUES SYSTOOLS.ADD_VALIDATION_LIST_ENTRY( \r\n                             VALIDATION_LIST_LIBRARY => 'APPLIB',  \r\n                             VALIDATION_LIST_NAME    => 'APPVLDL', \r\n                             VALIDATION_USER         => 'my application user name', \r\n                             PASSWORD                => MYLIB.VLDL_PW);"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'SYSTOOLS', 'SERVICE_NAME': 'CHANGE_VALIDATION_LIST_ENTRY', 'SQL_OBJECT_TYPE': 'SCALAR FUNCTION', 'OBJECT_TYPE': None, 'SYSTEM_OBJECT_NAME': None, 'LATEST_DB2_GROUP_LEVEL': 29, 'INITIAL_DB2_GROUP_LEVEL': 29, 'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0', 'EXAMPLE': "-- Description: Change the password for an existing authentication entry.\r\n     CREATE VARIABLE MYLIB.VLDL_PW VARCHAR(100); \r\n \r\nSET MYLIB.VLDL_PW = 'my new password'; \r\n \r\nVALUES SYSTOOLS.CHANGE_VALIDATION_LIST_ENTRY( \r\n                             VALIDATION_LIST_LIBRARY => 'APPLIB',  \r\n                             VALIDATION_LIST_NAME    => 'APPVLDL', \r\n                             VALIDATION_USER         => 'my application user name', \r\n                             PASSWORD                => MYLIB.VLDL_PW);"}
# {'SERVICE_CATEGORY': 'SECURITY', 'SERVICE_SCHEMA_NAME': 'SYSTOOLS', 'SERVICE_NAME': 'REMOVE_VALIDATION_LIST_ENTRY', 'SQL_OBJECT_TYPE': 'SCALAR FUNCTION', 'OBJECT_TYPE': None, 'SYSTEM_OBJECT_NAME': None, 'LATEST_DB2_GROUP_LEVEL': 29, 'INITIAL_DB2_GROUP_LEVEL': 29, 'EARLIEST_POSSIBLE_RELEASE': 'V7R4M0', 'EXAMPLE': "-- Description: Remove an authentication entry for a specific user of an external interface.\r\nVALUES SYSTOOLS.REMOVE_VALIDATION_LIST_ENTRY( \r\n                             VALIDATION_LIST_LIBRARY => 'APPLIB',  \r\n                             VALIDATION_LIST_NAME    => 'APPVLDL', \r\n                             VALIDATION_USER         => 'my application user name');"}

# %%
import json
from typing import List

def save_services_to_json(services: List[ServiceInfo], filename: str):
    # Convert all BaseModel objects to dictionaries
    services_data = [service.model_dump() for service in services]
    for service in services:
        print(service)
    
    with open(filename, 'w') as f:
        json.dump(services_data, f, indent=2, default=str)

# %%
save_services_to_json(list(service_collection.values()), "service_collection.json")
# Out:
# SERVICE_CATEGORY='PTF' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='PTF_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='PTF_INFO' LATEST_DB2_GROUP_LEVEL=26 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Will an IPL impact PTF state? \r\n  SELECT PTF_IDENTIFIER, PTF_IPL_ACTION, A.* \r\n  FROM QSYS2.PTF_INFO A \r\n       WHERE PTF_IPL_ACTION <> 'NONE';"
# SERVICE_CATEGORY='PTF' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='GROUP_PTF_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='GRPPTFINFO' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: What is the most recently installed CUM? \r\n  SELECT MAX(PTF_GROUP_LEVEL) AS CUM_LEVEL FROM \r\n  QSYS2.GROUP_PTF_INFO P, SYSIBMADM.ENV_SYS_INFO V \r\n  WHERE PTF_GROUP_NAME = 'SF99' CONCAT V.OS_VERSION CONCAT V.OS_RELEASE CONCAT '0' \r\n  AND PTF_GROUP_STATUS = 'INSTALLED';"
# SERVICE_CATEGORY='PTF' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='GROUP_PTF_CURRENCY' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='GRPPTFCUR' LATEST_DB2_GROUP_LEVEL=10 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Determine whether the PTF Groups are current \r\n  SELECT * FROM SYSTOOLS.GROUP_PTF_CURRENCY, SYSIBMADM.ENV_SYS_INFO V  \r\n  WHERE PTF_GROUP_RELEASE = 'R' CONCAT V.OS_VERSION CONCAT V.OS_RELEASE CONCAT '0' \r\n  ORDER BY PTF_GROUP_LEVEL_AVAILABLE - PTF_GROUP_LEVEL_INSTALLED DESC;"
# SERVICE_CATEGORY='PTF' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='GROUP_PTF_DETAILS' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='GRPPTFDTL' LATEST_DB2_GROUP_LEVEL=10 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Review all unapplied PTFs contained within PTF Groups installed \r\n-- on the partition against the live PTF detail available from IBM \r\n  SELECT * FROM SYSTOOLS.GROUP_PTF_DETAILS \r\n  WHERE PTF_STATUS <> 'PTF APPLIED' \r\n  ORDER BY PTF_GROUP_NAME;"
# SERVICE_CATEGORY='SECURITY' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='USER_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='USER_INFO' LATEST_DB2_GROUP_LEVEL=13 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Which users are at risk of becoming disabled due to lack of use? \r\n SELECT * FROM QSYS2.USER_INFO \r\n WHERE STATUS = '*ENABLED' AND LAST_USED_TIMESTAMP IS NOT NULL \r\n ORDER BY LAST_USED_TIMESTAMP ASC \r\n FETCH FIRST 20 ROWS ONLY;"
# SERVICE_CATEGORY='SECURITY' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='FUNCTION_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='FCN_INFO' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE='-- Description: Which function usage IDs exist \r\n SELECT * FROM QSYS2.FUNCTION_INFO ORDER BY FUNCTION_ID;'
# SERVICE_CATEGORY='SECURITY' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='FUNCTION_USAGE' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='FCN_USAGE' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Which Database function usage has been granted or revoked? \r\n   SELECT * FROM QSYS2.FUNCTION_USAGE \r\n   WHERE FUNCTION_ID LIKE 'QIBM_DB_%' ORDER BY FUNCTION_ID, USER_NAME;"
# SERVICE_CATEGORY='SECURITY' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='GROUP_PROFILE_ENTRIES' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='GROUPLIST' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Review *ALLOBJ users \r\n SELECT AUTHORIZATION_NAME, STATUS, NO_PASSWORD_INDICATOR, PREVIOUS_SIGNON, \r\n TEXT_DESCRIPTION \r\n FROM QSYS2.USER_INFO \r\n WHERE SPECIAL_AUTHORITIES LIKE '%*ALLOBJ%' \r\n OR AUTHORIZATION_NAME IN ( \r\n SELECT USER_PROFILE_NAME \r\n FROM QSYS2.GROUP_PROFILE_ENTRIES \r\n WHERE GROUP_PROFILE_NAME IN ( \r\n SELECT AUTHORIZATION_NAME \r\n FROM QSYS2.USER_INFO \r\n WHERE SPECIAL_AUTHORITIES like '%*ALLOBJ%')) \r\n ORDER BY AUTHORIZATION_NAME;"
# SERVICE_CATEGORY='SECURITY' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SQL_CHECK_AUTHORITY' SQL_OBJECT_TYPE='SCALAR FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Does this user have authority to query this file \r\n   VALUES ( CASE WHEN QSYS2.SQL_CHECK_AUTHORITY('QSYS2','SYSLIMITS') = 1 \r\n   THEN 'I can query QSYS2/SYSLIMITS' ELSE 'No query access for me' END );"
# SERVICE_CATEGORY='SECURITY' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SET_COLUMN_ATTRIBUTE' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Secure salary column values in the SQL Performance Center \r\n     CALL SYSPROC.SET_COLUMN_ATTRIBUTE('TOYSTORE', 'EMPLOYEE', 'SALARY', \r\n     'SECURE YES'); \r\n-- Review configuration of SECURE column values for DBE & Performance analysts \r\n SELECT COLUMN_NAME,SECURE \r\n    FROM QSYS2.SYSCOLUMNS2 \r\n    WHERE SYSTEM_TABLE_SCHEMA = 'TOYSTORE' AND SYSTEM_TABLE_NAME = 'EMPLOYEE';"
# SERVICE_CATEGORY='SECURITY' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='DRDA_AUTHENTICATION_ENTRY_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='DRDA_AUTHE' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE='-- Description: Retrieve the DRDA Authentication Entry info \r\n SELECT * FROM QSYS2.DRDA_AUTHENTICATION_ENTRY_INFO \r\n  ORDER BY AUTHORIZATION_NAME, SERVER_NAME;'
# SERVICE_CATEGORY='SECURITY' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='AUTHORITY_COLLECTION' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='AUTH_COL' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R3M0' EXAMPLE="-- Description: Review authority failures, contrasting the authority required versus the current authority \r\nSELECT AUTHORIZATION_NAME, OBJECT_NAME, SYSTEM_OBJECT_TYPE, \r\nREQUIRED_AUTHORITY, DETAILED_REQUIRED_AUTHORITY, CURRENT_AUTHORITY, A.* \r\n FROM QSYS2.AUTHORITY_COLLECTION A \r\n WHERE AUTHORITY_CHECK_SUCCESSFUL = '0' ORDER BY 1;"
# SERVICE_CATEGORY='SECURITY' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='OBJECT_PRIVILEGES' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='OBJ_PRIV' LATEST_DB2_GROUP_LEVEL=7 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R2M0' EXAMPLE="-- Description: Review *PUBLIC authority for user libraries \r\nSELECT OBJECT_AUTHORITY AS LIBRARY_AUTHORITY, COUNT(*) AS COUNT \r\n FROM TABLE(QSYS2.OBJECT_STATISTICS('*ALLUSR', 'LIB')) L, \r\n LATERAL (SELECT OBJECT_AUTHORITY \r\n   FROM QSYS2.OBJECT_PRIVILEGES \r\n   WHERE NAME = L.OBJNAME AND \r\n   OBJECT_SCHEMA = 'QSYS' AND \r\n   OBJECT_TYPE = '*LIB' AND \r\n   USER_NAME = '*PUBLIC') p \r\n GROUP BY OBJECT_AUTHORITY \r\n ORDER BY 2 DESC;"
# SERVICE_CATEGORY='SECURITY' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='AUTHORIZATION_LIST_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='AUTHL_INFO' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R2M0' EXAMPLE="-- Description: Find objects not included in the authorization list for \r\n  --  Schema = TOYSTORE  Authorization List = TOYSTOREAL \r\nWITH ALLOBJS(OBJNAME, OBJDEFINER, OBJTYPE, SQL_OBJECT_TYPE) AS ( \r\nSELECT OBJNAME, OBJDEFINER, OBJTYPE, SQL_OBJECT_TYPE   \r\n FROM TABLE(QSYS2.OBJECT_STATISTICS('TOYSTORE', 'ALL')) O), \r\n AUTLOBJS(OBJNAME) AS ( \r\nSELECT SYSTEM_OBJECT_NAME  \r\n FROM QSYS2.AUTHORIZATION_LIST_INFO b  \r\n   WHERE B.AUTHORIZATION_LIST = 'TOYSTOREAL' \r\n) SELECT A.OBJNAME, OBJDEFINER, OBJTYPE, SQL_OBJECT_TYPE \r\n  FROM ALLOBJS A LEFT EXCEPTION JOIN AUTLOBJS B  \r\n  ON A.OBJNAME = B.OBJNAME;"
# SERVICE_CATEGORY='SECURITY' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='AUTHORIZATION_LIST_USER_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='AUTL_USERS' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R2M0' EXAMPLE="-- Description: Review JOEUSER's object access via authorization lists \r\nSELECT AUTHORIZATION_LIST, object_authority  \r\n   FROM QSYS2.AUTHORIZATION_LIST_USER_INFO B \r\n   WHERE AUTHORIZATION_NAME = 'JOEUSER' OR \r\n         (AUTHORIZATION_NAME = '*PUBLIC' AND \r\n         OBJECT_AUTHORITY <> '*EXCLUDE') \r\n   ORDER BY 1;"
# SERVICE_CATEGORY='WORK MANAGEMENT' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SYSTEM_VALUE_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='SYSVALINFO' LATEST_DB2_GROUP_LEVEL=26 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE='-- Description: Compare System Values across two partitions \r\n DECLARE GLOBAL TEMPORARY TABLE SESSION.Remote_System_Values \r\n ( SYSTEM_VALUE_NAME,CURRENT_NUMERIC_VALUE,CURRENT_CHARACTER_VALUE ) \r\n AS (SELECT * FROM REMOTEPART.QSYS2.SYSTEM_VALUE_INFO) WITH DATA \r\n WITH REPLACE; \r\n-- Use exception join to reveal any differences \r\n  SELECT \'REMOTEPART\' AS "System Name", A.SYSTEM_VALUE_NAME, \r\n  A.CURRENT_NUMERIC_VALUE,A.CURRENT_CHARACTER_VALUE FROM QSYS2.SYSTEM_VALUE_INFO A \r\n LEFT EXCEPTION JOIN SESSION.Remote_System_Values B \r\n ON A.SYSTEM_VALUE_NAME = B.SYSTEM_VALUE_NAME AND \r\n    A.CURRENT_NUMERIC_VALUE IS NOT DISTINCT FROM B.CURRENT_NUMERIC_VALUE AND \r\n    A.CURRENT_CHARACTER_VALUE IS NOT DISTINCT FROM B.CURRENT_CHARACTER_VALUE \r\n UNION ALL \r\n  SELECT \'LOCALPART\' AS "System Name", B.SYSTEM_VALUE_NAME, \r\n  B.CURRENT_NUMERIC_VALUE, \r\n  B.CURRENT_CHARACTER_VALUE FROM QSYS2.SYSTEM_VALUE_INFO A \r\n RIGHT EXCEPTION JOIN SESSION.Remote_System_Values B \r\n ON A.SYSTEM_VALUE_NAME = B.SYSTEM_VALUE_NAME AND \r\n    A.CURRENT_NUMERIC_VALUE IS NOT DISTINCT FROM B.CURRENT_NUMERIC_VALUE AND \r\n    A.CURRENT_CHARACTER_VALUE IS NOT DISTINCT FROM B.CURRENT_CHARACTER_VALUE \r\n ORDER BY SYSTEM_VALUE_NAME;'
# SERVICE_CATEGORY='WORK MANAGEMENT' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='GET_JOB_INFO' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Find the jobs with SQL statements executing \r\n WITH ACTIVE_USER_JOBS (Q_JOB_NAME, CPU_TIME, RUN_PRIORITY) AS ( \r\n SELECT \r\n  JOB_NAME, CPU_TIME, RUN_PRIORITY \r\n  FROM TABLE (ACTIVE_JOB_INFO()) x \r\n WHERE JOB_TYPE <> 'SYS' \r\n ) SELECT Q_JOB_NAME, CPU_TIME, RUN_PRIORITY, V_SQL_STATEMENT_TEXT, \r\n ABS( CURRENT TIMESTAMP - V_SQL_STMT_START_TIMESTAMP ) AS SQL_STMT_DURATION, B.* \r\n FROM ACTIVE_USER_JOBS, TABLE(QSYS2.GET_JOB_INFO(Q_JOB_NAME)) B \r\n WHERE V_SQL_STMT_STATUS = 'ACTIVE' \r\n ORDER BY SQL_STMT_DURATION DESC;"
# SERVICE_CATEGORY='WORK MANAGEMENT' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='ACTIVE_JOB_INFO' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Find the top 10 consumers of CPU in the QUSRWRK and QSYSWRK subsystems \r\n select CPU_TIME, A.* FROM \r\n table(QSYS2.ACTIVE_JOB_INFO(SUBSYSTEM_LIST_FILTER => 'QUSRWRK,QSYSWRK')) A \r\n ORDER BY CPU_TIME DESC \r\n LIMIT 10;"
# SERVICE_CATEGORY='WORK MANAGEMENT' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SCHEDULED_JOB_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='SCHED_JOB' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Review the job scheduled entries which are no longer in effect \r\n   SELECT * FROM QSYS2.SCHEDULED_JOB_INFO WHERE \r\n   STATUS IN ('HELD', 'SAVED') ORDER BY SCHEDULED_BY;"
# SERVICE_CATEGORY='WORK MANAGEMENT' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='MEMORY_POOL' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Return all available pool information. \r\n SELECT * FROM TABLE(QSYS2.MEMORY_POOL('YES')) X;"
# SERVICE_CATEGORY='WORK MANAGEMENT' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='MEMORY_POOL_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='POOL_INFO' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE='-- Description: Review the details of all active memory pools. \r\n SELECT * FROM QSYS2.MEMORY_POOL_INFO;'
# SERVICE_CATEGORY='WORK MANAGEMENT' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SYSTEM_STATUS' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Review elapsed system status over a 60 second window \r\n DECLARE GLOBAL TEMPORARY TABLE SESSION.SYSTEM_STATUS_REFERENCE_POINT AS ( \r\n  SELECT TOTAL_JOBS_IN_SYSTEM, ACTIVE_JOBS_IN_SYSTEM, ELAPSED_CPU_USED, \r\n         ELAPSED_CPU_SHARED, ELAPSED_CPU_UNCAPPED_CAPACITY \r\n    FROM TABLE(QSYS2.SYSTEM_STATUS('YES')) A \r\n ) WITH DATA WITH REPLACE; \r\n CALL QSYS2.QCMDEXC('DLYJOB DLY(60)'); \r\n SELECT B.TOTAL_JOBS_IN_SYSTEM - A.TOTAL_JOBS_IN_SYSTEM \r\n   AS DELTA_TOTAL_JOBS_IN_SYSTEM, \r\n B.ACTIVE_JOBS_IN_SYSTEM - A.ACTIVE_JOBS_IN_SYSTEM \r\n AS DELTA_ACTIVE_JOBS_IN_SYSTEM, \r\n        B.ELAPSED_TIME, \r\n B.ELAPSED_CPU_USED - A.ELAPSED_CPU_USED \r\n AS DELTA_ELAPSED_CPU_USED, \r\n B.ELAPSED_CPU_SHARED - A.ELAPSED_CPU_SHARED \r\n AS DELTA_ELAPSED_CPU_SHARED, \r\n B.ELAPSED_CPU_UNCAPPED_CAPACITY - A.ELAPSED_CPU_UNCAPPED_CAPACITY \r\n AS DELTA_ELAPSED_CPU_UNCAPPED_CAPACITY \r\n FROM SESSION.SYSTEM_STATUS_REFERENCE_POINT A, \r\n TABLE(QSYS2.SYSTEM_STATUS('NO')) B;"
# SERVICE_CATEGORY='WORK MANAGEMENT' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SYSTEM_STATUS_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='SYS_STATUS' LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE='-- Description: Review current system status, including the job max percentage \r\n SELECT TOTAL_JOBS_IN_SYSTEM, MAXIMUM_JOBS_IN_SYSTEM, \r\n DECIMAL((DECIMAL(TOTAL_JOBS_IN_SYSTEM) / \r\n          DECIMAL(MAXIMUM_JOBS_IN_SYSTEM)), 11, 3) * 100 AS JOB_MAX_PERCENT, A.* \r\n    FROM QSYS2.SYSTEM_STATUS_INFO A;'
# SERVICE_CATEGORY='WORK MANAGEMENT' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='OBJECT_LOCK_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='OBJ_LOCK' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Find any object locks over the TOYSTORE/SALES table \r\n WITH LOCK_CONFLICT_TABLE (object_name, lock_state, q_job_name) AS ( \r\n SELECT object_name, lock_state, job_name \r\n FROM QSYS2.OBJECT_LOCK_INFO where \r\n object_schema = 'TOYSTORE' and \r\n object_name = 'SALES' ) \r\n      SELECT object_name, lock_state, q_job_name, \r\n    V_SQL_STATEMENT_TEXT, V_CLIENT_IP_ADDRESS, \r\n   B.* FROM LOCK_CONFLICT_TABLE, \r\n TABLE(QSYS2.GET_JOB_INFO(q_job_name)) B;"
# SERVICE_CATEGORY='WORK MANAGEMENT' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='RECORD_LOCK_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='RCD_LOCK' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Find any record locks over the TOYSTORE/SALES table \r\n WITH LOCK_CONFLICT_TABLE ( \r\n  table_name, lock_state, rrn, q_job_name) AS ( \r\n SELECT table_name, lock_state, rrn, job_name \r\n FROM QSYS2.RECORD_LOCK_INFO where \r\n  table_schema = 'TOYSTORE' and \r\n  table_name = 'SALES' \r\n ) SELECT table_name, lock_state, rrn, \r\n          q_job_name, V_SQL_STATEMENT_TEXT, \r\n          V_CLIENT_IP_ADDRESS, B.* \r\n     FROM LOCK_CONFLICT_TABLE, TABLE(QSYS2.GET_JOB_INFO(q_job_name)) B;"
# SERVICE_CATEGORY='WORK MANAGEMENT' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='JOB_INFO' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=13 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R2M0' EXAMPLE="-- Description: Review jobs that are scheduled to run tomorrow\r\n SELECT * \r\n   FROM TABLE(qsys2.job_info(job_status_filter => '*JOBQ')) x \r\n   WHERE job_scheduled_time BETWEEN DATE(CURRENT TIMESTAMP + 1 DAY) \r\n      AND DATE(CURRENT TIMESTAMP + 2 DAYS) \r\n   ORDER BY job_scheduled_time  ;"
# SERVICE_CATEGORY='WORK MANAGEMENT' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='JOB_QUEUE_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='JOBQ_INFO' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R2M0' EXAMPLE='-- Description: Examine the job queues with the largest number of active jobs.\r\n SELECT * FROM QSYS2.JOB_QUEUE_INFO \r\n WHERE ACTIVE_JOBS IS NOT NULL \r\n ORDER BY NUMBER_OF_JOBS DESC;'
# SERVICE_CATEGORY='MESSAGE HANDLING' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='REPLY_LIST_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='REPLYLIST' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Review reply list detail for all messages which begin with CPA \r\n SELECT * FROM QSYS2.REPLY_LIST_INFO WHERE message_ID LIKE 'CPA%';"
# SERVICE_CATEGORY='MESSAGE HANDLING' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='JOBLOG_INFO' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=20 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Find the top 25 consumers of CPU in active QSQSRVR jobs \r\nWITH TT(AUTHORIZATION_NAME, SERVER_MODE_JOB_NAME, CPU_TIME, TOTAL_DISK_IO_COUNT) \r\nAS (SELECT AUTHORIZATION_NAME, JOB_NAME, CPU_TIME, TOTAL_DISK_IO_COUNT \r\n    FROM TABLE(QSYS2.ACTIVE_JOB_INFO(JOB_NAME_FILTER => 'QSQSRVR')) X) \r\nSELECT AUTHORIZATION_NAME, SS.MESSAGE_TEXT, \r\n       SERVER_MODE_JOB_NAME, CPU_TIME, TOTAL_DISK_IO_COUNT \r\nFROM TT, TABLE(QSYS2.JOBLOG_INFO(SERVER_MODE_JOB_NAME)) SS \r\nWHERE MESSAGE_ID = 'CPF9898' AND FROM_PROGRAM = 'QSQSRVR' \r\nORDER BY CPU_TIME DESC LIMIT 25;"
# SERVICE_CATEGORY='MESSAGE HANDLING' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='HISTORY_LOG_INFO' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=23 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R2M0' EXAMPLE="-- Description: Compute the 50 user jobs with the longest time span, \r\n     -- that started between yesterday (midnight) and now \r\n   WITH new_jobs(job_name, start_time) \r\n   AS (SELECT from_job, message_timestamp \r\n          FROM TABLE(qsys2.history_log_info()) x \r\n          WHERE message_id = 'CPF1124'), \r\n     ended_jobs(job_name, end_time) \r\n   AS (SELECT from_job, message_timestamp \r\n          FROM TABLE(qsys2.history_log_info()) x \r\n          WHERE message_id = 'CPF1164') \r\n   SELECT n.job_name, \r\n          TIMESTAMPDIFF(4, CAST(end_time - start_time AS CHAR(22))) AS execution_minutes \r\n          FROM new_jobs n INNER JOIN ended_jobs e ON n.job_name = e.job_name \r\n      WHERE n.job_name NOT LIKE '%/Q%/%' \r\n      ORDER BY execution_minutes DESC \r\n      FETCH FIRST 50 ROWS ONLY  ;"
# SERVICE_CATEGORY='MESSAGE HANDLING' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='MESSAGE_QUEUE_INFO' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=13 INITIAL_DB2_GROUP_LEVEL=13 EARLIEST_POSSIBLE_RELEASE='V7R3M0' EXAMPLE="-- Description: Return a list of inquiry messages in QSYSOPR that have not been replied to \r\n SELECT MESSAGE_ID, MESSAGE_TEXT, MESSAGE_TIMESTAMP \r\n  FROM TABLE(QSYS2.MESSAGE_QUEUE_INFO(MESSAGE_FILTER => 'INQUIRY'));"
# SERVICE_CATEGORY='LIBRARIAN' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='LIBRARY_LIST_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='LIBLIST' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Ensure that the TOYSTORE library is the first library \r\n-- in the user portion of the library list \r\n BEGIN \r\n DECLARE V_ROW_NUM INTEGER; \r\n WITH CTE1(SCHEMA_NAME, ROW_NUM) AS ( \r\n SELECT SCHEMA_NAME, ROW_NUMBER() OVER (ORDER BY ORDINAL_POSITION) AS ROW_NUM \r\n FROM QSYS2.LIBRARY_LIST_INFO WHERE TYPE = 'USER' \r\n ) SELECT ROW_NUM INTO V_ROW_NUM FROM CTE1 WHERE SCHEMA_NAME = 'TOYSTORE'; \r\n IF (V_ROW_NUM IS NULL) THEN \r\n   CALL QSYS2.QCMDEXC('ADDLIBLE TOYSTORE'); \r\n ELSEIF (V_ROW_NUM > 1) THEN \r\n   BEGIN \r\n     CALL QSYS2.QCMDEXC('RMVLIBLE TOYSTORE'); \r\n     CALL QSYS2.QCMDEXC('ADDLIBLE TOYSTORE'); \r\n   END; \r\n END IF; \r\n END;"
# SERVICE_CATEGORY='LIBRARIAN' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='OBJECT_STATISTICS' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=13 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Find programs that are the least utilized \r\n   SELECT S1.OBJNAME, P.OBJCREATED, P.OBJNAME, P.OBJLONGNAME, P.OBJTYPE, \r\n   P.SQL_OBJECT_TYPE, P.OBJDEFINER, \r\n   P.LAST_USED_TIMESTAMP, P.LAST_RESET_TIMESTAMP \r\n   FROM TABLE(QSYS2.OBJECT_STATISTICS('*ALLUSR', 'LIB    ')) AS S1, \r\n   LATERAL \r\n (SELECT * FROM TABLE(QSYS2.OBJECT_STATISTICS(S1.OBJNAME, \r\n                                              'PGM SRVPGM')) AS X) AS P \r\n    WHERE S1.OBJNAME NOT LIKE 'Q%' AND \r\n    P.LAST_USED_TIMESTAMP IS NULL \r\n    OR P.DAYS_USED_COUNT = 0 \r\n    ORDER BY OBJCREATED ASC \r\n    LIMIT 100;"
# SERVICE_CATEGORY='STORAGE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='USER_STORAGE' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='USER_STG' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Review the top 10 storage consumers, by user \r\n    SELECT A.AUTHORIZATION_NAME, SUM(A.STORAGE_USED) AS \r\n    TOTAL_STORAGE_USED, \r\n    B.TEXT_DESCRIPTION, B.ACCOUNTING_CODE, B.MAXIMUM_ALLOWED_STORAGE \r\n   FROM QSYS2.USER_STORAGE A \r\n    INNER JOIN QSYS2.USER_INFO B ON B.USER_NAME = A.AUTHORIZATION_NAME \r\n    WHERE \r\n    B.USER_NAME NOT LIKE 'Q%' \r\n    GROUP BY A.AUTHORIZATION_NAME, B.TEXT_DESCRIPTION, \r\n    B.ACCOUNTING_CODE, \r\n    B.MAXIMUM_ALLOWED_STORAGE \r\n   ORDER BY TOTAL_STORAGE_USED DESC FETCH FIRST 10 ROWS ONLY;"
# SERVICE_CATEGORY='STORAGE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SYSDISKSTAT' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=28 INITIAL_DB2_GROUP_LEVEL=10 EARLIEST_POSSIBLE_RELEASE='V7R3M0' EXAMPLE="-- Description: Return information about all disks, resetting the \r\n     -- statistical information shown for the current job. \r\n SELECT * FROM TABLE(QSYS2.SYSDISKSTAT(RESET_STATISTICS=>'YES'));"
# SERVICE_CATEGORY='STORAGE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SYSTMPSTG' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='SYSTMPSTG' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R2M0' EXAMPLE="-- Description: Looking at the database server jobs, find the \r\n-- top 10 consumers of temporary storage and retrieve \r\n-- details about those jobs. \r\n WITH TOP_TMP_STG(BUCKET_CURRENT_SIZE, BUCKET_PEAK_SIZE, Q_JOB_NAME) \r\n AS (SELECT BUCKET_CURRENT_SIZE, BUCKET_PEAK_SIZE, RTRIM(JOB_NUMBER) CONCAT '/' CONCAT \r\n     RTRIM(JOB_USER_NAME) CONCAT '/' CONCAT RTRIM(JOB_NAME) AS Q_JOB_NAME \r\n    FROM QSYS2.SYSTMPSTG \r\n    WHERE JOB_STATUS = '*ACTIVE' AND \r\n    JOB_NAME IN ('QZDASOINIT', 'QZDASSINIT', 'QRWTSRVR', 'QSQSRVR') \r\n    ORDER BY BUCKET_CURRENT_SIZE DESC \r\n    FETCH FIRST 10 ROWS ONLY) \r\n SELECT BUCKET_CURRENT_SIZE, BUCKET_PEAK_SIZE, Q_JOB_NAME, V_SQL_STATEMENT_TEXT, B.* \r\n FROM TOP_TMP_STG, TABLE(QSYS2.GET_JOB_INFO(Q_JOB_NAME)) B;"
# SERVICE_CATEGORY='BACKUP AND RECOVERY' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='MEDIA_LIBRARY_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='MEDIA_INFO' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Check for unavailable tape drives \r\n SELECT * FROM QSYS2.MEDIA_LIBRARY_INFO WHERE DEVICE_STATUS = 'VARIED OFF';"
# SERVICE_CATEGORY='STORAGE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='ASP_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='ASP_INFO' LATEST_DB2_GROUP_LEVEL=25 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R2M0' EXAMPLE='-- Description: Show the ASP information for the partition. \r\n SELECT * FROM QSYS2.ASP_INFO;'
# SERVICE_CATEGORY='STORAGE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='ASP_VARY_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='VARY_INFO' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R2M0' EXAMPLE='-- Description: Analyze the total time needed for vary on and off. \r\n SELECT IASP_NAME, OPERATION_TYPE, OPERATION_NUMBER,   BIGINT(SUM(DURATION)) AS TOTAL_SECONDS,  DATE(MAX(START_TIMESTAMP)) AS WHEN   FROM QSYS2.ASP_VARY_INFO GROUP BY IASP_NAME, OPERATION_TYPE,   OPERATION_NUMBER ORDER BY 5 DESC;'
# SERVICE_CATEGORY='PRODUCT' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='LICENSE_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='LIC_INFO' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Review licenses for installed features  \r\n     --    which have logged license violations  \r\n SELECT L.*  \r\n   FROM QSYS2.LICENSE_INFO L  \r\n   WHERE INSTALLED = 'YES' AND  \r\n         LOG_VIOLATION = 'YES';"
# SERVICE_CATEGORY='PTF' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='FIRMWARE_CURRENCY' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='FWCUR' LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R3M0' EXAMPLE='-- Description: Determine whether there is a newer version of \r\n-- firmware available for the current partition \r\n  SELECT * FROM SYSTOOLS.FIRMWARE_CURRENCY;'
# SERVICE_CATEGORY='SPOOL' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='OUTPUT_QUEUE_ENTRIES' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=23 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Find the top 10 consumers of SPOOL storage \r\n SELECT USER_NAME, SUM(SIZE) AS TOTAL_SPOOL_SPACE \r\n   FROM TABLE(QSYS2.OBJECT_STATISTICS('*ALLUSR   ', 'LIB    ')) AS S1, \r\n   LATERAL \r\n   (SELECT * FROM TABLE(QSYS2.OBJECT_STATISTICS(CAST(S1.objname AS CHAR(10)), \r\n                                                'OUTQ   ')) AS b) AS S2, \r\n   LATERAL \r\n   (SELECT * FROM TABLE(QSYS2.OUTPUT_QUEUE_ENTRIES(S1.objname, \r\n                                                   S2.objname, '*NO')) \r\n    AS c) AS S3 \r\n   WHERE S1.OBJNAME NOT LIKE 'Q%' AND USER_NAME NOT LIKE 'Q%' \r\n   GROUP BY USER_NAME \r\n   ORDER BY TOTAL_SPOOL_SPACE DESC \r\n   LIMIT 10;"
# SERVICE_CATEGORY='SPOOL' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='OUTPUT_QUEUE_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='OUTQ_DTL' LATEST_DB2_GROUP_LEVEL=23 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Find the output queue with the most files and examine the spool detail \r\n WITH BIGGEST_OUTQ(LIBNAME, QUEUENAME, FILECOUNT) \r\n AS (SELECT OUTPUT_QUEUE_LIBRARY_NAME, OUTPUT_QUEUE_NAME, NUMBER_OF_FILES \r\n    FROM QSYS2.OUTPUT_QUEUE_INFO \r\n    ORDER BY NUMBER_OF_FILES DESC \r\n    FETCH FIRST 1 ROWS ONLY) \r\n SELECT LIBNAME, QUEUENAME, X.* \r\n    FROM BIGGEST_OUTQ, TABLE(QSYS2.OUTPUT_QUEUE_ENTRIES(LIBNAME, QUEUENAME, '*NO')) X \r\n ORDER BY TOTAL_PAGES DESC;"
# SERVICE_CATEGORY='SYSTEM HEALTH' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SYSLIMTBL' SQL_OBJECT_TYPE='TABLE' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='SYSLIMTBL' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Are there any triggers created over the System Limits table \r\n SELECT * FROM QSYS2.SYSTRIGGERS \r\n  WHERE EVENT_OBJECT_SCHEMA = 'QSYS2' AND EVENT_OBJECT_TABLE = 'SYSLIMTBL';"
# SERVICE_CATEGORY='SYSTEM HEALTH' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SYSLIMITS' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='SYSLIMITS' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE='-- Description: Review the largest tables in System Limits \r\n WITH X AS (SELECT ROW_NUMBER() \r\n            OVER(PARTITION BY SYSTEM_SCHEMA_NAME, \r\n                 SYSTEM_OBJECT_NAME, SYSTEM_TABLE_MEMBER ORDER BY \r\n                CURRENT_VALUE DESC NULLS LAST) AS R, U.* \r\n            FROM QSYS2.SYSLIMITS U \r\n            WHERE LIMIT_ID = 15000) \r\n        SELECT LAST_CHANGE_TIMESTAMP, SYSTEM_SCHEMA_NAME, \r\n          SYSTEM_OBJECT_NAME, SYSTEM_TABLE_MEMBER, \r\n        CURRENT_VALUE \r\n        FROM X WHERE R = 1 \r\n        ORDER BY CURRENT_VALUE DESC;'
# SERVICE_CATEGORY='JOURNAL' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='JOURNAL_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='JRNINFO' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE='-- Description: Which remote journals fell the farthest behind this week? \r\n SELECT MAXIMUM_TIME_BEHIND, A.* FROM QSYS2.JOURNAL_INFO A WHERE \r\n        MAXIMUM_BEHIND_TIMESTAMP > CURRENT TIMESTAMP - 7 DAYS AND \r\n        MAXIMUM_TIME_BEHIND > 0 AND \r\n        MAXIMUM_TIME_BEHIND IS NOT NULL ORDER BY MAXIMUM_TIME_BEHIND DESC \r\n        FETCH FIRST 10 ROWS ONLY;'
# SERVICE_CATEGORY='JOURNAL' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='DISPLAY_JOURNAL' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=26 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Retrieve the Change Profile entries over that last day \r\n SELECT journal_code, journal_entry_type, object, object_type, X.* \r\n FROM TABLE ( \r\n QSYS2.Display_Journal( \r\n   'QSYS', 'QAUDJRN', \r\n   Starting_Timestamp => CURRENT DATE - 1 DAY, \r\n   Journal_Codes => 'T', \r\n   Journal_Entry_Types => 'CP' \r\n )) as x;"
# SERVICE_CATEGORY='JAVA' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='JVM_INFO' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=25 INITIAL_DB2_GROUP_LEVEL=25 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE='-- Description: Show information for all JVMs on the system. Do not wait longer than  \r\n  --   10 seconds for the results of any individual JVM to be returned. \r\n SELECT * FROM TABLE(QSYS2.JVM_INFO(WAIT_TIME => 10));'
# SERVICE_CATEGORY='JAVA' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SET_JVM' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Generate detailed diagnostics for a specific JVM \r\n CALL QSYS2.SET_JVM('962835/JAVA/QJVAEXEC', 'GENERATE_HEAP_DUMP');"
# SERVICE_CATEGORY='APPLICATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='QCMDEXC' SQL_OBJECT_TYPE='SCALAR FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=13 INITIAL_DB2_GROUP_LEVEL=13 EARLIEST_POSSIBLE_RELEASE='V7R3M0' EXAMPLE="-- Description: Hold jobs that started running an SQL statement \r\n     -- more than 2 hours ago. \r\n SELECT JOB_NAME,   \r\n       CASE WHEN QSYS2.QCMDEXC('HLDJOB ' CONCAT JOB_NAME) = 1 THEN 'Job Held' \r\n            ELSE 'Job not held' \r\n         END AS HLDJOB_RESULT \r\n  FROM TABLE (QSYS2.ACTIVE_JOB_INFO (DETAILED_INFO=> 'ALL'))  \r\n  WHERE SQL_STATEMENT_START_TIMESTAMP < CURRENT TIMESTAMP - 2 HOURS;"
# SERVICE_CATEGORY='APPLICATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SERVICES_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='SERV_INFO' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Review all the Security related IBM i Services \r\n SELECT * FROM QSYS2.SERVICES_INFO \r\n  WHERE SERVICE_CATEGORY = 'SECURITY';"
# SERVICE_CATEGORY='APPLICATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='ENVIRONMENT_VARIABLE_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='ENV_VARS' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Review all system level environment variables for this connection \r\n SELECT * \r\n   FROM QSYS2.ENVIRONMENT_VARIABLE_INFO \r\n   WHERE ENVIRONMENT_VARIABLE_TYPE = 'SYSTEM';"
# SERVICE_CATEGORY='APPLICATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SET_PASE_SHELL_INFO' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Set the current user's shell to BASH shipped by 5733-OPS. \r\n CALL QSYS2.SET_PASE_SHELL_INFO('*CURRENT',  \r\n   '/QOpenSys/QIBM/ProdData/OPS/tools/bin/bash');"
# SERVICE_CATEGORY='MESSAGE HANDLING' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='MESSAGE_FILE_DATA' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='MSGF_DATA' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R3M0' EXAMPLE="-- Description: Find any messages in the APPLIB/APPMSGS message file that  \r\n-- contain the word VALUE in upper case, lower case, or mixed case in the second  \r\n-- level message text. \r\nSELECT * FROM QSYS2.MESSAGE_FILE_DATA  \r\n  WHERE MESSAGE_FILE_LIBRARY = 'APPLIB' AND MESSAGE_FILE = 'APPMSGS' \r\n   AND UPPER(MESSAGE_SECOND_LEVEL_TEXT) LIKE '%VALUE%';"
# SERVICE_CATEGORY='COMMUNICATION' SERVICE_SCHEMA_NAME='SYSIBMADM' SERVICE_NAME='ENV_SYS_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='ENVSYSINFO' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Review the IBM i Operating system level \r\n     SELECT OS_NAME CONCAT ' ' CONCAT OS_VERSION CONCAT '.' \r\n     CONCAT OS_RELEASE FROM SYSIBMADM.ENV_SYS_INFO;"
# SERVICE_CATEGORY='COMMUNICATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='TCPIP_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='TCPIP_INFO' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE='-- Description: Retrieve the Host name, IBM i OS version and Client IP address \r\n SELECT LOCAL_HOST_NAME, HOST_VERSION, CLIENT_IP_ADDRESS FROM QSYS2.TCPIP_INFO;'
# SERVICE_CATEGORY='COMMUNICATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SET_SERVER_SBS_ROUTING' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=4 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Use SERVER_SBS_ROUTING to reposition SCOTT to an alternate SBS \r\n CL: CRTSBSD SBSD(QGPL/ADHOCSBS) POOLS((1 *BASE)) TEXT('Ad hoc users SBS'); \r\n CL: CRTJOBQ QGPL/ADHOCJOBQ TEXT('Ad hoc users job queue'); \r\n CL: ADDJOBQE SBSD(QGPL/ADHOCSBS) JOBQ(QGPL/ADHOCJOBQ) MAXACT(100) SEQNBR(40); \r\n CL: CRTCLS CLS(QGPL/ADHOCCLS) RUNPTY(55) TIMESLICE(100) TEXT('Ad hoc class'); \r\n CL: ADDPJE SBSD(QGPL/ADHOCSBS) PGM(QSYS/QRWTSRVR) JOBD(QGPL/QDFTSVR) CLS(QGPL/ADHOCCLS); \r\n CL: ADDPJE SBSD(QGPL/ADHOCSBS) PGM(QSYS/QZDASOINIT) JOBD(QGPL/QDFTSVR) CLS(QGPL/ADHOCCLS); \r\n CL: STRSBS SBSD(QGPL/ADHOCSBS); \r\n CALL QSYS2.SET_SERVER_SBS_ROUTING('SCOTT','*ALL','ADHOCSBS');"
# SERVICE_CATEGORY='COMMUNICATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SERVER_SBS_ROUTING' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='SRVR_RTG' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE='-- Description: Review the existing configurations for users and groups \r\n SELECT * FROM QSYS2.SERVER_SBS_ROUTING;'
# SERVICE_CATEGORY='COMMUNICATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='NETSTAT_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='NS_INFO' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE='-- Description: Review the connections that are transferring the most data \r\n SELECT * FROM QSYS2.NETSTAT_INFO \r\n   ORDER BY BYTES_SENT_REMOTELY + BYTES_RECEIVED_LOCALLY DESC \r\n   LIMIT 10;'
# SERVICE_CATEGORY='COMMUNICATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='NETSTAT_INTERFACE_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='NS_INTER' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE='-- Description: Review the TCP/IP Interface details \r\n SELECT * FROM QSYS2.NETSTAT_INTERFACE_INFO;'
# SERVICE_CATEGORY='COMMUNICATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='NETSTAT_JOB_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='NS_JOB' LATEST_DB2_GROUP_LEVEL=26 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Review the network jobs coming in from a unique IP address \r\n WITH NETSTAT_USER_JOBS (V_JOB_NAME,  V_LOCAL_PORT) AS ( \r\n SELECT JOB_NAME, LOCAL_PORT_NAME FROM QSYS2.NETSTAT_JOB_INFO \r\n  WHERE REMOTE_ADDRESS = '9.10.213.27' ) \r\n   SELECT AUTHORIZATION_NAME, V_JOB_NAME, V_LOCAL_PORT, \r\n          RUN_PRIORITY, CPU_TIME, SERVER_TYPE \r\n     FROM NETSTAT_USER_JOBS, \r\n          TABLE(QSYS2.ACTIVE_JOB_INFO()) B \r\n          WHERE JOB_NAME = V_JOB_NAME;"
# SERVICE_CATEGORY='COMMUNICATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='NETSTAT_ROUTE_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='NS_ROUTE' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE='-- Description: Review the details of all TCP/IP routes \r\n SELECT * FROM QSYS2.NETSTAT_ROUTE_INFO;'
# SERVICE_CATEGORY='DATABASE-APPLICATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='PARSE_STATEMENT' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=26 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R2M0' EXAMPLE="-- Description: For schema TOYSTORE, find all tables referenced by \r\n-- static SQL statements by all application programs \r\n  WITH program_statements(naming_mode,\r\n                          dec_point,\r\n                          string_delim,\r\n                          stmt_text,\r\n                          system_program_name,\r\n                          program_type)\r\n    AS (SELECT a.naming,\r\n               a.decimal_point,\r\n               a.sql_string_delimiter,\r\n               b.statement_text,\r\n               a.system_program_name,\r\n               a.program_type\r\n          FROM qsys2.sysprogramstat a INNER JOIN\r\n               qsys2.sysprogramstmtstat b ON \r\n                     a.program_schema = b.program_schema AND\r\n                     a.program_name = b.program_name AND\r\n                     a.module_name = b.module_name\r\n          WHERE a.program_schema = 'TOYSTORE' AND\r\n                b.program_schema = 'TOYSTORE')\r\n    SELECT system_program_name,\r\n           program_type,\r\n           c.schema,\r\n           c.name,\r\n           stmt_text\r\n      FROM program_statements,\r\n         TABLE(qsys2.parse_statement(stmt_text, naming_mode,\r\n                                     dec_point, string_delim)) c\r\n      WHERE c.name_type = 'TABLE'\r\n      ORDER BY c.schema, c.name;"
# SERVICE_CATEGORY='DATABASE-APPLICATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='DELIMIT_NAME' SQL_OBJECT_TYPE='SCALAR FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE='-- Description: Delimit DB2 for i catalog names, as needed \r\n SELECT QSYS2.DELIMIT_NAME(TABLE_NAME) FROM QSYS2.SYSTABLES;'
# SERVICE_CATEGORY='DATABASE-APPLICATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='OVERRIDE_TABLE' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Use a higher blocking factor for I/O \r\n CALL QSYS2.OVERRIDE_TABLE('TOYSTORE', 'ITEM_FACT', '*BUF128KB');"
# SERVICE_CATEGORY='DATABASE-APPLICATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='OVERRIDE_QAQQINI' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=7 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Establish the temporary override for QAQQINI. \r\n -- The current QAQQINI values for the job will be used as the initial values. \r\n CALL QSYS2.OVERRIDE_QAQQINI(1, '', ''); \r\n    -- Description: Temporarily override the UDF timeout QAQQINI option. \r\n CALL QSYS2.OVERRIDE_QAQQINI(2, 'UDF_TIME_OUT', '*MAX');"
# SERVICE_CATEGORY='DATABASE-APPLICATION' SERVICE_SCHEMA_NAME='SYSPROC' SERVICE_NAME='WLM_SET_CLIENT_INFO' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=23 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Brand the client special register values for a connection \r\n CALL SYSPROC.WLM_SET_CLIENT_INFO('db2user','machine.rchland.ibm.com','auditor', \r\n    'Accounting department', 'MYPGM');"
# SERVICE_CATEGORY='DATABASE-PERFORMANCE' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='ACT_ON_INDEX_ADVICE' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: For schema TOYSTORE, find all instances of index advice where \r\n-- an MTI was used more than 1000 times and create permanent SQL indexes. \r\n CALL SYSTOOLS.ACT_ON_INDEX_ADVICE('TOYSTORE',NULL,NULL,1000,NULL);"
# SERVICE_CATEGORY='DATABASE-PERFORMANCE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='DATABASE_MONITOR_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='DBMON_INFO' LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Retrieve the info for all the active PUBLIC monitors \r\n SELECT MONITOR_ID, MONITOR_LIBRARY, MONITOR_FILE \r\n   FROM QSYS2.DATABASE_MONITOR_INFO \r\n   WHERE MONITOR_STATUS = 'ACTIVE' AND \r\n         MONITOR_TYPE = 'PUBLIC';"
# SERVICE_CATEGORY='DATABASE-PERFORMANCE' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='HARVEST_INDEX_ADVICE' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Harvest create index statements for file TOYSTORE/SALES \r\n-- Further, use RUNSQLSTM to create the indexes. \r\n-- The criteria for index creation is: \r\n-- 1) The index has been advised at least 100 times AND \r\n-- 2) A matching MTI has been used at least 50 times AND \r\n-- 3) The average query estimate is greater than 5 seconds \r\n BEGIN \r\n DECLARE not_found CONDITION FOR '02000'; \r\n DECLARE ERROR_COUNT INTEGER DEFAULT 0; \r\n DECLARE at_end INT DEFAULT 0; \r\n DECLARE V_INDEX_COUNT INTEGER DEFAULT 0; \r\n DECLARE V_PARTITION_NAME VARCHAR(10); \r\n DECLARE INDEX_SOURCE_CURSOR CURSOR FOR \r\n   select TABLE_partition from qsys2.syspartitionstat where \r\n   table_schema = 'QGPL' and table_name = 'INDEXSRC'; \r\n DECLARE CONTINUE HANDLER FOR SQLEXCEPTION SET ERROR_COUNT = ERROR_COUNT + 1; \r\n CALL QSYS2.QCMDEXC('DLTF FILE(QGPL/INDEXSRC)'); \r\n CALL QSYS2.QCMDEXC('CRTSRCPF FILE(QGPL/INDEXSRC)  RCDLEN(10000)'); \r\n-- Create the source file with a big record length, \r\n-- to allow the create index statement to fit on one line \r\n CALL SYSTOOLS.HARVEST_INDEX_ADVICE('TOYSTORE', 'SALES', \r\n                                    100, 50, 5, 'QGPL', 'INDEXSRC'); \r\n  BEGIN \r\n    DECLARE V_RUNSQLSTM_TEXT VARCHAR(500); \r\n    DECLARE CONTINUE HANDLER FOR SQLEXCEPTION SET at_end = 1; \r\n    DECLARE CONTINUE HANDLER FOR not_found    SET at_end = 1; \r\n    OPEN INDEX_SOURCE_CURSOR; \r\n    FETCH FROM INDEX_SOURCE_CURSOR INTO V_PARTITION_NAME; \r\n    WHILE ( at_end = 0 ) DO \r\n      -- Now that QGPL/INDEXSRC has been populated with members named HARVnnnn, \r\n      -- the RUNSQLSTM command can be used to execute the CREATE INDEX statement. \r\n      -- By using ERRLVL = 30, we will ignore any failures. \r\n      SET V_RUNSQLSTM_TEXT = 'RUNSQLSTM SRCFILE(QGPL/INDEXSRC) SRCMBR(' \r\n       CONCAT RTRIM(V_PARTITION_NAME) CONCAT \r\n       ') COMMIT(*NONE) NAMING(*SQL) ERRLVL(30) MARGINS(10000)'; \r\n      CALL QSYS2.QCMDEXC(V_RUNSQLSTM_TEXT); \r\n      FETCH FROM INDEX_SOURCE_CURSOR INTO V_PARTITION_NAME; \r\n    END WHILE; \r\n    CLOSE INDEX_SOURCE_CURSOR; \r\n  END; \r\n END;"
# SERVICE_CATEGORY='DATABASE-PERFORMANCE' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='REMOVE_INDEXES' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Remove indexes older than a month that have never been used. \r\n CALL SYSTOOLS.REMOVE_INDEXES('TOYSTORE', 1, '1 MONTH');"
# SERVICE_CATEGORY='DATABASE-PERFORMANCE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='RESET_TABLE_INDEX_STATISTICS' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Reset the QUERY_USE_COUNT and QUERY_STATISTICS_COUNT \r\n-- statistics for all the indexes built over the TOYSTORE/EMPLOYEE table \r\n CALL QSYS2.RESET_TABLE_INDEX_STATISTICS('TOYSTORE', 'EMPLOYEE');"
# SERVICE_CATEGORY='DATABASE-PLAN CACHE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='CHANGE_PLAN_CACHE_SIZE' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE='-- Description: Change the plan cache size to 5Gig \r\n   CALL QSYS2.CHANGE_PLAN_CACHE_SIZE(5120);'
# SERVICE_CATEGORY='DATABASE-PLAN CACHE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='CLEAR_PLAN_CACHE' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=13 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Clear the entire plan cache \r\n   CALL QSYS2.QCMDEXC('SBMJOB CMD(RUNSQL SQL(''CALL \r\n        QSYS2.CLEAR_PLAN_CACHE()'') COMMIT(*NONE) NAMING(*SQL))');"
# SERVICE_CATEGORY='DATABASE-PLAN CACHE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='DUMP_PLAN_CACHE' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=28 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Capture a complete plan cache snapshot \r\n   CALL QSYS2.DUMP_PLAN_CACHE('SNAPSHOTS','FULLSNAP');"
# SERVICE_CATEGORY='DATABASE-PLAN CACHE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='DUMP_PLAN_CACHE_PROPERTIES' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=None INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V7R1M0' EXAMPLE="-- Description: Retrieve the properties \r\n    CALL QSYS2.DUMP_PLAN_CACHE_PROPERTIES('SNAPSHOTS','PCP160217');"
# SERVICE_CATEGORY='DATABASE-PLAN CACHE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='DUMP_PLAN_CACHE_TOPN' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=13 INITIAL_DB2_GROUP_LEVEL=None EARLIEST_POSSIBLE_RELEASE='V6R1M0' EXAMPLE="-- Description: Capture the 25 heaviest queries \r\n    CALL QSYS2.DUMP_PLAN_CACHE_TOPN('SNAPSHOTS', 'TOPN160217', 25);"
# ...
# SERVICE_CATEGORY='APPLICATION' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='ERRNO_INFO' SQL_OBJECT_TYPE='SCALAR FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=28 INITIAL_DB2_GROUP_LEVEL=28 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE='-- Description: Return information for errno 3025. \r\n    VALUES SYSTOOLS.ERRNO_INFO(3025);'
# SERVICE_CATEGORY='APPLICATION' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='GETENV' SQL_OBJECT_TYPE='SCALAR FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=28 INITIAL_DB2_GROUP_LEVEL=28 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: Get the value of MY_ENVVAR for the current job. \r\n    VALUES SYSTOOLS.GETENV('MY_ENVVAR');"
# SERVICE_CATEGORY='APPLICATION' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='PUTENV' SQL_OBJECT_TYPE='SCALAR FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=28 INITIAL_DB2_GROUP_LEVEL=28 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: Set the value of MY_ENVVAR for the current job. \r\n    VALUES SYSTOOLS.PUTENV('MY_ENVVAR', 'My job''s value for the environment variable');"
# SERVICE_CATEGORY='DATABASE-APPLICATION' SERVICE_SCHEMA_NAME='SYSIBMADM' SERVICE_NAME='SELFCODES' SQL_OBJECT_TYPE='GLOBAL VARIABLE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=23 INITIAL_DB2_GROUP_LEVEL=23 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: Configure SELF to capture detail for all jobs started in the future, \r\n     -- for any SQL statements that fail with SQLCODE = -913 or SQLCODE = -204. \r\n  CREATE OR REPLACE VARIABLE SYSIBMADM.SELFCODES  \r\n      VARCHAR(256) DEFAULT '-913, -204';"
# SERVICE_CATEGORY='DATABASE-UTILITY' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SYSMEMBERSTAT' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='SYSMSTAT' LATEST_DB2_GROUP_LEVEL=28 INITIAL_DB2_GROUP_LEVEL=28 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: Examine some statistical information for all members of all files in APPLIB1. \r\n SELECT TABLE_NAME, NUMBER_ROWS, NUMBER_DELETED_ROWS, LAST_USED_TIMESTAMP \r\n  FROM QSYS2.SYSMEMBERSTAT \r\n  WHERE TABLE_SCHEMA = 'APPLIB1';"
# SERVICE_CATEGORY='IFS' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='IFS_UNLINK' SQL_OBJECT_TYPE='SCALAR FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=28 INITIAL_DB2_GROUP_LEVEL=28 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: Unlink file /usr/reportdata.txt. \r\n   VALUES SYSTOOLS.IFS_UNLINK(PATH_NAME => '/usr/reportdata.txt');"
# SERVICE_CATEGORY='IFS' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='COMPARE_IFS' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=28 INITIAL_DB2_GROUP_LEVEL=28 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: Compare the names for all objects in two subtrees. Compare recursively  \r\n        -- through the entire set of subdirectories. \r\n   SELECT * FROM TABLE(QSYS2.COMPARE_IFS(  \r\n                                       START_PATH_NAME1    => '/usr/files.dir',  \r\n                                       START_PATH_NAME2    => '/usrbackup/files.dir', \r\n                                       SUBTREE_DIRECTORIES => 'YES', \r\n                                       COMPARE_ATTRIBUTES  => 'NAMES' \r\n                              ));"
# SERVICE_CATEGORY='SECURITY' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='ADD_VALIDATION_LIST_ENTRY' SQL_OBJECT_TYPE='SCALAR FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: Add an authentication entry for a user of an external interface. \r\n     --   Use a global variable so the password is not visible in the function invocation. \r\n     --   for all user profiles on the system. \r\n     CREATE VARIABLE MYLIB.VLDL_PW VARCHAR(100); \r\n \r\nSET MYLIB.VLDL_PW = 'password for my user access'; \r\n \r\nVALUES SYSTOOLS.ADD_VALIDATION_LIST_ENTRY( \r\n                             VALIDATION_LIST_LIBRARY => 'APPLIB',  \r\n                             VALIDATION_LIST_NAME    => 'APPVLDL', \r\n                             VALIDATION_USER         => 'my application user name', \r\n                             PASSWORD                => MYLIB.VLDL_PW);"
# SERVICE_CATEGORY='SECURITY' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='CHANGE_VALIDATION_LIST_ENTRY' SQL_OBJECT_TYPE='SCALAR FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: Change the password for an existing authentication entry.\r\n     CREATE VARIABLE MYLIB.VLDL_PW VARCHAR(100); \r\n \r\nSET MYLIB.VLDL_PW = 'my new password'; \r\n \r\nVALUES SYSTOOLS.CHANGE_VALIDATION_LIST_ENTRY( \r\n                             VALIDATION_LIST_LIBRARY => 'APPLIB',  \r\n                             VALIDATION_LIST_NAME    => 'APPVLDL', \r\n                             VALIDATION_USER         => 'my application user name', \r\n                             PASSWORD                => MYLIB.VLDL_PW);"
# SERVICE_CATEGORY='SECURITY' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='REMOVE_VALIDATION_LIST_ENTRY' SQL_OBJECT_TYPE='SCALAR FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: Remove an authentication entry for a specific user of an external interface.\r\nVALUES SYSTOOLS.REMOVE_VALIDATION_LIST_ENTRY( \r\n                             VALIDATION_LIST_LIBRARY => 'APPLIB',  \r\n                             VALIDATION_LIST_NAME    => 'APPVLDL', \r\n                             VALIDATION_USER         => 'my application user name');"
# SERVICE_CATEGORY='WORK MANAGEMENT' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='END_JOBS' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: Find and end all the active jobs with a job name of BATCHTEST. \r\n    -- For every job, end using the controlled option, save any spooled files, and do \r\n    -- not generate a job log. \r\n  CALL SYSTOOLS.END_JOBS(JOB_NAME_FILTER          => 'BATCHTEST',  \r\n                       END_OPTION               => 'CONTROLLED', \r\n                       DELETE_SPOOLED_FILES     => 'NO', \r\n                       MAXIMUM_JOBLOG_ENTRIES   => 0);"
# SERVICE_CATEGORY='WORK MANAGEMENT' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='POWER_SCHEDULE_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='POWER_INFO' LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE='-- Description: List all the scheduled power events. \r\n  SELECT * FROM SYSTOOLS.POWER_SCHEDULE_INFO;'
# SERVICE_CATEGORY='CONFIGURATION' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='CONFIGURATION_STATUS' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='CONFIG_STS' LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: List the status of all controllers. \r\n   SELECT OBJECT_NAME, OBJECT_ATTRIBUTE, STATUS_DESCRIPTION, TEXT_DESCRIPTION  \r\n  FROM SYSTOOLS.CONFIGURATION_STATUS \r\n  WHERE OBJECT_TYPE = '*CTLD';"
# SERVICE_CATEGORY='CONFIGURATION' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='SERVICE_TOOLS_SERVER_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='STS_INFO' LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE='-- Description: Show information about the service tools server configuration. \r\n   SELECT * FROM QSYS2.SERVICE_TOOLS_SERVER_INFO;'
# SERVICE_CATEGORY='JOURNAL' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='AUDIT_JOURNAL_VP' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE='-- Description: Review the Network Server password failures, by day and by server name. \r\n  SELECT DATE(ENTRY_TIMESTAMP) AS "DATE", SERVER_NAME,  \r\n       COUNT(*) AS NETWORK_SERVER_PASSWORD_ERROR_COUNT \r\n  FROM TABLE (  \r\n      SYSTOOLS.AUDIT_JOURNAL_VP(STARTING_TIMESTAMP => CURRENT TIMESTAMP - 7 DAYS))  \r\n  GROUP BY DATE(ENTRY_TIMESTAMP), SERVER_NAME \r\n  ORDER BY "DATE", NETWORK_SERVER_PASSWORD_ERROR_COUNT DESC;'
# SERVICE_CATEGORY='MIGRATE WHILE ACTIVE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='CHANGE_MIGRATION_MANAGER' SQL_OBJECT_TYPE='PROCEDURE' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: Enable initial configuration of IBM i Migrate While Active                         \r\n-- and set the current node as the source node.                                                     \r\n    CALL QSYS2.CHANGE_MIGRATION_MANAGER(ACTION => 'SETUP');"
# SERVICE_CATEGORY='MIGRATE WHILE ACTIVE' SERVICE_SCHEMA_NAME='SYSIBMADM' SERVICE_NAME='DATA_COMPRESSION_FACTOR' SQL_OBJECT_TYPE='TABLE' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='COMP_FACT' LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE='-- Description: List the compression factors used for the different types                          \r\n-- of compression in IBM i Migrate While Active.                                                    \r\n    SELECT * FROM SYSIBMADM.DATA_COMPRESSION_FACTOR;'
# SERVICE_CATEGORY='MIGRATE WHILE ACTIVE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='ESTIMATE_FINAL_SYNCHRONIZATION_TIME' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE='-- Description: Estimate the length of time required to complete                                   \r\n-- synchronization of objects in a IBM i Migrate While                                              \r\n-- Active environment to the copy node.                                                             \r\n    SELECT * FROM TABLE(QSYS2.ESTIMATE_FINAL_SYNCHRONIZATION_TIME());'
# SERVICE_CATEGORY='MIGRATE WHILE ACTIVE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='IFS_MIGRATION_LIST' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='MIG_ITL' LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: Examine the integrated file system objects that are                                \r\n-- currently attempting migration to the copy node.                                                 \r\n    SELECT PATH_NAME, OBJECT_TYPE                                                                   \r\n      FROM QSYS2.IFS_MIGRATION_LIST                                                                 \r\n      WHERE TRACKING_STATE = 'MIGRATING'                                                          \r\n      ORDER BY PATH_NAME, OBJECT_TYPE;"
# SERVICE_CATEGORY='MIGRATE WHILE ACTIVE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='LIBRARY_MIGRATION_LIST' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='MIG_LTL' LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: Examine the eligible library-based objects that need                               \r\n-- to be migrated to the copy node.                                                                 \r\n    SELECT LIBRARY_NAME, OBJECT_NAME, OBJECT_SIZE                                                   \r\n      FROM QSYS2.LIBRARY_MIGRATION_LIST                                                             \r\n      WHERE TRACKING_STATE  <> 'MIGRATING'                                                        \r\n      ORDER BY LIBRARY_NAME, OBJECT_NAME;"
# SERVICE_CATEGORY='MIGRATE WHILE ACTIVE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='MIGRATED_IFS' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='MIG_IFS' LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE='-- Description: Review a list of the integrated file system objects that                           \r\n-- have successfully completed migration to the copy node within                                    \r\n-- the last hour.                                                                                   \r\n    SELECT * FROM QSYS2.MIGRATED_IFS                                                                \r\n      WHERE MIGRATION_END_TIME > CURRENT TIMESTAMP - 1 HOUR                                         \r\n      ORDER BY MIGRATION_END_TIME DESC;'
# SERVICE_CATEGORY='MIGRATE WHILE ACTIVE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='MIGRATED_LIBRARY' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='MIG_LIB' LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: Review a list of library-based objects in TOYSTORE                                 \r\n-- that have successfully completed migration to the copy node                                      \r\n-- within the last hour.                                                                            \r\n    SELECT * FROM QSYS2.MIGRATED_LIBRARY                                                            \r\n      WHERE MIGRATION_END_TIME > CURRENT TIMESTAMP - 1 HOUR AND                                     \r\n            (LIBRARY_NAME = 'TOYSTORE' OR                                                         \r\n             (LIBRARY_NAME = 'QSYS' AND                                                           \r\n              OBJECT_NAME = 'TOYSTORE' AND                                                        \r\n              OBJECT_TYPE = '*LIB'))                                                              \r\n      ORDER BY MIGRATION_END_TIME DESC;"
# SERVICE_CATEGORY='MIGRATE WHILE ACTIVE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='MIGRATION_MANAGER_INFO' SQL_OBJECT_TYPE='VIEW' OBJECT_TYPE='*FILE' SYSTEM_OBJECT_NAME='MIG_MANAGE' LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE='-- Description: Examine information about the IBM i Migrate While                                  \r\n-- Active environment.                                                                              \r\n    SELECT * FROM QSYS2.MIGRATION_MANAGER_INFO;'
# SERVICE_CATEGORY='MIGRATE WHILE ACTIVE' SERVICE_SCHEMA_NAME='QSYS2' SERVICE_NAME='MIGRATION_NETWORK_BANDWIDTH' SQL_OBJECT_TYPE='TABLE FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE='-- Description: Check the bandwidth to the copy node in a IBM i                                    \r\n-- Migrate While Active environment. Take the measurement 5                                         \r\n-- times for calculating the values.                                                                \r\n    SELECT * FROM TABLE(QSYS2.MIGRATION_NETWORK_BANDWIDTH(5));'
# SERVICE_CATEGORY='IFS' SERVICE_SCHEMA_NAME='SYSTOOLS' SERVICE_NAME='IFS_ACCESS' SQL_OBJECT_TYPE='SCALAR FUNCTION' OBJECT_TYPE=None SYSTEM_OBJECT_NAME=None LATEST_DB2_GROUP_LEVEL=29 INITIAL_DB2_GROUP_LEVEL=29 EARLIEST_POSSIBLE_RELEASE='V7R4M0' EXAMPLE="-- Description: Determine whether the invoker of the function has read access to \r\n        --   /usr/reportdata.txt. \r\n   VALUES SYSTOOLS.IFS_ACCESS(PATH_NAME => '/usr/reportdata.txt',  \r\n                           READ => 'YES');"
